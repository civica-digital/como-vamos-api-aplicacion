# %%
import Levenshtein

# %%
import numpy as np
import pandas

# %%
a = ["objetivo","subjetivo","diccionario"]

# %%
for word in a:
    print(Levenshtein.ratio("subjetivos_lote_cucuta.csv",word))
# Out:
# 0.4117647058823529
# 0.5142857142857142
# 0.21621621621621623

# %%
v for v in a
# Out:
#   File "<ipython-input-20-254fc83c0250>", line 1
#     v for v in a
#         ^
# SyntaxError: invalid syntax

# %%
import os

# %%
os.listdir("data")
# Out:
# []

# %%
def return_city_files(allcityfiles,city):
    cityfiles = []
    for filename in allcityfiles:
        if city in filename:
            cityfiles.append(filename)
    return(cityfiles)

# %%
def return_allcityfiles():
    allcityfiles = os.listdir(DATADIRECTORY)
    return allcityfiles

# %%
def identify_data_type(cityfiles):
    datatype_byfilename = {}
    for filename in cityfiles:
        ratio_objective = Levenshtein.ratio(filename,"indicadores")
        ratio_subjetive = Levenshtein.ratio(filename,"encuestas")
        if ratio_objective > ratio_subjetive: 
            datatype = "objetivo"
        else:
            datatype = "subjetivo"
        if "diccionario" in filename:
            filetype = "diccionario"
        else:
            filetype = "datos"
        datatype_byfilename[filename] = {"datatype":datatype,"filetype":filetype}
    return(datatype_byfilename)

# %%
DATADIRECTORY = "data"
files = return_allcityfiles()
bogota_files = return_city_files(files,"bogota")
datatypes = identify_data_type(bogota_files)

# %%
def get_dictionaries(files_data_type):
    dictionaries = {}
    for filename in datatypes:
        if datatypes[filename]["filetype"] == "diccionario": 
            dictionaries[filename] = datatypes[filename]["datatype"]
    return(dictionaries)

# %%
print(get_dictionaries(datatypes))
# Out:
# {'diccionario_indicadores_bogota.csv': 'objetivo', 'diccionario_encuestas_bogota_lote.csv': 'subjetivo'}

# %%
diccionario_objetivos = pandas.read_csv("data/diccionario_indicadores_bogota.csv",delimiter=",", encoding="utf-8", dtype=np.string_ )

# %%
diccionario_subjetivos = pandas.read_csv("data/diccionario_encuestas_bogota_lote.csv",delimiter=",", encoding="utf-8", dtype=np.string_ )

# %%
diccionario_objetivos
# Out:
#             id                                          Indicador  \
# 0       0-PO-1                  Indice de Envejecimiento Hombres
# 1      0-PO-12              Extensión territorial área hectáreas
# 2      0-PO-13                    Extensión territorial área km2
# 3      0-PO-14                           Indice de envejecimiento
# 4       0-PO-2                  Indice de Envejecimiento Mujeres
# 5      0-PO-23                                  Población Hombres
# 6      0-PO-25                                  Población Mujeres
# 7      0-PO-27                                    Población Total
# 8      0-PO-28         Porcentaje de Población Afrodescendientes
# 9      0-PO-29          Porcentaje de población en el área Urbana
# 10      0-PO-3                       Densidad poblacional por Km
# 11     0-PO-30                  Porcentaje de Población Indígena
# 12     0-PO-34                            Relación de Dependencia
# 13     0-PO-36                Tasa de crecimiento de la población
# 14     0-PO-37                        Tasa de Dependencia Hombres
# 15     0-PO-38                       Tasa de Dependencia Mujeres
# 16      0-PO-4  El lugar donde habita es propio con permiso de...
# 17      0-PO-5  El lugar donde habita es propio y se esta paga...
# 18      0-PO-6           El lugar en donde habita es en arriendo
# 19      0-PO-7  El lugar en donde habita es propio totalmente ...
# 20      0-PO-8                        Esperanza de vida al nacer
# 21      0-PO-9                Esperanza de vida al nacer Mujeres
# 22     0-PD-11                 Índice de condiciones de vida ICV
# 23     0-PD-16                 Índice de Desarrollo Humano Urbano
# 24     0-PD-17                Índice de Pobreza Multidimensional
# 25     0-PD-18  Índice de Pobreza Multidimensional Multipropós...
# 26     0-PD-21             Población bajo la línea de indigencia
# 27     0-PD-22        Población bajo la línea de indigencia 13 AM
# 28     0-PD-23         Población bajo la línea de indigencia GEIH
# 29     0-PD-24                Población bajo la línea de pobreza
# ..         ...                                                ...
# 275   2-MO-326  Porcentaje de personas que se moviliza princip...
# 276   2-MO-327  Porcentaje de personas que se moviliza princip...
# 277   2-MO-328  Porcentaje de personas que se moviliza princip...
# 278   2-MO-329  Porcentaje de personas que se moviliza princip...
# 279   2-MO-330  Porcentaje de personas que se moviliza princip...
# 280   2-MO-331  Porcentaje de personas que se moviliza princip...
# 281   2-MO-332  Porcentaje de personas que se moviliza princip...
# 282   2-MO-333  Porcentaje de personas que se moviliza princip...
# 283   2-MO-334  Porcentaje de personas que se moviliza princip...
# 284   2-MO-335  Pasajeros diarios movilizados por transporte p...
# 285   2-MO-336  Promedio de pasajeros en hora pico en Transmil...
# 286   2-MO-337  Número total de pasajeros interurbanos transpo...
# 287   2-MO-338  Promedio anual de velocidad en transporte públ...
# 288   2-MO-339  Promedio anual de velocidad de transporte indi...
# 289   2-MO-340  Promedio anual de velocidad particular (km/hor...
# 290   2-MO-341         Velocidad promedio de recorrido en el SITP
# 291   2-MO-342    Velocidad promedio de recorrido en Transmilenio
# 292   2-MO-343                 Muertes en el sistema Transmilenio
# 293   2-MO-344                 Heridos en el sistema Transmilenio
# 294   2-MO-345                           Cobertura de ciclo rutas
# 295   2-MO-346                              Cobertura Bici-carril
# 296   2-MO-347  Total infraestrutura para bicicletas (Ciclorut...
# 297   2-MO-348                              Cobertura carril bici
# 298   2-MO-349  Parque automotor de transporte particular (aut...
# 299   2-MO-350  Parque automotor de transporte particular (mot...
# 300   2-MO-351             Parque automotor de transporte público
# 301   2-MO-352       Charratización buses, busetas y microbusetas
# 302       ANIO                                                AÑO
# 303     CIUDAD                                             CIUDAD
# 304  LOCALIDAD                                          LOCALIDAD
#
#                        anillo                    tema  \
# 0    Escenarios Transversales  Población y Demografía
# 1    Escenarios Transversales  Población y Demografía
# 2    Escenarios Transversales  Población y Demografía
# 3    Escenarios Transversales  Población y Demografía
# 4    Escenarios Transversales  Población y Demografía
# 5    Escenarios Transversales  Población y Demografía
# 6    Escenarios Transversales  Población y Demografía
# 7    Escenarios Transversales  Población y Demografía
# 8    Escenarios Transversales  Población y Demografía
# 9    Escenarios Transversales  Población y Demografía
# 10   Escenarios Transversales  Población y Demografía
# 11   Escenarios Transversales  Población y Demografía
# 12   Escenarios Transversales  Población y Demografía
# 13   Escenarios Transversales  Población y Demografía
# 14   Escenarios Transversales  Población y Demografía
# 15   Escenarios Transversales  Población y Demografía
# 16   Escenarios Transversales  Población y Demografía
# 17   Escenarios Transversales  Población y Demografía
# 18   Escenarios Transversales  Población y Demografía
# 19   Escenarios Transversales  Población y Demografía
# 20   Escenarios Transversales  Población y Demografía
# 21   Escenarios Transversales  Población y Demografía
# 22   Escenarios Transversales   Pobreza y desigualdad
# 23   Escenarios Transversales   Pobreza y desigualdad
# 24   Escenarios Transversales   Pobreza y desigualdad
# 25   Escenarios Transversales   Pobreza y desigualdad
# 26   Escenarios Transversales   Pobreza y desigualdad
# 27   Escenarios Transversales   Pobreza y desigualdad
# 28   Escenarios Transversales   Pobreza y desigualdad
# 29   Escenarios Transversales   Pobreza y desigualdad
# ..                        ...                     ...
# 275            Hábitat Urbano          Movilidad Vial
# 276            Hábitat Urbano          Movilidad Vial
# 277            Hábitat Urbano          Movilidad Vial
# 278            Hábitat Urbano          Movilidad Vial
# 279            Hábitat Urbano          Movilidad Vial
# 280            Hábitat Urbano          Movilidad Vial
# 281            Hábitat Urbano          Movilidad Vial
# 282            Hábitat Urbano          Movilidad Vial
# 283            Hábitat Urbano          Movilidad Vial
# 284            Hábitat Urbano          Movilidad Vial
# 285            Hábitat Urbano          Movilidad Vial
# 286            Hábitat Urbano          Movilidad Vial
# 287            Hábitat Urbano          Movilidad Vial
# 288            Hábitat Urbano          Movilidad Vial
# 289            Hábitat Urbano          Movilidad Vial
# 290            Hábitat Urbano          Movilidad Vial
# 291            Hábitat Urbano          Movilidad Vial
# 292            Hábitat Urbano          Movilidad Vial
# 293            Hábitat Urbano          Movilidad Vial
# 294            Hábitat Urbano          Movilidad Vial
# 295            Hábitat Urbano          Movilidad Vial
# 296            Hábitat Urbano          Movilidad Vial
# 297            Hábitat Urbano          Movilidad Vial
# 298            Hábitat Urbano          Movilidad Vial
# 299            Hábitat Urbano          Movilidad Vial
# 300            Hábitat Urbano          Movilidad Vial
# 301            Hábitat Urbano          Movilidad Vial
# 302                       NaN                     NaN
# 303                       NaN                     NaN
# 304                       NaN                     NaN
#
#                                                 fuente                  notas  \
# 0                                                 DANE                    NaN
# 1                   Secretaría Distrital de planeación                    NaN
# 2                   Secretaría Distrital de planeación                    NaN
# 3                                                 DANE                    NaN
# 4                                                 DANE                    NaN
# 5                                                 DANE                    NaN
# 6                                                 DANE                    NaN
# 7                                                 DANE                    NaN
# 8                                                 DANE                    NaN
# 9                                                 DANE                    NaN
# 10                  Secretaría Distrital de planeación                    NaN
# 11                                                DANE                    NaN
# 12                                                DANE                    NaN
# 13                                                DANE                    NaN
# 14                                                DANE                    NaN
# 15                                                DANE                    NaN
# 16                                                DANE                    NaN
# 17                                                DANE                    NaN
# 18                                                DANE                    NaN
# 19                                                DANE                    NaN
# 20                                                DANE                    NaN
# 21                                                DANE                    NaN
# 22                             Encuesta Multipropósito                    NaN
# 23                             Encuesta Multipropósito                    NaN
# 24                                                DANE                    NaN
# 25                                                DANE                    NaN
# 26                                                DANE                    NaN
# 27                                                DANE                    NaN
# 28                                                DANE                    NaN
# 29                                                DANE                    NaN
# ..                                                 ...                    ...
# 275                        Encuesta bienal de culturas                    NaN
# 276                        Encuesta bienal de culturas                    NaN
# 277                        Encuesta bienal de culturas                    NaN
# 278                        Encuesta bienal de culturas                    NaN
# 279                        Encuesta bienal de culturas                    NaN
# 280                        Encuesta bienal de culturas                    NaN
# 281                        Encuesta bienal de culturas                    NaN
# 282                        Encuesta bienal de culturas                    NaN
# 283                        Encuesta bienal de culturas                    NaN
# 284  DANE. Dato de 2013 actualizado del informe Tra...                    NaN
# 285                                    Transmilenio SA                    NaN
# 286                                    Transmilenio SA                    NaN
# 287                            Secretaría de Movilidad                    NaN
# 288                            Secretaría de Movilidad                    NaN
# 289                            Secretaría de Movilidad                    NaN
# 290                                    Transmilenio SA                    NaN
# 291                                    Transmilenio SA                    NaN
# 292                                    Transmilenio SA                    NaN
# 293                                    Transmilenio SA                    NaN
# 294                                                IDU                    NaN
# 295                                                IDU                    NaN
# 296                                                IDU                    NaN
# 297                                                IDU                    NaN
# 298                            Secretaría de Movilidad                    NaN
# 299                            Secretaría de Movilidad                    NaN
# 300                            Secretaría de Movilidad                    NaN
# 301                            Secretaría de Movilidad                    NaN
# 302                                                NaN  Desde 2005 hasta 2014
# 303                                                NaN                    NaN
# 304                                                NaN                    NaN
#
#                  unidad
# 0                   NaN
# 1             Hectáreas
# 2                    km
# 3                   NaN
# 4                   NaN
# 5                   NaN
# 6    Número de personas
# 7    Número de personas
# 8                   NaN
# 9                   NaN
# 10                  NaN
# 11                  NaN
# 12                  NaN
# 13                  NaN
# 14                  NaN
# 15                  NaN
# 16                  NaN
# 17                  NaN
# 18                  NaN
# 19                  NaN
# 20                  NaN
# 21                  NaN
# 22                  NaN
# 23                  NaN
# 24                  NaN
# 25                  NaN
# 26                  NaN
# 27                  NaN
# 28                  NaN
# 29                  NaN
# ..                  ...
# 275                 NaN
# 276                 NaN
# 277                 NaN
# 278                 NaN
# 279                 NaN
# 280                 NaN
# 281                 NaN
# 282                 NaN
# 283                 NaN
# 284                 NaN
# 285                 NaN
# 286                 NaN
# 287                 NaN
# 288                 NaN
# 289                 NaN
# 290                 NaN
# 291                 NaN
# 292                 NaN
# 293                 NaN
# 294                 NaN
# 295                 NaN
# 296                 NaN
# 297                 NaN
# 298                 NaN
# 299                 NaN
# 300                 NaN
# 301                 NaN
# 302                 Año
# 303                 NaN
# 304                 NaN
#
# [305 rows x 7 columns]

# %%
diccionario_subjetivos
# Out:
#               variable                                        descripcion  \
# 0                 CR1H  Cuando usted va a - Ferias generalmente paga o...
# 1               NUMERO                                             NUMERO
# 2                NSE_1                                                NSE
# 3               CIUDAD                                             CIUDAD
# 4          TIPO_ENTREV                                        TIPO_ENTREV
# 5     LOCALIDAD_COMUNA                                   LOCALIDAD_COMUNA
# 6               BARRIO                                             BARRIO
# 7                ZONAS                                              ZONAS
# 8                 SEXO                                               SEXO
# 9                 EDAD                                               EDAD
# 10                 PON                                                PON
# 11                 AÑO                                                AÑO
# 12     TIPO_TRANSPORTE                                    TIPO_TRANSPORTE
# 13                  F1                             Tipo de entrevistad(a)
# 14                  F2  Actualmente estamos realizando un estudio para...
# 15                F3_1  Para comenzar me gustaría saber si usted o alg...
# 16               F3A_1  Para comenzar me gustaría saber si usted o alg...
# 17               F3A_2  Para comenzar me gustaría saber si usted o alg...
# 18               F3A_3  Para comenzar me gustaría saber si usted o alg...
# 19                  F4                     ¿En qué empresa trabaja Usted?
# 20                  F5                           ¿Y cuál es su ocupación?
# 21                  F6  ¿Usted vive de forma permanente en [CIUDAD], o...
# 22             F6A_AOS              ¿Hace cuánto tiempo vive en [CIUDAD]?
# 23           F6A_MESES              ¿Hace cuánto tiempo vive en [CIUDAD]?
# 24            F6A_DIAS              ¿Hace cuánto tiempo vive en [CIUDAD]?
# 25                  F7  ¿Podría por favor decirme cuántos hogares hay ...
# 26                 F7A                                    ¿Usted vive en?
# 27                 F7B                Podría decirme si esta vivienda es:
# 28                  F9  De acuerdo a su cultura o rasgos físicos, ¿Ust...
# 29                 F12  Cuál de las siguientes opciones describe mejor...
# ...                ...                                                ...
# 1337            CC7D_4  De los temas que le voy a leer ¿qué tan import...
# 1338            CC7D_5  De los temas que le voy a leer ¿qué tan import...
# 1339            CC7E_1  De estos temas que le acabo de mencionar ¿cuál...
# 1340            CC7E_2  De estos temas que le acabo de mencionar ¿cuál...
# 1341            CC7E_3  De estos temas que le acabo de mencionar ¿cuál...
# 1342            CC7E_4  De estos temas que le acabo de mencionar ¿cuál...
# 1343            CC7E_5  De estos temas que le acabo de mencionar ¿cuál...
# 1344               CC7  ¿Sabe Usted que hay una Junta Administradora L...
# 1345               CC8  ¿Conoce Usted el trabajo desarrollado por la J...
# 1346               CC9  ¿Conoce usted o había escuchado [HABLAR] antes...
# 1347              CC9C  ¿Conoce usted o había escuchado [HABLAR] antes...
# 1348              CC9A  ¿Conoce usted o había escuchado [HABLAR] antes...
# 1349              CC10  ¿Cómo califica, en términos generales, la gest...
# 1350              CC13  ¿Sabe Usted que hay representantes en el Congr...
# 1351             CC13A  ¿Los representantes en el Congreso de la Repúb...
# 1352             CC13B  ¿Qué tan insatisfecho(a) o satisfecho(a) está ...
# 1353              CC14  Pensando en las elecciones que se celebran en ...
# 1354             CC15A  Ya para terminar, y solamente con propósitos e...
# 1355              CC16  ¿Cuál considera usted que debe ser la función ...
# 1356              CC23  ¿La imagen que Usted tiene del Concejo de [CIU...
# 1357        TOTALP6D_1                                                NaN
# 1358        TOTALP6D_2                                                NaN
# 1359        TOTALP6D_3                                                NaN
# 1360        TOTALP6D_4                                                NaN
# 1361        TOTALP6D_5                                                NaN
# 1362        TOTALP6D_6                                                NaN
# 1363        TOTALP6D_7                                                NaN
# 1364        TOTALP6D_8                                                NaN
# 1365      TOTALP6D_HOM                                                NaN
# 1366      TOTALP6D_MUJ                                                NaN
#
#                        dimension                         modulo  \
# 0     Buen Gobierno y Ciudadanía  Cultura, Recreación Y Deporte
# 1                            NaN                            NaN
# 2                            NaN                            NaN
# 3                            NaN                            NaN
# 4                            NaN                            NaN
# 5                          Extra          Módulo De Desigualdad
# 6                            NaN                            NaN
# 7                          Extra          Módulo De Desigualdad
# 8                            NaN                            NaN
# 9        Activos de las personas                      Educación
# 10                         Extra          Módulo De Desigualdad
# 11                           NaN                            NaN
# 12                           NaN                            NaN
# 13                           NaN                            NaN
# 14                           NaN                            NaN
# 15                           NaN                            NaN
# 16                           NaN                            NaN
# 17                           NaN                            NaN
# 18                           NaN                            NaN
# 19                           NaN                            NaN
# 20                           NaN                            NaN
# 21                           NaN                            NaN
# 22                           NaN                            NaN
# 23                           NaN                            NaN
# 24                           NaN                            NaN
# 25                           NaN                            NaN
# 26                           NaN                            NaN
# 27                           NaN                            NaN
# 28                           NaN                            NaN
# 29                           NaN                            NaN
# ...                          ...                            ...
# 1337  Buen Gobierno y Ciudadanía           Concejo De La Ciudad
# 1338  Buen Gobierno y Ciudadanía           Concejo De La Ciudad
# 1339  Buen Gobierno y Ciudadanía           Concejo De La Ciudad
# 1340  Buen Gobierno y Ciudadanía           Concejo De La Ciudad
# 1341  Buen Gobierno y Ciudadanía           Concejo De La Ciudad
# 1342  Buen Gobierno y Ciudadanía           Concejo De La Ciudad
# 1343  Buen Gobierno y Ciudadanía           Concejo De La Ciudad
# 1344  Buen Gobierno y Ciudadanía           Concejo De La Ciudad
# 1345  Buen Gobierno y Ciudadanía           Concejo De La Ciudad
# 1346  Buen Gobierno y Ciudadanía           Concejo De La Ciudad
# 1347  Buen Gobierno y Ciudadanía           Concejo De La Ciudad
# 1348  Buen Gobierno y Ciudadanía           Concejo De La Ciudad
# 1349  Buen Gobierno y Ciudadanía           Concejo De La Ciudad
# 1350  Buen Gobierno y Ciudadanía           Concejo De La Ciudad
# 1351  Buen Gobierno y Ciudadanía           Concejo De La Ciudad
# 1352  Buen Gobierno y Ciudadanía           Concejo De La Ciudad
# 1353  Buen Gobierno y Ciudadanía           Concejo De La Ciudad
# 1354  Buen Gobierno y Ciudadanía           Concejo De La Ciudad
# 1355  Buen Gobierno y Ciudadanía           Concejo De La Ciudad
# 1356  Buen Gobierno y Ciudadanía           Concejo De La Ciudad
# 1357                       Extra          Módulo De Desigualdad
# 1358                       Extra          Módulo De Desigualdad
# 1359                       Extra          Módulo De Desigualdad
# 1360                       Extra          Módulo De Desigualdad
# 1361                       Extra          Módulo De Desigualdad
# 1362                       Extra          Módulo De Desigualdad
# 1363                       Extra          Módulo De Desigualdad
# 1364                       Extra          Módulo De Desigualdad
# 1365                       Extra          Módulo De Desigualdad
# 1366                       Extra          Módulo De Desigualdad
#
#                                              respuestas tipo_respuestas  \
# 0     {'9': 'Visitar museos/ galerías/ bibliotecas[/...      categorica
# 1                                                   NaN             NaN
# 2     {'4': 'Estrato 4', '7': 'Rural', '5': 'Estrato...      categorica
# 3     {'54001': 'Cucuta', '66001': 'Pereira', '76892...      categorica
# 4     {'4': 'Transporte Informal', '1': 'Transporte ...      categorica
# 5     {'157': 'Villa Hermosa', '9': 'Fontibón', '158...      categorica
# 6                                                   NaN             NaN
# 7     {'9': 'Nororiental', '12': 'Histórica y del Ca...      categorica
# 8                   {'1': 'Masculino', '2': 'Femenino'}      categorica
# 9     {'4': 'De 46 a 55 años', '5': 'Más de 55 años'...      categorica
# 10    {'4': 'Nada importante', '92': 'No Sabe / No R...      categorica
# 11    {'2000': '2000', '2007': '2007', '2012': '2012...      categorica
# 12    {'4': 'Transporte Informal', '1': 'Transporte ...      categorica
# 13    {'1': '¿Podría por favor hablar con el jefe de...      categorica
# 14                               {'1': 'Sí', '2': 'No'}      categorica
# 15                               {'1': 'Si', '2': 'No'}      categorica
# 16                               {'1': 'Si', '2': 'No'}      categorica
# 17                               {'1': 'Si', '2': 'No'}      categorica
# 18                               {'1': 'Si', '2': 'No'}      categorica
# 19    {'4': 'Por ser mujer (ENC: VALIDE POR SEXO)', ...      categorica
# 20                                                  NaN             NaN
# 21    {'1': 'Vive en [CIUDAD]', '2': 'Está en la ciu...      categorica
# 22                                                  NaN             NaN
# 23                                                  NaN             NaN
# 24                                                  NaN             NaN
# 25    {'4': 'En usufructo', '5': 'Ocupante de hecho'...      categorica
# 26    {'4': 'Apartamento Conjunto Cerrado', '1': 'Ca...      categorica
# 27    {'4': 'En usufructo', '5': 'Ocupante de hecho'...      categorica
# 28    {'4': 'Afrodescendiente', '5': 'Raizal de San ...      categorica
# 29    {'4': '\tHija/Hijo de la familia', '5': 'Abuel...      categorica
# ...                                                 ...             ...
# 1337  {'4': '4', '5': 'Muy importante', '2': '2', '9...      categorica
# 1338  {'4': '4', '5': 'Muy importante', '2': '2', '9...      categorica
# 1339  {'92': 'No Sabe / No Responde', '1': 'Si', '2'...      categorica
# 1340  {'92': 'No Sabe / No Responde', '1': 'Si', '2'...      categorica
# 1341  {'92': 'No Sabe / No Responde', '1': 'Si', '2'...      categorica
# 1342  {'92': 'No Sabe / No Responde', '1': 'Si', '2'...      categorica
# 1343  {'92': 'No Sabe / No Responde', '1': 'Si', '2'...      categorica
# 1344  {'92': 'No Sabe / No Responde', '1': 'Sí sabe'...      categorica
# 1345  {'92': 'No Sabe / No Responde', '1': 'Sí lo co...      categorica
# 1346  {'92': 'No Sabe / No Responde', '1': 'Sí', '2'...      categorica
# 1347  {'90': 'Ninguno', '1': 'Ciudad Cómo Vamos', '2...      categorica
# 1348  {'90': 'Ninguno', '1': 'Ciudad Cómo Vamos', '2...      categorica
# 1349  {'9': 'Cámara de comercio', '95': 'Todos', '2'...      categorica
# 1350  {'92': 'No Sabe / No Responde', '1': 'Si', '2'...      categorica
# 1351  {'92': 'No Sabe / No Responde', '1': 'Sí están...      categorica
# 1352  {'4': '4', '5': 'Muy satisfecho', '1': 'Muy in...      categorica
# 1353  {'4': 'No voto nunca', '2': 'En la mayoría', '...      categorica
# 1354  {'4': 'Presidente de la republica', '7': 'Conc...      categorica
# 1355  {'4': '\tSeñalar los sectores, comunidades o t...      categorica
# 1356  {'4': 'El programa que busca reducir el tiempo...      categorica
# 1357                                                NaN             NaN
# 1358                                                NaN             NaN
# 1359                                                NaN             NaN
# 1360                                                NaN             NaN
# 1361                                                NaN             NaN
# 1362                                                NaN             NaN
# 1363                                                NaN             NaN
# 1364                                                NaN             NaN
# 1365                                                NaN             NaN
# 1366                                                NaN             NaN
#
#      ano_min ano_max
# 0       2013    2013
# 1       1998    2014
# 2       1998    2014
# 3       1998    2014
# 4       2008    2013
# 5       1998    2014
# 6       2002    2014
# 7       1998    2014
# 8       1998    2014
# 9       1998    2014
# 10      1998    2014
# 11       AÑO     AÑO
# 12      2011    2014
# 13      2008    2014
# 14      2008    2014
# 15      2008    2014
# 16      2001    2007
# 17      2001    2007
# 18      2001    2007
# 19      2004    2014
# 20      2004    2014
# 21      2000    2014
# 22      2002    2014
# 23      2004    2014
# 24      2004    2007
# 25      2004    2014
# 26      2004    2007
# 27      2004    2004
# 28      2005    2013
# 29      2004    2007
# ...      ...     ...
# 1337    2002    2002
# 1338    2002    2002
# 1339    2002    2002
# 1340    2002    2002
# 1341    2002    2002
# 1342    2002    2002
# 1343    2002    2002
# 1344    2009    2014
# 1345    2009    2014
# 1346    2013    2014
# 1347    2005    2007
# 1348    2005    2007
# 1349    2005    2007
# 1350    2008    2010
# 1351    2008    2010
# 1352    2008    2008
# 1353    2004    2006
# 1354    2005    2006
# 1355    2004    2006
# 1356    2000    2000
# 1357    2005    2005
# 1358    2005    2005
# 1359    2005    2005
# 1360    2005    2005
# 1361    2005    2005
# 1362    2005    2005
# 1363    2005    2005
# 1364    2005    2005
# 1365    2005    2005
# 1366    2005    2005
#
# [1367 rows x 8 columns]

# %%
diccionario_objetivos.anillo.unique()
# Out:
# array(['Escenarios Transversales', 'Activos de las personas',
#        'Hábitat Urbano', nan], dtype=object)

# %%
diccionario_subjetivos.dimension.unique()
# Out:
# array(['Buen Gobierno y Ciudadanía', nan, 'Extra',
#        'Activos de las personas', 'Optimismo y bienestar subjetivo',
#        'Hábitat Urbano'], dtype=object)

# %%
anillos = list(diccionario_objetivos.anillo.unique())
for anillo_extra in list(diccionario_subjetivos.dimension.unique()):
    if anillo_extra not in anillos:
        anillos.append(anillo_extra)

# %%
diccionario = {}

# %%
ciudad = "saltillo"
wat = "watwat"
diccionario[ciudad][wat] = "0"
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-37-c5634380ba68> in <module>()
#       1 ciudad = "saltillo"
#       2 wat = "watwat"
# ----> 3 diccionario[ciudad][wat] = "0"
#
# KeyError: 'saltillo'

# %%
diccionario[ciudad] = {}
diccionario[ciudad][wat] = {}

# %%
anillos
# Out:
# ['Escenarios Transversales',
#  'Activos de las personas',
#  'Hábitat Urbano',
#  nan,
#  'Buen Gobierno y Ciudadanía',
#  'Extra',
#  'Optimismo y bienestar subjetivo']

# %%
for ring in anillos: diccionario[ciudad][ring] = {}

# %%
diccionario[ciudad]
# Out:
# {nan: {},
#  'Buen Gobierno y Ciudadanía': {},
#  'watwat': {},
#  'Escenarios Transversales': {},
#  'Optimismo y bienestar subjetivo': {},
#  'Extra': {},
#  'Activos de las personas': {},
#  'Hábitat Urbano': {}}

# %%
for indicadores in diccionario_objetivos.iterrows():
    print(indicadores)
# Out:
# (0, id                                      0-PO-1
# Indicador    Indice de Envejecimiento Hombres
# anillo                Escenarios Transversales
# tema                    Población y Demografía
# fuente                                    DANE
# notas                                      NaN
# unidad                                     NaN
# Name: 0, dtype: object)
# (1, id                                         0-PO-12
# Indicador    Extensión territorial área hectáreas
# anillo                    Escenarios Transversales
# tema                        Población y Demografía
# fuente          Secretaría Distrital de planeación
# notas                                          NaN
# unidad                                   Hectáreas
# Name: 1, dtype: object)
# (2, id                                      0-PO-13
# Indicador       Extensión territorial área km2
# anillo                 Escenarios Transversales
# tema                     Población y Demografía
# fuente       Secretaría Distrital de planeación
# notas                                       NaN
# unidad                                       km
# Name: 2, dtype: object)
# (3, id                            0-PO-14
# Indicador    Indice de envejecimiento
# anillo       Escenarios Transversales
# tema           Población y Demografía
# fuente                           DANE
# notas                             NaN
# unidad                            NaN
# Name: 3, dtype: object)
# (4, id                                      0-PO-2
# Indicador    Indice de Envejecimiento Mujeres
# anillo                Escenarios Transversales
# tema                    Población y Demografía
# fuente                                    DANE
# notas                                      NaN
# unidad                                     NaN
# Name: 4, dtype: object)
# (5, id                            0-PO-23
# Indicador           Población Hombres
# anillo       Escenarios Transversales
# tema           Población y Demografía
# fuente                           DANE
# notas                             NaN
# unidad                            NaN
# Name: 5, dtype: object)
# (6, id                            0-PO-25
# Indicador           Población Mujeres
# anillo       Escenarios Transversales
# tema           Población y Demografía
# fuente                           DANE
# notas                             NaN
# unidad             Número de personas
# Name: 6, dtype: object)
# (7, id                            0-PO-27
# Indicador             Población Total
# anillo       Escenarios Transversales
# tema           Población y Demografía
# fuente                           DANE
# notas                             NaN
# unidad             Número de personas
# Name: 7, dtype: object)
# (8, id                                              0-PO-28
# Indicador    Porcentaje de Población Afrodescendientes
# anillo                         Escenarios Transversales
# tema                             Población y Demografía
# fuente                                             DANE
# notas                                               NaN
# unidad                                              NaN
# Name: 8, dtype: object)
# (9, id                                             0-PO-29
# Indicador    Porcentaje de población en el área Urbana
# anillo                        Escenarios Transversales
# tema                            Población y Demografía
# fuente                                            DANE
# notas                                              NaN
# unidad                                             NaN
# Name: 9, dtype: object)
# (10, id                                       0-PO-3
# Indicador          Densidad poblacional por Km
# anillo                 Escenarios Transversales
# tema                     Población y Demografía
# fuente       Secretaría Distrital de planeación
# notas                                       NaN
# unidad                                      NaN
# Name: 10, dtype: object)
# (11, id                                     0-PO-30
# Indicador    Porcentaje de Población Indígena
# anillo                Escenarios Transversales
# tema                    Población y Demografía
# fuente                                    DANE
# notas                                      NaN
# unidad                                     NaN
# Name: 11, dtype: object)
# (12, id                            0-PO-34
# Indicador     Relación de Dependencia
# anillo       Escenarios Transversales
# tema           Población y Demografía
# fuente                           DANE
# notas                             NaN
# unidad                            NaN
# Name: 12, dtype: object)
# (13, id                                       0-PO-36
# Indicador    Tasa de crecimiento de la población
# anillo                  Escenarios Transversales
# tema                      Población y Demografía
# fuente                                      DANE
# notas                                        NaN
# unidad                                       NaN
# Name: 13, dtype: object)
# (14, id                               0-PO-37
# Indicador    Tasa de Dependencia Hombres
# anillo          Escenarios Transversales
# tema              Población y Demografía
# fuente                              DANE
# notas                                NaN
# unidad                               NaN
# Name: 14, dtype: object)
# (15, id                                0-PO-38
# Indicador    Tasa de Dependencia Mujeres
# anillo           Escenarios Transversales
# tema               Población y Demografía
# fuente                               DANE
# notas                                 NaN
# unidad                                NaN
# Name: 15, dtype: object)
# (16, id                                                      0-PO-4
# Indicador    El lugar donde habita es propio con permiso de...
# anillo                                Escenarios Transversales
# tema                                    Población y Demografía
# fuente                                                    DANE
# notas                                                      NaN
# unidad                                                     NaN
# Name: 16, dtype: object)
# (17, id                                                      0-PO-5
# Indicador    El lugar donde habita es propio y se esta paga...
# anillo                                Escenarios Transversales
# tema                                    Población y Demografía
# fuente                                                    DANE
# notas                                                      NaN
# unidad                                                     NaN
# Name: 17, dtype: object)
# (18, id                                             0-PO-6
# Indicador    El lugar en donde habita es en arriendo
# anillo                       Escenarios Transversales
# tema                           Población y Demografía
# fuente                                           DANE
# notas                                             NaN
# unidad                                            NaN
# Name: 18, dtype: object)
# (19, id                                                      0-PO-7
# Indicador    El lugar en donde habita es propio totalmente ...
# anillo                                Escenarios Transversales
# tema                                    Población y Demografía
# fuente                                                    DANE
# notas                                                      NaN
# unidad                                                     NaN
# Name: 19, dtype: object)
# (20, id                                0-PO-8
# Indicador    Esperanza de vida al nacer
# anillo          Escenarios Transversales
# tema              Población y Demografía
# fuente                              DANE
# notas                                NaN
# unidad                               NaN
# Name: 20, dtype: object)
# (21, id                                        0-PO-9
# Indicador    Esperanza de vida al nacer Mujeres
# anillo                  Escenarios Transversales
# tema                      Población y Demografía
# fuente                                      DANE
# notas                                        NaN
# unidad                                       NaN
# Name: 21, dtype: object)
# (22, id                                      0-PD-11
# Indicador    Índice de condiciones de vida ICV
# anillo                 Escenarios Transversales
# tema                      Pobreza y desigualdad
# fuente                  Encuesta Multipropósito
# notas                                       NaN
# unidad                                      NaN
# Name: 22, dtype: object)
# (23, id                                      0-PD-16
# Indicador    Índice de Desarrollo Humano Urbano
# anillo                 Escenarios Transversales
# tema                      Pobreza y desigualdad
# fuente                  Encuesta Multipropósito
# notas                                       NaN
# unidad                                      NaN
# Name: 23, dtype: object)
# (24, id                                       0-PD-17
# Indicador    Índice de Pobreza Multidimensional
# anillo                  Escenarios Transversales
# tema                       Pobreza y desigualdad
# fuente                                      DANE
# notas                                        NaN
# unidad                                       NaN
# Name: 24, dtype: object)
# (25, id                                                     0-PD-18
# Indicador    Índice de Pobreza Multidimensional Multipropós...
# anillo                                Escenarios Transversales
# tema                                     Pobreza y desigualdad
# fuente                                                    DANE
# notas                                                      NaN
# unidad                                                     NaN
# Name: 25, dtype: object)
# (26, id                                          0-PD-21
# Indicador    Población bajo la línea de indigencia
# anillo                     Escenarios Transversales
# tema                          Pobreza y desigualdad
# fuente                                         DANE
# notas                                           NaN
# unidad                                          NaN
# Name: 26, dtype: object)
# (27, id                                               0-PD-22
# Indicador    Población bajo la línea de indigencia 13 AM
# anillo                          Escenarios Transversales
# tema                               Pobreza y desigualdad
# fuente                                              DANE
# notas                                                NaN
# unidad                                               NaN
# Name: 27, dtype: object)
# (28, id                                              0-PD-23
# Indicador    Población bajo la línea de indigencia GEIH
# anillo                         Escenarios Transversales
# tema                              Pobreza y desigualdad
# fuente                                             DANE
# notas                                               NaN
# unidad                                              NaN
# Name: 28, dtype: object)
# (29, id                                       0-PD-24
# Indicador    Población bajo la línea de pobreza
# anillo                  Escenarios Transversales
# tema                       Pobreza y desigualdad
# fuente                                      DANE
# notas                                        NaN
# unidad                                       NaN
# Name: 29, dtype: object)
# (30, id                                            0-PD-25
# Indicador    Población bajo la línea de pobreza 13 AM
# anillo                       Escenarios Transversales
# tema                            Pobreza y desigualdad
# fuente                                           DANE
# notas                                             NaN
# unidad                                            NaN
# Name: 30, dtype: object)
# (31, id                                           0-PD-26
# Indicador    Población bajo la línea de pobreza GEIH
# anillo                      Escenarios Transversales
# tema                           Pobreza y desigualdad
# fuente                                          DANE
# notas                                            NaN
# unidad                                           NaN
# Name: 31, dtype: object)
# (32, id                                                     0-PD-27
# Indicador    Porcentaje de familias promovidas en el progra...
# anillo                                Escenarios Transversales
# tema                                     Pobreza y desigualdad
# fuente                                                     DPS
# notas                                                      NaN
# unidad                                                     NaN
# Name: 32, dtype: object)
# (33, id                                              0-PD-3
# Indicador    Coeficiente de Gini Bogotá Multipróposito
# anillo                        Escenarios Transversales
# tema                             Pobreza y desigualdad
# fuente                         Encuesta Multipropósito
# notas                                              NaN
# unidad                                             NaN
# Name: 33, dtype: object)
# (34, id                                         0-PD-32
# Indicador    Tasa de cobertura del programa Unidos
# anillo                    Escenarios Transversales
# tema                         Pobreza y desigualdad
# fuente                                         DPS
# notas                                          NaN
# unidad                                         NaN
# Name: 34, dtype: object)
# (35, id                            0-PD-33
# Indicador    Tasa de trabajo infantil
# anillo       Escenarios Transversales
# tema            Pobreza y desigualdad
# fuente                           DANE
# notas                             NaN
# unidad                            NaN
# Name: 35, dtype: object)
# (36, id                                     0-PD-34
# Indicador    Tasa de trabajo infantil ampliado
# anillo                Escenarios Transversales
# tema                     Pobreza y desigualdad
# fuente                                    DANE
# notas                                      NaN
# unidad                                     NaN
# Name: 36, dtype: object)
# (37, id                                                     0-PD-37
# Indicador    Variación porcentual en el Ingreso promedio de...
# anillo                                Escenarios Transversales
# tema                                     Pobreza y desigualdad
# fuente                                                    DANE
# notas                                                      NaN
# unidad                                                     NaN
# Name: 37, dtype: object)
# (38, id                                        0-PD-4
# Indicador    coeficiente de Gini de los ingresos
# anillo                  Escenarios Transversales
# tema                       Pobreza y desigualdad
# fuente                                      DANE
# notas                                        NaN
# unidad                                       NaN
# Name: 38, dtype: object)
# (39, id                                                     0-PD-5
# Indicador    El lugar donde habita es en tenencia o posesión
# anillo                               Escenarios Transversales
# tema                                    Pobreza y desigualdad
# fuente                                                   DANE
# notas                                                     NaN
# unidad                                                    NaN
# Name: 39, dtype: object)
# (40, id                                 0-PD-6
# Indicador    Incidencia pobreza monetaria
# anillo           Escenarios Transversales
# tema                Pobreza y desigualdad
# fuente                               DANE
# notas                                 NaN
# unidad                                NaN
# Name: 40, dtype: object)
# (41, id                                         0-PD-7
# Indicador    Incidencia pobreza monetaria extrema
# anillo                   Escenarios Transversales
# tema                        Pobreza y desigualdad
# fuente                                       DANE
# notas                                         NaN
# unidad                                        NaN
# Name: 41, dtype: object)
# (42, id                                                    1-SA-100
# Indicador    Porcentaje de desnutrición crónica en menores ...
# anillo                                 Activos de las personas
# tema                                                     Salud
# fuente                     Secretarías de Salud de cada ciudad
# notas                                                      NaN
# unidad                                                     NaN
# Name: 42, dtype: object)
# (43, id                                                    1-SA-105
# Indicador    Porcentaje de nacimientos en adolescentes de 1...
# anillo                                 Activos de las personas
# tema                                                     Salud
# fuente                                                    DANE
# notas                                                      NaN
# unidad                                                     NaN
# Name: 43, dtype: object)
# (44, id                                                    1-SA-108
# Indicador    Porcentaje de personas vinculadas pero no afil...
# anillo                                 Activos de las personas
# tema                                                     Salud
# fuente                    Base de datos SISBÉN certificada DNP
# notas                                                      NaN
# unidad                                                     NaN
# Name: 44, dtype: object)
# (45, id                                                    1-SA-111
# Indicador    Porcentaje de población que requirió el servic...
# anillo                                 Activos de las personas
# tema                                                     Salud
# fuente                                                 EPC-MCV
# notas                                                      NaN
# unidad                                                     NaN
# Name: 45, dtype: object)
# (46, id                                    1-SA-115
# Indicador    Prevalencia de bajo peso al nacer
# anillo                 Activos de las personas
# tema                                     Salud
# fuente                                    DANE
# notas                                      NaN
# unidad                                     NaN
# Name: 46, dtype: object)
# (47, id                                            1-SA-145
# Indicador    Razón de mortalidad materna x 100.000 NV
# anillo                         Activos de las personas
# tema                                             Salud
# fuente                             Secretaría de Salud
# notas                                              NaN
# unidad                                             NaN
# Name: 47, dtype: object)
# (48, id                                                    1-SA-168
# Indicador    Tasa de  (AVPP) por afecciones del periodo neo...
# anillo                                 Activos de las personas
# tema                                                     Salud
# fuente                                     Secretaría de Salud
# notas                                                      NaN
# unidad                                                     NaN
# Name: 48, dtype: object)
# (49, id                                       1-SA-169
# Indicador    Tasa de  (AVPP) por causas externas.
# anillo                    Activos de las personas
# tema                                        Salud
# fuente                        Secretaría de Salud
# notas                                         NaN
# unidad                                        NaN
# Name: 49, dtype: object)
# (50, id                                                     1-SA-17
# Indicador    Cinco primeras causas de morbilidad atendida e...
# anillo                                 Activos de las personas
# tema                                                     Salud
# fuente                                     Secretaría de Salud
# notas                                                      NaN
# unidad                                                     NaN
# Name: 50, dtype: object)
# (51, id                                                    1-SA-170
# Indicador    Tasa de  (AVPP) por enfermedades del sistema c...
# anillo                                 Activos de las personas
# tema                                                     Salud
# fuente                                     Secretaría de Salud
# notas                                                      NaN
# unidad                                                     NaN
# Name: 51, dtype: object)
# (52, id                                                 1-SA-171
# Indicador    Tasa de  (AVPP) por enfermedades Transmisibles
# anillo                              Activos de las personas
# tema                                                  Salud
# fuente                                  Secretaría de Salud
# notas                                                   NaN
# unidad                                                  NaN
# Name: 52, dtype: object)
# (53, id                                 1-SA-172
# Indicador    Tasa de  (AVPP) por neoplasias
# anillo              Activos de las personas
# tema                                  Salud
# fuente                  Secretaría de Salud
# notas                                   NaN
# unidad                                  NaN
# Name: 53, dtype: object)
# (54, id                                                    1-SA-173
# Indicador    Tasa de desnutrición global para menores de 5 ...
# anillo                                 Activos de las personas
# tema                                                     Salud
# fuente       Sistema de vigilancia epidemiológica alimentar...
# notas                                                      NaN
# unidad                                                     NaN
# Name: 54, dtype: object)
# (55, id                                                     1-SA-18
# Indicador    Cinco primeras causas de morbilidad atendida e...
# anillo                                 Activos de las personas
# tema                                                     Salud
# fuente                                     Secretaría de Salud
# notas                                                      NaN
# unidad                                                     NaN
# Name: 55, dtype: object)
# (56, id                                         1-SA-181
# Indicador    Tasa de mortalidad en menores de 1 año
# anillo                      Activos de las personas
# tema                                          Salud
# fuente                                         DANE
# notas                                           NaN
# unidad                                          NaN
# Name: 56, dtype: object)
# (57, id                                          1-SA-182
# Indicador    Tasa de mortalidad en menores de 5 años
# anillo                       Activos de las personas
# tema                                           Salud
# fuente                                          DANE
# notas                                            NaN
# unidad                                           NaN
# Name: 57, dtype: object)
# (58, id                             1-SA-183
# Indicador    Tasa de mortalidad general
# anillo          Activos de las personas
# tema                              Salud
# fuente                             DANE
# notas                               NaN
# unidad                              NaN
# Name: 58, dtype: object)
# (59, id                                                  1-SA-184
# Indicador    Tasa de mortalidad infantil (menores de un año)
# anillo                               Activos de las personas
# tema                                                   Salud
# fuente                         Secretaría Distrital de Salud
# notas                                                    NaN
# unidad                                                   NaN
# Name: 59, dtype: object)
# (60, id                                                    1-SA-185
# Indicador                           Tasa de mortalidad materna
# anillo                                 Activos de las personas
# tema                                                     Salud
# fuente                                                    DANE
# notas        Número de madres muertas / total Nacidos vivos...
# unidad                                                     NaN
# Name: 60, dtype: object)
# (61, id                                                    1-SA-187
# Indicador    Tasa de mortalidad perinatal por 1.000 nacidos...
# anillo                                 Activos de las personas
# tema                                                     Salud
# fuente                                                    DANE
# notas                                                      NaN
# unidad                                                     NaN
# Name: 61, dtype: object)
# (62, id                                                    1-SA-188
# Indicador    Tasa de mortalidad por cáncer de cuello uterin...
# anillo                                 Activos de las personas
# tema                                                     Salud
# fuente                                     Secretaría de salud
# notas                                                      NaN
# unidad                                                     NaN
# Name: 62, dtype: object)
# (63, id                                                    1-SA-189
# Indicador    Tasa de mortalidad por desnutrición en menores...
# anillo                                 Activos de las personas
# tema                                                     Salud
# fuente                           Secretaría Distrital de Salud
# notas                                                      NaN
# unidad                                                     NaN
# Name: 63, dtype: object)
# (64, id                                          1-SA-19
# Indicador    Cinco principales causas de mortalidad
# anillo                      Activos de las personas
# tema                                          Salud
# fuente                                         DANE
# notas                                           NaN
# unidad                                          NaN
# Name: 64, dtype: object)
# (65, id                                                    1-SA-199
# Indicador    Tasa de mortalidad por neumonía por 100.000 me...
# anillo                                 Activos de las personas
# tema                                                     Salud
# fuente                           Secretaría Distrital de Salud
# notas                                                      NaN
# unidad                                                     NaN
# Name: 65, dtype: object)
# (66, id                                     1-SA-20
# Indicador    Cobertura al régimen contributivo
# anillo                 Activos de las personas
# tema                                     Salud
# fuente                                      ND
# notas                                      NaN
# unidad                                     NaN
# Name: 66, dtype: object)
# (67, id                                  1-SA-21
# Indicador    Cobertura al régimen especial
# anillo              Activos de las personas
# tema                                  Salud
# fuente                                  NaN
# notas                                   NaN
# unidad                                  NaN
# Name: 67, dtype: object)
# (68, id                                                     1-SA-22
# Indicador    Cobertura de población afiliada al régimen sub...
# anillo                                 Activos de las personas
# tema                                                     Salud
# fuente                                                    DANE
# notas                                                      NaN
# unidad                                                     NaN
# Name: 68, dtype: object)
# (69, id                                                     1-SA-24
# Indicador    Cobertura de vacunación con anti influenzae ti...
# anillo                                 Activos de las personas
# tema                                                     Salud
# fuente       DIRECCIÓN DE SALUD PÚBLICA - ÁREA VIGILANCIA E...
# notas                                                      NaN
# unidad                                                     NaN
# Name: 69, dtype: object)
# (70, id                                                     1-SA-25
# Indicador    Cobertura de vacunación con antipolio en menor...
# anillo                                 Activos de las personas
# tema                                                     Salud
# fuente       DIRECCIÓN DE SALUD PÚBLICA - ÁREA VIGILANCIA E...
# notas                                                      NaN
# unidad                                                     NaN
# Name: 70, dtype: object)
# (71, id                                                     1-SA-26
# Indicador    Cobertura de vacunación con BCG en niños menor...
# anillo                                 Activos de las personas
# tema                                                     Salud
# fuente       DIRECCIÓN DE SALUD PÚBLICA - ÁREA VIGILANCIA E...
# notas                                                      NaN
# unidad                                                     NaN
# Name: 71, dtype: object)
# (72, id                                                     1-SA-27
# Indicador    Cobertura de vacunación contra fiebre amarilla...
# anillo                                 Activos de las personas
# tema                                                     Salud
# fuente       DIRECCIÓN DE SALUD PÚBLICA - ÁREA VIGILANCIA E...
# notas                                                      NaN
# unidad                                                     NaN
# Name: 72, dtype: object)
# (73, id                                                     1-SA-28
# Indicador    Cobertura de vacunación contra hepatitis B en ...
# anillo                                 Activos de las personas
# tema                                                     Salud
# fuente       DIRECCION DE SALUD PUBLICA - AREA VIGILANCIA E...
# notas                                                      NaN
# unidad                                                     NaN
# Name: 73, dtype: object)
# (74, id                                     1-SA-29
# Indicador          Cobertura de vacunación DPT
# anillo                 Activos de las personas
# tema                                     Salud
# fuente       Secretaría Distrital de salud-PAI
# notas                                      NaN
# unidad                                     NaN
# Name: 74, dtype: object)
# (75, id                                              1-SA-35
# Indicador    Cobertura de vacunación triple viral (T.V)
# anillo                          Activos de las personas
# tema                                              Salud
# fuente                Secretaría Distrital de salud-PAI
# notas                                               NaN
# unidad                                              NaN
# Name: 75, dtype: object)
# (76, id                              1-SA-36
# Indicador    Cobertura en aseguramiento
# anillo          Activos de las personas
# tema                              Salud
# fuente              Ministerio de Salud
# notas                               NaN
# unidad                              NaN
# Name: 76, dtype: object)
# (77, id                                                     1-SA-38
# Indicador    Cobertura en vacunación  DTP tercera dosis (me...
# anillo                                 Activos de las personas
# tema                                                     Salud
# fuente                                     Ministerio de Salud
# notas                                                      NaN
# unidad                                                     NaN
# Name: 77, dtype: object)
# (78, id                                       1-SA-39
# Indicador    Cobertura en vacunación TV (un año)
# anillo                   Activos de las personas
# tema                                       Salud
# fuente                       Ministerio de Salud
# notas                                        NaN
# unidad                                       NaN
# Name: 78, dtype: object)
# (79, id                                                     1-SA-43
# Indicador    Cobertura en vacunación, en menores de un año ...
# anillo                                 Activos de las personas
# tema                                                     Salud
# fuente                                     Secretaría de Salud
# notas                                HEPATITIS B (MENOR 1 AÑO)
# unidad                                              Porcentaje
# Name: 79, dtype: object)
# (80, id                                      1-SA-47
# Indicador    Consumo de sustancias psicoactivas
# anillo                  Activos de las personas
# tema                                      Salud
# fuente                      Secretaría de salud
# notas                                       NaN
# unidad                                      NaN
# Name: 80, dtype: object)
# (81, id                                                 1-SA-5
# Indicador    Camas hospitalarias por cada 1000 habitantes
# anillo                            Activos de las personas
# tema                                                Salud
# fuente                                Secretaría de salud
# notas                                                 NaN
# unidad                                                NaN
# Name: 81, dtype: object)
# (82, id                                    1-SA-63
# Indicador    Incidencia del VIH * 100,000 hab
# anillo                Activos de las personas
# tema                                    Salud
# fuente                    Secretaría de salud
# notas                                     NaN
# unidad                                    NaN
# Name: 82, dtype: object)
# (83, id                                                     1-SA-65
# Indicador    La Tasa de Morbilidad por Enfermedad Diarreica...
# anillo                                 Activos de las personas
# tema                                                     Salud
# fuente                                                    DANE
# notas                                                      NaN
# unidad                                                     NaN
# Name: 83, dtype: object)
# (84, id                                                     1-SA-66
# Indicador                        Mediana de lactancia materna
# anillo                                 Activos de las personas
# tema                                                     Salud
# fuente       Sistema de vigilancia epidemiológica alimentar...
# notas                                                      NaN
# unidad                                                     NaN
# Name: 84, dtype: object)
# (85, id                                                   1-SA-67
# Indicador    Mortalidad por cáncer de mama (número de casos)
# anillo                               Activos de las personas
# tema                                                   Salud
# fuente                                   Secretaría de salud
# notas                                                    NaN
# unidad                                                   NaN
# Name: 85, dtype: object)
# (86, id                                             1-SA-77
# Indicador    N de ambulancias habilitadas en la ciudad
# anillo                         Activos de las personas
# tema                                             Salud
# fuente                             Secretaría de salud
# notas                                              NaN
# unidad                                             NaN
# Name: 86, dtype: object)
# (87, id                                               1-SA-82
# Indicador    Nacimientos en adolescentes de 10 a 14 años
# anillo                           Activos de las personas
# tema                                               Salud
# fuente                                              DANE
# notas                                                NaN
# unidad                                               NaN
# Name: 87, dtype: object)
# (88, id                                                1-SA-83
# Indicador    Nacimientos en adolescentes de 15 a 19 años
# anillo                            Activos de las personas
# tema                                                Salud
# fuente                                               DANE
# notas                                                 NaN
# unidad                                                NaN
# Name: 88, dtype: object)
# (89, id                                                     1-SA-90
# Indicador    Número de personas afiliadas al régimen subsid...
# anillo                                 Activos de las personas
# tema                                                     Salud
# fuente                                                    DANE
# notas                                                      NaN
# unidad                                                     NaN
# Name: 89, dtype: object)
# (90, id                                                     1-ED-11
# Indicador    Años promedio de educación población de 15 a 2...
# anillo                                 Activos de las personas
# tema                                                 Educación
# fuente                                                    DANE
# notas                                                      NaN
# unidad                                                     NaN
# Name: 90, dtype: object)
# (91, id                                                     1-ED-12
# Indicador    Cobertura neta en educación inicial (prejardin...
# anillo                                 Activos de las personas
# tema                                                 Educación
# fuente                Secretarías de educación de cada ciudad
# notas                                                      NaN
# unidad                                                     NaN
# Name: 91, dtype: object)
# (92, id                                                    1-ED-124
# Indicador                           resultados prueba saber 11
# anillo                                 Activos de las personas
# tema                                                 Educación
# fuente       Secretaria de educacion municipal de cada ciudad.
# notas                                                      NaN
# unidad                                                     NaN
# Name: 92, dtype: object)
# (93, id                                                    1-ED-131
# Indicador    Tasa  de Deserción para el Sector Privado Pree...
# anillo                                 Activos de las personas
# tema                                                 Educación
# fuente                                 Secretaría de Educación
# notas                                                      NaN
# unidad                                                     NaN
# Name: 93, dtype: object)
# (94, id                                                    1-ED-132
# Indicador    Tasa  de Deserción para el Sector Privado Prim...
# anillo                                 Activos de las personas
# tema                                                 Educación
# fuente                                 Secretaría de Educación
# notas                                                      NaN
# unidad                                                     NaN
# Name: 94, dtype: object)
# (95, id                                                    1-ED-133
# Indicador    Tasa  de Deserción para el Sector Privado Secu...
# anillo                                 Activos de las personas
# tema                                                 Educación
# fuente                                 Secretaría de Educación
# notas                                                      NaN
# unidad                                                     NaN
# Name: 95, dtype: object)
# (96, id                                              1-ED-134
# Indicador    Tasa bruta de cobertura en media vocacional
# anillo                           Activos de las personas
# tema                                           Educación
# fuente           Secretarías de educación de cada ciudad
# notas                                                NaN
# unidad                                               NaN
# Name: 96, dtype: object)
# (97, id                                                    1-ED-135
# Indicador          Tasa bruta de cobertura Preescolar (5 años)
# anillo                                 Activos de las personas
# tema                                                 Educación
# fuente       Secretarías de educación de cada ciudad - Dato...
# notas                                                      NaN
# unidad                                                     NaN
# Name: 97, dtype: object)
# (98, id                                        1-ED-136
# Indicador    Tasa de analfabetismo de 15 a 24 años
# anillo                     Activos de las personas
# tema                                     Educación
# fuente                                        DANE
# notas                                          NaN
# unidad                                         NaN
# Name: 98, dtype: object)
# (99, id                                                    1-ED-140
# Indicador                     Tasa de aprobación oficial media
# anillo                                 Activos de las personas
# tema                                                 Educación
# fuente       C-600 año 2013.Cálculo: Oficina Asesora de Pla...
# notas                                                      NaN
# unidad                                                     NaN
# Name: 99, dtype: object)
# (100, id                                                    1-ED-141
# Indicador               Tasa de aprobación oficial preescolar
# anillo                                 Activos de las personas
# tema                                                 Educación
# fuente       C-600 año 2013.Cálculo: Oficina Asesora de Pla...
# notas                                                      NaN
# unidad                                                     NaN
# Name: 100, dtype: object)
# (101, id                                                    1-ED-142
# Indicador                 Tasa de aprobación oficial primaria
# anillo                                 Activos de las personas
# tema                                                 Educación
# fuente       C-600 año 2013.Cálculo: Oficina Asesora de Pla...
# notas                                                      NaN
# unidad                                                     NaN
# Name: 101, dtype: object)
# (102, id                                                    1-ED-143
# Indicador               Tasa de aprobación oficial secundaria
# anillo                                 Activos de las personas
# tema                                                 Educación
# fuente       C-600 año 2013.Cálculo: Oficina Asesora de Pla...
# notas                                                      NaN
# unidad                                                     NaN
# Name: 102, dtype: object)
# (103, id                                                    1-ED-144
# Indicador                    Tasa de aprobación oficial total
# anillo                                 Activos de las personas
# tema                                                 Educación
# fuente       C-600 año 2013.Cálculo: Oficina Asesora de Pla...
# notas                                                      NaN
# unidad                                                     NaN
# Name: 103, dtype: object)
# (104, id                                                    1-ED-145
# Indicador    Tasa de Aprobación para el Sector Privado nive...
# anillo                                 Activos de las personas
# tema                                                 Educación
# fuente                                 Secretaría de Educación
# notas                                                      NaN
# unidad                                                     NaN
# Name: 104, dtype: object)
# (105, id                                                    1-ED-146
# Indicador    Tasa de Aprobación para el Sector Privado nive...
# anillo                                 Activos de las personas
# tema                                                 Educación
# fuente                                 Secretaría de Educación
# notas                                                      NaN
# unidad                                                     NaN
# Name: 105, dtype: object)
# (106, id                                                    1-ED-147
# Indicador    Tasa de Aprobación para el Sector Privado nive...
# anillo                                 Activos de las personas
# tema                                                 Educación
# fuente                                 Secretaría de Educación
# notas                                                      NaN
# unidad                                                     NaN
# Name: 106, dtype: object)
# (107, id                                                    1-ED-148
# Indicador    Tasa de Aprobación para el Sector Privado nive...
# anillo                                 Activos de las personas
# tema                                                 Educación
# fuente                                 Secretaría de Educación
# notas                                                      NaN
# unidad                                                     NaN
# Name: 107, dtype: object)
# (108, id                                          1-ED-149
# Indicador    Tasa de Aprobación Total Sector Privado
# anillo                       Activos de las personas
# tema                                       Educación
# fuente                       Secretaría de Educación
# notas                                            NaN
# unidad                                           NaN
# Name: 108, dtype: object)
# (109, id                                                    1-ED-151
# Indicador    Tasa de cobertura bruta en educación universit...
# anillo                                 Activos de las personas
# tema                                                 Educación
# fuente                        Ministerio de Educación Nacional
# notas                                                      NaN
# unidad                                                     NaN
# Name: 109, dtype: object)
# (110, id                                                    1-ED-154
# Indicador                 Tasa de cobertura Bruta en Primaria
# anillo                                 Activos de las personas
# tema                                                 Educación
# fuente       Secretaria de educacion municipal de cada ciudad.
# notas                                                      NaN
# unidad                                                     NaN
# Name: 110, dtype: object)
# (111, id                                                    1-ED-155
# Indicador               Tasa de cobertura Bruta en Secundaria
# anillo                                 Activos de las personas
# tema                                                 Educación
# fuente       Secretaria de educacion municipal de cada ciudad.
# notas                                                      NaN
# unidad                                                     NaN
# Name: 111, dtype: object)
# (112, id                                              1-ED-158
# Indicador    Tasa de cobertura neta en básica secundaria
# anillo                           Activos de las personas
# tema                                           Educación
# fuente               Secretarías de Salud de cada ciudad
# notas                                                NaN
# unidad                                               NaN
# Name: 112, dtype: object)
# (113, id                                          1-ED-159
# Indicador           Tasa de cobertura neta en Media
# anillo                       Activos de las personas
# tema                                       Educación
# fuente       Secretarías de educación de cada ciudad
# notas                                            NaN
# unidad                                           NaN
# Name: 113, dtype: object)
# (114, id                                                    1-ED-160
# Indicador                Tasa de cobertura neta en preescolar
# anillo                                 Activos de las personas
# tema                                                 Educación
# ...
# fuente       Base de Datos del Inventario y Diagnóstico de ...
# notas                                                      NaN
# unidad                                                     NaN
# Name: 267, dtype: object)
# (268, id                                                    2-MO-319
# Indicador             Estado de la malla vial INTERMEDIA bueno
# anillo                                          Hábitat Urbano
# tema                                            Movilidad Vial
# fuente       Base de Datos del Inventario y Diagnóstico de ...
# notas                                                      NaN
# unidad                                                     NaN
# Name: 268, dtype: object)
# (269, id                                                    2-MO-320
# Indicador           Estado de la malla vial INTERMEDIA regular
# anillo                                          Hábitat Urbano
# tema                                            Movilidad Vial
# fuente       Base de Datos del Inventario y Diagnóstico de ...
# notas                                                      NaN
# unidad                                                     NaN
# Name: 269, dtype: object)
# (270, id                                                    2-MO-321
# Indicador              Estado de la malla vial INTERMEDIA malo
# anillo                                          Hábitat Urbano
# tema                                            Movilidad Vial
# fuente       Base de Datos del Inventario y Diagnóstico de ...
# notas                                                      NaN
# unidad                                                     NaN
# Name: 270, dtype: object)
# (271, id                                                    2-MO-322
# Indicador                  Estado de la malla vial LOCAL bueno
# anillo                                          Hábitat Urbano
# tema                                            Movilidad Vial
# fuente       Base de Datos del Inventario y Diagnóstico de ...
# notas                                                      NaN
# unidad                                                     NaN
# Name: 271, dtype: object)
# (272, id                                                    2-MO-323
# Indicador                Estado de la malla vial LOCAL regular
# anillo                                          Hábitat Urbano
# tema                                            Movilidad Vial
# fuente       Base de Datos del Inventario y Diagnóstico de ...
# notas                                                      NaN
# unidad                                                     NaN
# Name: 272, dtype: object)
# (273, id                                                    2-MO-324
# Indicador                   Estado de la malla vial LOCAL malo
# anillo                                          Hábitat Urbano
# tema                                            Movilidad Vial
# fuente       Base de Datos del Inventario y Diagnóstico de ...
# notas                                                      NaN
# unidad                                                     NaN
# Name: 273, dtype: object)
# (274, id                                                    2-MO-325
# Indicador    Recuperación de la malla vial (km anuales recu...
# anillo                                          Hábitat Urbano
# tema                                            Movilidad Vial
# fuente       Unidad Administrativa Especial de Rehabilitaci...
# notas                                                      NaN
# unidad                                                     NaN
# Name: 274, dtype: object)
# (275, id                                                    2-MO-326
# Indicador    Porcentaje de personas que se moviliza princip...
# anillo                                          Hábitat Urbano
# tema                                            Movilidad Vial
# fuente                             Encuesta bienal de culturas
# notas                                                      NaN
# unidad                                                     NaN
# Name: 275, dtype: object)
# (276, id                                                    2-MO-327
# Indicador    Porcentaje de personas que se moviliza princip...
# anillo                                          Hábitat Urbano
# tema                                            Movilidad Vial
# fuente                             Encuesta bienal de culturas
# notas                                                      NaN
# unidad                                                     NaN
# Name: 276, dtype: object)
# (277, id                                                    2-MO-328
# Indicador    Porcentaje de personas que se moviliza princip...
# anillo                                          Hábitat Urbano
# tema                                            Movilidad Vial
# fuente                             Encuesta bienal de culturas
# notas                                                      NaN
# unidad                                                     NaN
# Name: 277, dtype: object)
# (278, id                                                    2-MO-329
# Indicador    Porcentaje de personas que se moviliza princip...
# anillo                                          Hábitat Urbano
# tema                                            Movilidad Vial
# fuente                             Encuesta bienal de culturas
# notas                                                      NaN
# unidad                                                     NaN
# Name: 278, dtype: object)
# (279, id                                                    2-MO-330
# Indicador    Porcentaje de personas que se moviliza princip...
# anillo                                          Hábitat Urbano
# tema                                            Movilidad Vial
# fuente                             Encuesta bienal de culturas
# notas                                                      NaN
# unidad                                                     NaN
# Name: 279, dtype: object)
# (280, id                                                    2-MO-331
# Indicador    Porcentaje de personas que se moviliza princip...
# anillo                                          Hábitat Urbano
# tema                                            Movilidad Vial
# fuente                             Encuesta bienal de culturas
# notas                                                      NaN
# unidad                                                     NaN
# Name: 280, dtype: object)
# (281, id                                                    2-MO-332
# Indicador    Porcentaje de personas que se moviliza princip...
# anillo                                          Hábitat Urbano
# tema                                            Movilidad Vial
# fuente                             Encuesta bienal de culturas
# notas                                                      NaN
# unidad                                                     NaN
# Name: 281, dtype: object)
# (282, id                                                    2-MO-333
# Indicador    Porcentaje de personas que se moviliza princip...
# anillo                                          Hábitat Urbano
# tema                                            Movilidad Vial
# fuente                             Encuesta bienal de culturas
# notas                                                      NaN
# unidad                                                     NaN
# Name: 282, dtype: object)
# (283, id                                                    2-MO-334
# Indicador    Porcentaje de personas que se moviliza princip...
# anillo                                          Hábitat Urbano
# tema                                            Movilidad Vial
# fuente                             Encuesta bienal de culturas
# notas                                                      NaN
# unidad                                                     NaN
# Name: 283, dtype: object)
# (284, id                                                    2-MO-335
# Indicador    Pasajeros diarios movilizados por transporte p...
# anillo                                          Hábitat Urbano
# tema                                            Movilidad Vial
# fuente       DANE. Dato de 2013 actualizado del informe Tra...
# notas                                                      NaN
# unidad                                                     NaN
# Name: 284, dtype: object)
# (285, id                                                    2-MO-336
# Indicador    Promedio de pasajeros en hora pico en Transmil...
# anillo                                          Hábitat Urbano
# tema                                            Movilidad Vial
# fuente                                         Transmilenio SA
# notas                                                      NaN
# unidad                                                     NaN
# Name: 285, dtype: object)
# (286, id                                                    2-MO-337
# Indicador    Número total de pasajeros interurbanos transpo...
# anillo                                          Hábitat Urbano
# tema                                            Movilidad Vial
# fuente                                         Transmilenio SA
# notas                                                      NaN
# unidad                                                     NaN
# Name: 286, dtype: object)
# (287, id                                                    2-MO-338
# Indicador    Promedio anual de velocidad en transporte públ...
# anillo                                          Hábitat Urbano
# tema                                            Movilidad Vial
# fuente                                 Secretaría de Movilidad
# notas                                                      NaN
# unidad                                                     NaN
# Name: 287, dtype: object)
# (288, id                                                    2-MO-339
# Indicador    Promedio anual de velocidad de transporte indi...
# anillo                                          Hábitat Urbano
# tema                                            Movilidad Vial
# fuente                                 Secretaría de Movilidad
# notas                                                      NaN
# unidad                                                     NaN
# Name: 288, dtype: object)
# (289, id                                                    2-MO-340
# Indicador    Promedio anual de velocidad particular (km/hor...
# anillo                                          Hábitat Urbano
# tema                                            Movilidad Vial
# fuente                                 Secretaría de Movilidad
# notas                                                      NaN
# unidad                                                     NaN
# Name: 289, dtype: object)
# (290, id                                             2-MO-341
# Indicador    Velocidad promedio de recorrido en el SITP
# anillo                                   Hábitat Urbano
# tema                                     Movilidad Vial
# fuente                                  Transmilenio SA
# notas                                               NaN
# unidad                                              NaN
# Name: 290, dtype: object)
# (291, id                                                  2-MO-342
# Indicador    Velocidad promedio de recorrido en Transmilenio
# anillo                                        Hábitat Urbano
# tema                                          Movilidad Vial
# fuente                                       Transmilenio SA
# notas                                                    NaN
# unidad                                                   NaN
# Name: 291, dtype: object)
# (292, id                                     2-MO-343
# Indicador    Muertes en el sistema Transmilenio
# anillo                           Hábitat Urbano
# tema                             Movilidad Vial
# fuente                          Transmilenio SA
# notas                                       NaN
# unidad                                      NaN
# Name: 292, dtype: object)
# (293, id                                     2-MO-344
# Indicador    Heridos en el sistema Transmilenio
# anillo                           Hábitat Urbano
# tema                             Movilidad Vial
# fuente                          Transmilenio SA
# notas                                       NaN
# unidad                                      NaN
# Name: 293, dtype: object)
# (294, id                           2-MO-345
# Indicador    Cobertura de ciclo rutas
# anillo                 Hábitat Urbano
# tema                   Movilidad Vial
# fuente                            IDU
# notas                             NaN
# unidad                            NaN
# Name: 294, dtype: object)
# (295, id                        2-MO-346
# Indicador    Cobertura Bici-carril
# anillo              Hábitat Urbano
# tema                Movilidad Vial
# fuente                         IDU
# notas                          NaN
# unidad                         NaN
# Name: 295, dtype: object)
# (296, id                                                    2-MO-347
# Indicador    Total infraestrutura para bicicletas (Ciclorut...
# anillo                                          Hábitat Urbano
# tema                                            Movilidad Vial
# fuente                                                     IDU
# notas                                                      NaN
# unidad                                                     NaN
# Name: 296, dtype: object)
# (297, id                        2-MO-348
# Indicador    Cobertura carril bici
# anillo              Hábitat Urbano
# tema                Movilidad Vial
# fuente                         IDU
# notas                          NaN
# unidad                         NaN
# Name: 297, dtype: object)
# (298, id                                                    2-MO-349
# Indicador    Parque automotor de transporte particular (aut...
# anillo                                          Hábitat Urbano
# tema                                            Movilidad Vial
# fuente                                 Secretaría de Movilidad
# notas                                                      NaN
# unidad                                                     NaN
# Name: 298, dtype: object)
# (299, id                                                    2-MO-350
# Indicador    Parque automotor de transporte particular (mot...
# anillo                                          Hábitat Urbano
# tema                                            Movilidad Vial
# fuente                                 Secretaría de Movilidad
# notas                                                      NaN
# unidad                                                     NaN
# Name: 299, dtype: object)
# (300, id                                         2-MO-351
# Indicador    Parque automotor de transporte público
# anillo                               Hábitat Urbano
# tema                                 Movilidad Vial
# fuente                      Secretaría de Movilidad
# notas                                           NaN
# unidad                                          NaN
# Name: 300, dtype: object)
# (301, id                                               2-MO-352
# Indicador    Charratización buses, busetas y microbusetas
# anillo                                     Hábitat Urbano
# tema                                       Movilidad Vial
# fuente                            Secretaría de Movilidad
# notas                                                 NaN
# unidad                                                NaN
# Name: 301, dtype: object)
# (302, id                            ANIO
# Indicador                      AÑO
# anillo                         NaN
# tema                           NaN
# fuente                         NaN
# notas        Desde 2005 hasta 2014
# unidad                         Año
# Name: 302, dtype: object)
# (303, id           CIUDAD
# Indicador    CIUDAD
# anillo          NaN
# tema            NaN
# fuente          NaN
# notas           NaN
# unidad          NaN
# Name: 303, dtype: object)
# (304, id           LOCALIDAD
# Indicador    LOCALIDAD
# anillo             NaN
# tema               NaN
# fuente             NaN
# notas              NaN
# unidad             NaN
# Name: 304, dtype: object)

# %%
for variables in diccionario_subjetivos.iterrows():
    print(variables)
# Out:
# (0, variable                                                        CR1H
# descripcion        Cuando usted va a - Ferias generalmente paga o...
# dimension                                 Buen Gobierno y Ciudadanía
# modulo                                 Cultura, Recreación Y Deporte
# respuestas         {'9': 'Visitar museos/ galerías/ bibliotecas[/...
# tipo_respuestas                                           categorica
# ano_min                                                         2013
# ano_max                                                         2013
# Name: 0, dtype: object)
# (1, variable           NUMERO
# descripcion        NUMERO
# dimension             NaN
# modulo                NaN
# respuestas            NaN
# tipo_respuestas       NaN
# ano_min              1998
# ano_max              2014
# Name: 1, dtype: object)
# (2, variable                                                       NSE_1
# descripcion                                                      NSE
# dimension                                                        NaN
# modulo                                                           NaN
# respuestas         {'4': 'Estrato 4', '7': 'Rural', '5': 'Estrato...
# tipo_respuestas                                           categorica
# ano_min                                                         1998
# ano_max                                                         2014
# Name: 2, dtype: object)
# (3, variable                                                      CIUDAD
# descripcion                                                   CIUDAD
# dimension                                                        NaN
# modulo                                                           NaN
# respuestas         {'54001': 'Cucuta', '66001': 'Pereira', '76892...
# tipo_respuestas                                           categorica
# ano_min                                                         1998
# ano_max                                                         2014
# Name: 3, dtype: object)
# (4, variable                                                 TIPO_ENTREV
# descripcion                                              TIPO_ENTREV
# dimension                                                        NaN
# modulo                                                           NaN
# respuestas         {'4': 'Transporte Informal', '1': 'Transporte ...
# tipo_respuestas                                           categorica
# ano_min                                                         2008
# ano_max                                                         2013
# Name: 4, dtype: object)
# (5, variable                                            LOCALIDAD_COMUNA
# descripcion                                         LOCALIDAD_COMUNA
# dimension                                                      Extra
# modulo                                         Módulo De Desigualdad
# respuestas         {'157': 'Villa Hermosa', '9': 'Fontibón', '158...
# tipo_respuestas                                           categorica
# ano_min                                                         1998
# ano_max                                                         2014
# Name: 5, dtype: object)
# (6, variable           BARRIO
# descripcion        BARRIO
# dimension             NaN
# modulo                NaN
# respuestas            NaN
# tipo_respuestas       NaN
# ano_min              2002
# ano_max              2014
# Name: 6, dtype: object)
# (7, variable                                                       ZONAS
# descripcion                                                    ZONAS
# dimension                                                      Extra
# modulo                                         Módulo De Desigualdad
# respuestas         {'9': 'Nororiental', '12': 'Histórica y del Ca...
# tipo_respuestas                                           categorica
# ano_min                                                         1998
# ano_max                                                         2014
# Name: 7, dtype: object)
# (8, variable                                          SEXO
# descripcion                                       SEXO
# dimension                                          NaN
# modulo                                             NaN
# respuestas         {'1': 'Masculino', '2': 'Femenino'}
# tipo_respuestas                             categorica
# ano_min                                           1998
# ano_max                                           2014
# Name: 8, dtype: object)
# (9, variable                                                        EDAD
# descripcion                                                     EDAD
# dimension                                    Activos de las personas
# modulo                                                     Educación
# respuestas         {'4': 'De 46 a 55 años', '5': 'Más de 55 años'...
# tipo_respuestas                                           categorica
# ano_min                                                         1998
# ano_max                                                         2014
# Name: 9, dtype: object)
# (10, variable                                                         PON
# descripcion                                                      PON
# dimension                                                      Extra
# modulo                                         Módulo De Desigualdad
# respuestas         {'4': 'Nada importante', '92': 'No Sabe / No R...
# tipo_respuestas                                           categorica
# ano_min                                                         1998
# ano_max                                                         2014
# Name: 10, dtype: object)
# (11, variable                                                         AÑO
# descripcion                                                      AÑO
# dimension                                                        NaN
# modulo                                                           NaN
# respuestas         {'2000': '2000', '2007': '2007', '2012': '2012...
# tipo_respuestas                                           categorica
# ano_min                                                          AÑO
# ano_max                                                          AÑO
# Name: 11, dtype: object)
# (12, variable                                             TIPO_TRANSPORTE
# descripcion                                          TIPO_TRANSPORTE
# dimension                                                        NaN
# modulo                                                           NaN
# respuestas         {'4': 'Transporte Informal', '1': 'Transporte ...
# tipo_respuestas                                           categorica
# ano_min                                                         2011
# ano_max                                                         2014
# Name: 12, dtype: object)
# (13, variable                                                          F1
# descripcion                                   Tipo de entrevistad(a)
# dimension                                                        NaN
# modulo                                                           NaN
# respuestas         {'1': '¿Podría por favor hablar con el jefe de...
# tipo_respuestas                                           categorica
# ano_min                                                         2008
# ano_max                                                         2014
# Name: 13, dtype: object)
# (14, variable                                                          F2
# descripcion        Actualmente estamos realizando un estudio para...
# dimension                                                        NaN
# modulo                                                           NaN
# respuestas                                    {'1': 'Sí', '2': 'No'}
# tipo_respuestas                                           categorica
# ano_min                                                         2008
# ano_max                                                         2014
# Name: 14, dtype: object)
# (15, variable                                                        F3_1
# descripcion        Para comenzar me gustaría saber si usted o alg...
# dimension                                                        NaN
# modulo                                                           NaN
# respuestas                                    {'1': 'Si', '2': 'No'}
# tipo_respuestas                                           categorica
# ano_min                                                         2008
# ano_max                                                         2014
# Name: 15, dtype: object)
# (16, variable                                                       F3A_1
# descripcion        Para comenzar me gustaría saber si usted o alg...
# dimension                                                        NaN
# modulo                                                           NaN
# respuestas                                    {'1': 'Si', '2': 'No'}
# tipo_respuestas                                           categorica
# ano_min                                                         2001
# ano_max                                                         2007
# Name: 16, dtype: object)
# (17, variable                                                       F3A_2
# descripcion        Para comenzar me gustaría saber si usted o alg...
# dimension                                                        NaN
# modulo                                                           NaN
# respuestas                                    {'1': 'Si', '2': 'No'}
# tipo_respuestas                                           categorica
# ano_min                                                         2001
# ano_max                                                         2007
# Name: 17, dtype: object)
# (18, variable                                                       F3A_3
# descripcion        Para comenzar me gustaría saber si usted o alg...
# dimension                                                        NaN
# modulo                                                           NaN
# respuestas                                    {'1': 'Si', '2': 'No'}
# tipo_respuestas                                           categorica
# ano_min                                                         2001
# ano_max                                                         2007
# Name: 18, dtype: object)
# (19, variable                                                          F4
# descripcion                           ¿En qué empresa trabaja Usted?
# dimension                                                        NaN
# modulo                                                           NaN
# respuestas         {'4': 'Por ser mujer (ENC: VALIDE POR SEXO)', ...
# tipo_respuestas                                           categorica
# ano_min                                                         2004
# ano_max                                                         2014
# Name: 19, dtype: object)
# (20, variable                                 F5
# descripcion        ¿Y cuál es su ocupación?
# dimension                               NaN
# modulo                                  NaN
# respuestas                              NaN
# tipo_respuestas                         NaN
# ano_min                                2004
# ano_max                                2014
# Name: 20, dtype: object)
# (21, variable                                                          F6
# descripcion        ¿Usted vive de forma permanente en [CIUDAD], o...
# dimension                                                        NaN
# modulo                                                           NaN
# respuestas         {'1': 'Vive en [CIUDAD]', '2': 'Está en la ciu...
# tipo_respuestas                                           categorica
# ano_min                                                         2000
# ano_max                                                         2014
# Name: 21, dtype: object)
# (22, variable                                         F6A_AOS
# descripcion        ¿Hace cuánto tiempo vive en [CIUDAD]?
# dimension                                            NaN
# modulo                                               NaN
# respuestas                                           NaN
# tipo_respuestas                                      NaN
# ano_min                                             2002
# ano_max                                             2014
# Name: 22, dtype: object)
# (23, variable                                       F6A_MESES
# descripcion        ¿Hace cuánto tiempo vive en [CIUDAD]?
# dimension                                            NaN
# modulo                                               NaN
# respuestas                                           NaN
# tipo_respuestas                                      NaN
# ano_min                                             2004
# ano_max                                             2014
# Name: 23, dtype: object)
# (24, variable                                        F6A_DIAS
# descripcion        ¿Hace cuánto tiempo vive en [CIUDAD]?
# dimension                                            NaN
# modulo                                               NaN
# respuestas                                           NaN
# tipo_respuestas                                      NaN
# ano_min                                             2004
# ano_max                                             2007
# Name: 24, dtype: object)
# (25, variable                                                          F7
# descripcion        ¿Podría por favor decirme cuántos hogares hay ...
# dimension                                                        NaN
# modulo                                                           NaN
# respuestas         {'4': 'En usufructo', '5': 'Ocupante de hecho'...
# tipo_respuestas                                           categorica
# ano_min                                                         2004
# ano_max                                                         2014
# Name: 25, dtype: object)
# (26, variable                                                         F7A
# descripcion                                          ¿Usted vive en?
# dimension                                                        NaN
# modulo                                                           NaN
# respuestas         {'4': 'Apartamento Conjunto Cerrado', '1': 'Ca...
# tipo_respuestas                                           categorica
# ano_min                                                         2004
# ano_max                                                         2007
# Name: 26, dtype: object)
# (27, variable                                                         F7B
# descripcion                      Podría decirme si esta vivienda es:
# dimension                                                        NaN
# modulo                                                           NaN
# respuestas         {'4': 'En usufructo', '5': 'Ocupante de hecho'...
# tipo_respuestas                                           categorica
# ano_min                                                         2004
# ano_max                                                         2004
# Name: 27, dtype: object)
# (28, variable                                                          F9
# descripcion        De acuerdo a su cultura o rasgos físicos, ¿Ust...
# dimension                                                        NaN
# modulo                                                           NaN
# respuestas         {'4': 'Afrodescendiente', '5': 'Raizal de San ...
# tipo_respuestas                                           categorica
# ano_min                                                         2005
# ano_max                                                         2013
# Name: 28, dtype: object)
# (29, variable                                                         F12
# descripcion        Cuál de las siguientes opciones describe mejor...
# dimension                                                        NaN
# modulo                                                           NaN
# respuestas         {'4': '\tHija/Hijo de la familia', '5': 'Abuel...
# tipo_respuestas                                           categorica
# ano_min                                                         2004
# ano_max                                                         2007
# Name: 29, dtype: object)
# (30, variable                                                         AG1
# descripcion        Ahora quisiera saber si en su opinión, las cos...
# dimension                            Optimismo y bienestar subjetivo
# modulo                                           Aspectos Generales
# respuestas         {'92': 'No Sabe / No Responde', '1': 'Buen cam...
# tipo_respuestas                                           categorica
# ano_min                                                         2001
# ano_max                                                         2014
# Name: 30, dtype: object)
# (31, variable                                                         AG2
# descripcion        Usted personalmente, ¿qué tan orgulloso(a) se ...
# dimension                            Optimismo y bienestar subjetivo
# modulo                                           Aspectos Generales
# respuestas         {'4': '4', '5': 'Muy orgulloso', '2': '2', '92...
# tipo_respuestas                                           categorica
# ano_min                                                         2001
# ano_max                                                         2014
# Name: 31, dtype: object)
# (32, variable                                                         AG3
# descripcion        Durante el próximo año, ¿Usted cree que las co...
# dimension                            Optimismo y bienestar subjetivo
# modulo                                           Aspectos Generales
# respuestas              {'1': 'Van a mejorar', '2': 'Van a emporar'}
# tipo_respuestas                                           categorica
# ano_min                                                         2011
# ano_max                                                         2011
# Name: 32, dtype: object)
# (33, variable                                                         CV0
# descripcion        Por favor imagine una escalera Suponga que el ...
# dimension                            Optimismo y bienestar subjetivo
# modulo                                               Calidad De Vida
# respuestas         {'4': '4', '7': '7', '5': '5', '8': '8', '2': ...
# tipo_respuestas                                           categorica
# ano_min                                                         2010
# ano_max                                                         2013
# Name: 33, dtype: object)
# (34, variable                                                         CV3
# descripcion        De los aspectos que encontrará en esta tarjeta...
# dimension                            Optimismo y bienestar subjetivo
# modulo                                               Calidad De Vida
# respuestas         {'9': 'Seguridad', '12': 'Recreación', '23': '...
# tipo_respuestas                                           categorica
# ano_min                                                         2010
# ano_max                                                         2010
# Name: 34, dtype: object)
# (35, variable                                                        CV5A
# descripcion        Pensando en las obras y en las inversiones que...
# dimension                            Optimismo y bienestar subjetivo
# modulo                                               Calidad De Vida
# respuestas         {'9': 'Mejor calidad de vida', '73': 'Peor de ...
# tipo_respuestas                                           categorica
# ano_min                                                         2008
# ano_max                                                         2008
# Name: 35, dtype: object)
# (36, variable                                                        CV6A
# descripcion        Independientemente si usted nació o no en [CIU...
# dimension                            Optimismo y bienestar subjetivo
# modulo                                               Calidad De Vida
# respuestas         {'92': 'No Sabe / No Responde', '1': 'De CIUDA...
# tipo_respuestas                                           categorica
# ano_min                                                         2001
# ano_max                                                         2008
# Name: 36, dtype: object)
# (37, variable                                                        CV6B
# descripcion        Por favor descríbame a Bogotá en una sola palabra
# dimension                            Optimismo y bienestar subjetivo
# modulo                                               Calidad De Vida
# respuestas         {'158': 'Politiquería', '2': 'Pujante', '281':...
# tipo_respuestas                                           categorica
# ano_min                                                         2011
# ano_max                                                         2011
# Name: 37, dtype: object)
# (38, variable                                                        CV6C
# descripcion                  ¿Ud. nació en CIUDAD, o en otra ciudad?
# dimension                            Optimismo y bienestar subjetivo
# modulo                                               Calidad De Vida
# respuestas         {'1': '\tNació en CIUDAD', '2': '\tNació en ot...
# tipo_respuestas                                           categorica
# ano_min                                                         2002
# ano_max                                                         2007
# Name: 38, dtype: object)
# (39, variable                                                    CV6D_BOG
# descripcion                              ¿En qué ciudad nació usted?
# dimension                            Optimismo y bienestar subjetivo
# modulo                                               Calidad De Vida
# respuestas         {'9': 'Girardot', '117': 'Cañas Gordas', '101'...
# tipo_respuestas                                           categorica
# ano_min                                                         2002
# ano_max                                                         2007
# Name: 39, dtype: object)
# (40, variable                                                        CV6E
# descripcion                        ¿En qué departamento nació usted?
# dimension                            Optimismo y bienestar subjetivo
# modulo                                               Calidad De Vida
# respuestas         {'104': 'Sabana (Córdoba, Sucre, Cesar)', '9':...
# tipo_respuestas                                           categorica
# ano_min                                                         2004
# ano_max                                                         2007
# Name: 40, dtype: object)
# (41, variable                                                         CO3
# descripcion        ¿En general cómo califica la calidad de la inf...
# dimension                            Optimismo y bienestar subjetivo
# modulo                                    Clima De Opinión Económica
# respuestas         {'9': 'El costo de acceso a cultura/ recreació...
# tipo_respuestas                                           categorica
# ano_min                                                         2001
# ano_max                                                         2014
# Name: 41, dtype: object)
# (42, variable                                                     CO4A_SI
# descripcion                          ¿Por qué SI se considera pobre?
# dimension                            Optimismo y bienestar subjetivo
# modulo                                    Clima De Opinión Económica
# respuestas         {'9': 'No tiene un buen salario', '46': 'No ti...
# tipo_respuestas                                           categorica
# ano_min                                                         2006
# ano_max                                                         2014
# Name: 42, dtype: object)
# (43, variable                                                     CO4A_NO
# descripcion                          ¿Por qué NO se considera pobre?
# dimension                            Optimismo y bienestar subjetivo
# modulo                                    Clima De Opinión Económica
# respuestas         {'9': 'Tengo familia/ hogar/ buen hogar', '46'...
# tipo_respuestas                                           categorica
# ano_min                                                         2006
# ano_max                                                         2014
# Name: 43, dtype: object)
# (44, variable                             CO4_SI_BOG_05
# descripcion        ¿Por qué SI se considera pobre?
# dimension          Optimismo y bienestar subjetivo
# modulo                  Clima De Opinión Económica
# respuestas                  {'1': 'Si', '2': 'No'}
# tipo_respuestas                         categorica
# ano_min                                       2005
# ano_max                                       2005
# Name: 44, dtype: object)
# (45, variable                                                        CO4B
# descripcion             ¿Podría decirme si usted se considera pobre?
# dimension                            Optimismo y bienestar subjetivo
# modulo                                    Clima De Opinión Económica
# respuestas         {'4': 'Otra pérdida económica importante', '7'...
# tipo_respuestas                                           categorica
# ano_min                                                         2007
# ano_max                                                         2007
# Name: 45, dtype: object)
# (46, variable                                                        CO4C
# descripcion             ¿Podría decirme si usted se considera pobre?
# dimension                            Optimismo y bienestar subjetivo
# modulo                                    Clima De Opinión Económica
# respuestas         {'9': 'Disminuyeron el gasto en vestuario', '9...
# tipo_respuestas                                           categorica
# ano_min                                                         2007
# ano_max                                                         2007
# Name: 46, dtype: object)
# (47, variable                                                        CO12
# descripcion        En el último año, ¿este hogar ha tenido alguna...
# dimension                            Optimismo y bienestar subjetivo
# modulo                                    Clima De Opinión Económica
# respuestas         {'92': 'No Sabe / No Responde', '1': 'Sí', '2'...
# tipo_respuestas                                           categorica
# ano_min                                                         2005
# ano_max                                                         2011
# Name: 47, dtype: object)
# (48, variable                                                        CO13
# descripcion        ¿Qué es lo primero que ha sacrificado el hogar...
# dimension                            Optimismo y bienestar subjetivo
# modulo                                    Clima De Opinión Económica
# respuestas         {'9': 'Gastos en recreación/ diversión/ vacaci...
# tipo_respuestas                                           categorica
# ano_min                                                         2008
# ano_max                                                         2011
# Name: 48, dtype: object)
# (49, variable                                                        CO14
# descripcion        ¿Cuál servicio público?/¿Cuál servicio público...
# dimension                            Optimismo y bienestar subjetivo
# modulo                                    Clima De Opinión Económica
# respuestas         {'4': 'Teléfono fijo', '5': 'Celular', '2': 'E...
# tipo_respuestas                                           categorica
# ano_min                                                         2005
# ano_max                                                         2011
# Name: 49, dtype: object)
# (50, variable                                                       CO14B
# descripcion        ¿Cuál servicio público?/¿Cuál servicio público...
# dimension                            Optimismo y bienestar subjetivo
# modulo                                    Clima De Opinión Económica
# respuestas         {'4': 'Gas', '90': 'Ninguno', '1': 'Energía el...
# tipo_respuestas                                           categorica
# ano_min                                                         2005
# ano_max                                                         2006
# Name: 50, dtype: object)
# (51, variable                                                         AL1
# descripcion        En las últimas CUATRO semanas, ¿Usted o algún ...
# dimension                            Optimismo y bienestar subjetivo
# modulo                                                  Alimentación
# respuestas                    {'1': 'Sí', '2': 'No', '3': 'No Sabe'}
# tipo_respuestas                                           categorica
# ano_min                                                         2012
# ano_max                                                         2014
# Name: 51, dtype: object)
# (52, variable                                                         AL2
# descripcion                        ¿Con qué frecuencia sucedió esto?
# dimension                            Optimismo y bienestar subjetivo
# modulo                                                  Alimentación
# respuestas         {'4': 'Por lo menos una vez al mes', '1': 'Poc...
# tipo_respuestas                                           categorica
# ano_min                                                         2012
# ano_max                                                         2014
# Name: 52, dtype: object)
# (53, variable                                                          A2
# descripcion        ¿Utilizaron los servicios de salud de cualquie...
# dimension                                                        NaN
# modulo                                                           NaN
# respuestas         {'4': 'Las tres comidas', '92': 'No Sabe / No ...
# tipo_respuestas                                           categorica
# ano_min                                                         2004
# ano_max                                                         2011
# Name: 53, dtype: object)
# (54, variable                                                         A2A
# descripcion            ¿Fue por consulta externa o fue una urgencia?
# dimension                                                        NaN
# modulo                                                           NaN
# respuestas         {'1': 'Por consulta externa', '2': 'Una urgenc...
# tipo_respuestas                                           categorica
# ano_min                                                         2005
# ano_max                                                         2005
# Name: 54, dtype: object)
# (55, variable                                                       A2B_1
# descripcion        Cuál o cuáles miembros del hogar no consumiero...
# dimension                                                        NaN
# modulo                                                           NaN
# respuestas         {'4': 'De 18 a 25 años', '7': 'De 46 a 55 años...
# tipo_respuestas                                           categorica
# ano_min                                                         2005
# ano_max                                                         2005
# Name: 55, dtype: object)
# (56, variable                                                       A2B_2
# descripcion        Cuál o cuáles miembros del hogar no consumiero...
# dimension                                                        NaN
# modulo                                                           NaN
# respuestas         {'4': 'De 18 a 25 años', '7': 'De 46 a 55 años...
# tipo_respuestas                                           categorica
# ano_min                                                         2005
# ano_max                                                         2005
# Name: 56, dtype: object)
# (57, variable                                                       A2B_3
# descripcion        Cuál o cuáles miembros del hogar no consumiero...
# dimension                                                        NaN
# modulo                                                           NaN
# respuestas         {'4': 'De 18 a 25 años', '7': 'De 46 a 55 años...
# tipo_respuestas                                           categorica
# ano_min                                                         2005
# ano_max                                                         2005
# Name: 57, dtype: object)
# (58, variable                                                       A2B_4
# descripcion        Cuál o cuáles miembros del hogar no consumiero...
# dimension                                                        NaN
# modulo                                                           NaN
# respuestas         {'4': '4', '5': 'Mucho', '2': '2', '92': 'No S...
# tipo_respuestas                                           categorica
# ano_min                                                         2005
# ano_max                                                         2005
# Name: 58, dtype: object)
# (59, variable                                                       A2B_5
# descripcion        Cuál o cuáles miembros del hogar no consumiero...
# dimension                                                        NaN
# modulo                                                           NaN
# respuestas         {'4': '4', '5': 'Mucho', '2': '2', '92': 'No S...
# tipo_respuestas                                           categorica
# ano_min                                                         2005
# ano_max                                                         2005
# Name: 59, dtype: object)
# (60, variable                                                       A2B_6
# descripcion        Cuál o cuáles miembros del hogar no consumiero...
# dimension                                                        NaN
# modulo                                                           NaN
# respuestas         {'4': '4', '5': 'Mucho', '2': '2', '92': 'No S...
# tipo_respuestas                                           categorica
# ano_min                                                         2005
# ano_max                                                         2005
# Name: 60, dtype: object)
# (61, variable                                                       A2B_7
# descripcion        Cuál o cuáles miembros del hogar no consumiero...
# dimension                                                        NaN
# modulo                                                           NaN
# respuestas         {'4': '4', '5': 'Mucho', '2': '2', '92': 'No S...
# tipo_respuestas                                           categorica
# ano_min                                                         2005
# ano_max                                                         2005
# Name: 61, dtype: object)
# (62, variable                                                       A2B_8
# descripcion        Cuál o cuáles miembros del hogar no consumiero...
# dimension                                                        NaN
# modulo                                                           NaN
# respuestas         {'4': '4', '5': 'Mucho', '2': '2', '92': 'No S...
# tipo_respuestas                                           categorica
# ano_min                                                         2005
# ano_max                                                         2005
# Name: 62, dtype: object)
# (63, variable                                                       A2C_1
# descripcion        Cuál o cuáles miembros del hogar no consumiero...
# dimension                                                        NaN
# modulo                                                           NaN
# respuestas         {'92': 'No Sabe / No Responde', '1': 'Si', '2'...
# tipo_respuestas                                           categorica
# ano_min                                                         2005
# ano_max                                                         2005
# Name: 63, dtype: object)
# (64, variable                                                       A2C_2
# descripcion        Cuál o cuáles miembros del hogar no consumiero...
# dimension                                                        NaN
# modulo                                                           NaN
# respuestas         {'92': 'No Sabe / No Responde', '1': 'Si', '2'...
# tipo_respuestas                                           categorica
# ano_min                                                         2005
# ano_max                                                         2005
# Name: 64, dtype: object)
# (65, variable                                                       A2C_3
# descripcion        Cuál o cuáles miembros del hogar no consumiero...
# dimension                                                        NaN
# modulo                                                           NaN
# respuestas         {'92': 'No Sabe / No Responde', '1': 'Si', '2'...
# tipo_respuestas                                           categorica
# ano_min                                                         2005
# ano_max                                                         2005
# Name: 65, dtype: object)
# (66, variable                                                       A2C_4
# descripcion        Cuál o cuáles miembros del hogar no consumiero...
# dimension                                                        NaN
# modulo                                                           NaN
# respuestas         {'92': 'No Sabe / No Responde', '1': 'Si', '2'...
# tipo_respuestas                                           categorica
# ano_min                                                         2005
# ano_max                                                         2005
# Name: 66, dtype: object)
# (67, variable                                                       A2C_5
# descripcion        Cuál o cuáles miembros del hogar no consumiero...
# dimension                                                        NaN
# modulo                                                           NaN
# respuestas         {'4': '4', '5': 'Mucho', '2': '2', '92': 'No S...
# tipo_respuestas                                           categorica
# ano_min                                                         2005
# ano_max                                                         2005
# Name: 67, dtype: object)
# (68, variable                                                       A2C_6
# descripcion        Cuál o cuáles miembros del hogar no consumiero...
# dimension                                                        NaN
# modulo                                                           NaN
# respuestas         {'4': '4', '5': 'Mucho', '2': '2', '92': 'No S...
# tipo_respuestas                                           categorica
# ano_min                                                         2005
# ano_max                                                         2005
# Name: 68, dtype: object)
# (69, variable                                                       A2C_7
# descripcion        Cuál o cuáles miembros del hogar no consumiero...
# dimension                                                        NaN
# modulo                                                           NaN
# respuestas         {'4': '4', '5': 'Mucho', '2': '2', '92': 'No S...
# tipo_respuestas                                           categorica
# ano_min                                                         2005
# ano_max                                                         2005
# Name: 69, dtype: object)
# (70, variable                                                       A2C_8
# descripcion        Cuál o cuáles miembros del hogar no consumiero...
# dimension                                                        NaN
# modulo                                                           NaN
# respuestas         {'4': '4', '5': 'Mucho', '2': '2', '92': 'No S...
# tipo_respuestas                                           categorica
# ano_min                                                         2005
# ano_max                                                         2005
# Name: 70, dtype: object)
# (71, variable                                                       AL7_1
# descripcion        A continuación, le mencionaré afirmaciones de ...
# dimension                            Optimismo y bienestar subjetivo
# modulo                                                  Alimentación
# respuestas         {'1': 'Siempre', '2': 'Algunas veces', '3': 'N...
# tipo_respuestas                                           categorica
# ano_min                                                         2004
# ano_max                                                         2004
# Name: 71, dtype: object)
# (72, variable                                                       AL7_2
# descripcion        A continuación, le mencionaré afirmaciones de ...
# dimension                            Optimismo y bienestar subjetivo
# modulo                                                  Alimentación
# respuestas         {'1': 'Siempre', '2': 'Algunas veces', '3': 'N...
# tipo_respuestas                                           categorica
# ano_min                                                         2004
# ano_max                                                         2004
# Name: 72, dtype: object)
# (73, variable                                                       AL7_3
# descripcion        A continuación, le mencionaré algunas afirmaci...
# dimension                            Optimismo y bienestar subjetivo
# modulo                                                  Alimentación
# respuestas         {'1': 'Siempre', '2': 'Algunas veces', '3': 'N...
# tipo_respuestas                                           categorica
# ano_min                                                         2004
# ano_max                                                         2004
# Name: 73, dtype: object)
# (74, variable                                                       AL7_4
# descripcion        Mencionaré algunas afirmaciones de la gente so...
# dimension                            Optimismo y bienestar subjetivo
# modulo                                                  Alimentación
# respuestas         {'1': 'Siempre', '2': 'Algunas veces', '3': 'N...
# tipo_respuestas                                           categorica
# ano_min                                                         2004
# ano_max                                                         2004
# Name: 74, dtype: object)
# (75, variable                                                       AL7_5
# descripcion        Voy a mencionar afirmaciones de la gente sobre...
# dimension                            Optimismo y bienestar subjetivo
# modulo                                                  Alimentación
# respuestas         {'1': 'Siempre', '2': 'Algunas veces', '3': 'N...
# tipo_respuestas                                           categorica
# ano_min                                                         2004
# ano_max                                                         2004
# Name: 75, dtype: object)
# (76, variable                                                       AL7_6
# descripcion        Voy a mencionar afirmaciones sobre su situació...
# dimension                            Optimismo y bienestar subjetivo
# modulo                                                  Alimentación
# respuestas         {'1': 'Siempre', '2': 'Algunas veces', '3': 'N...
# tipo_respuestas                                           categorica
# ano_min                                                         2004
# ano_max                                                         2004
# Name: 76, dtype: object)
# (77, variable                                                        ED23
# descripcion        De los siguientes niveles educativos, ¿cuál es...
# dimension                                    Activos de las personas
# modulo                                                     Educación
# respuestas         {'4': 'Técnico, tecnólogo o universitario', '5...
# tipo_respuestas                                           categorica
# ano_min                                                         2005
# ano_max                                                         2007
# Name: 77, dtype: object)
# (78, variable                                                         ED1
# descripcion        ¿En este hogar hay niños o jóvenes entre 5 y 1...
# dimension                                    Activos de las personas
# modulo                                                     Educación
# respuestas         {'92': 'No Sabe / No Responde', '1': 'Sí', '2'...
# tipo_respuestas                                           categorica
# ano_min                                                         1998
# ano_max                                                         2014
# Name: 78, dtype: object)
# (79, variable                                                        ED1A
# descripcion        ¿Cuántos niños y jóvenes, que estén entre 5 y ...
# dimension                                    Activos de las personas
# modulo                                                     Educación
# respuestas         {'4': 'Estando convencido que no es lo correct...
# tipo_respuestas                                           categorica
# ano_min                                                         2001
# ano_max                                                         2008
# Name: 79, dtype: object)
# (80, variable                                                     ED1A_90
# descripcion        ¿Cuántos niños y jóvenes, que estén entre 5 y ...
# dimension                                    Activos de las personas
# modulo                                                     Educación
# respuestas                                         {'90': 'Ninguna'}
# tipo_respuestas                                           categorica
# ano_min                                                         2005
# ano_max                                                         2008
# Name: 80, dtype: object)
# (81, variable                                                      ED1B_1
# descripcion        ¿Y de estos niños podría decirme cuantos están...
# dimension                                    Activos de las personas
# modulo                                                     Educación
# respuestas         {'4': 'Algo satisfecho', '5': 'Muy satisfecho'...
# tipo_respuestas                                           categorica
# ano_min                                                         2004
# ano_max                                                         2004
# Name: 81, dtype: object)
# (82, variable                                                      ED1B_2
# descripcion        ¿Y de estos niños podría decirme cuantos están...
# dimension                                    Activos de las personas
# modulo                                                     Educación
# respuestas         {'4': '4', '5': 'Completamente De Acuerdo', '1...
# tipo_respuestas                                           categorica
# ano_min                                                         2004
# ano_max                                                         2004
# Name: 82, dtype: object)
# (83, variable                                                      ED1B_3
# descripcion        ¿Y de estos niños podría decirme cuantos están...
# dimension                                    Activos de las personas
# modulo                                                     Educación
# respuestas         {'4': '4', '5': 'Mucho', '1': 'Nada', '2': '2'...
# tipo_respuestas                                           categorica
# ano_min                                                         2004
# ano_max                                                         2004
# Name: 83, dtype: object)
# (84, variable                                                      ED1B_4
# descripcion        ¿Y de estos niños podría decirme cuantos están...
# dimension                                    Activos de las personas
# modulo                                                     Educación
# respuestas                                    {'1': 'Sí', '2': 'No'}
# tipo_respuestas                                           categorica
# ano_min                                                         2004
# ano_max                                                         2004
# ...
# Name: 1335, dtype: object)
# (1336, variable                                                      CC7D_3
# descripcion        De los temas que le voy a leer ¿Qué tan import...
# dimension                                 Buen Gobierno y Ciudadanía
# modulo                                          Concejo De La Ciudad
# respuestas         {'4': '4', '5': 'Muy importante', '2': '2', '9...
# tipo_respuestas                                           categorica
# ano_min                                                         2002
# ano_max                                                         2002
# Name: 1336, dtype: object)
# (1337, variable                                                      CC7D_4
# descripcion        De los temas que le voy a leer ¿qué tan import...
# dimension                                 Buen Gobierno y Ciudadanía
# modulo                                          Concejo De La Ciudad
# respuestas         {'4': '4', '5': 'Muy importante', '2': '2', '9...
# tipo_respuestas                                           categorica
# ano_min                                                         2002
# ano_max                                                         2002
# Name: 1337, dtype: object)
# (1338, variable                                                      CC7D_5
# descripcion        De los temas que le voy a leer ¿qué tan import...
# dimension                                 Buen Gobierno y Ciudadanía
# modulo                                          Concejo De La Ciudad
# respuestas         {'4': '4', '5': 'Muy importante', '2': '2', '9...
# tipo_respuestas                                           categorica
# ano_min                                                         2002
# ano_max                                                         2002
# Name: 1338, dtype: object)
# (1339, variable                                                      CC7E_1
# descripcion        De estos temas que le acabo de mencionar ¿cuál...
# dimension                                 Buen Gobierno y Ciudadanía
# modulo                                          Concejo De La Ciudad
# respuestas         {'92': 'No Sabe / No Responde', '1': 'Si', '2'...
# tipo_respuestas                                           categorica
# ano_min                                                         2002
# ano_max                                                         2002
# Name: 1339, dtype: object)
# (1340, variable                                                      CC7E_2
# descripcion        De estos temas que le acabo de mencionar ¿cuál...
# dimension                                 Buen Gobierno y Ciudadanía
# modulo                                          Concejo De La Ciudad
# respuestas         {'92': 'No Sabe / No Responde', '1': 'Si', '2'...
# tipo_respuestas                                           categorica
# ano_min                                                         2002
# ano_max                                                         2002
# Name: 1340, dtype: object)
# (1341, variable                                                      CC7E_3
# descripcion        De estos temas que le acabo de mencionar ¿cuál...
# dimension                                 Buen Gobierno y Ciudadanía
# modulo                                          Concejo De La Ciudad
# respuestas         {'92': 'No Sabe / No Responde', '1': 'Si', '2'...
# tipo_respuestas                                           categorica
# ano_min                                                         2002
# ano_max                                                         2002
# Name: 1341, dtype: object)
# (1342, variable                                                      CC7E_4
# descripcion        De estos temas que le acabo de mencionar ¿cuál...
# dimension                                 Buen Gobierno y Ciudadanía
# modulo                                          Concejo De La Ciudad
# respuestas         {'92': 'No Sabe / No Responde', '1': 'Si', '2'...
# tipo_respuestas                                           categorica
# ano_min                                                         2002
# ano_max                                                         2002
# Name: 1342, dtype: object)
# (1343, variable                                                      CC7E_5
# descripcion        De estos temas que le acabo de mencionar ¿cuál...
# dimension                                 Buen Gobierno y Ciudadanía
# modulo                                          Concejo De La Ciudad
# respuestas         {'92': 'No Sabe / No Responde', '1': 'Si', '2'...
# tipo_respuestas                                           categorica
# ano_min                                                         2002
# ano_max                                                         2002
# Name: 1343, dtype: object)
# (1344, variable                                                         CC7
# descripcion        ¿Sabe Usted que hay una Junta Administradora L...
# dimension                                 Buen Gobierno y Ciudadanía
# modulo                                          Concejo De La Ciudad
# respuestas         {'92': 'No Sabe / No Responde', '1': 'Sí sabe'...
# tipo_respuestas                                           categorica
# ano_min                                                         2009
# ano_max                                                         2014
# Name: 1344, dtype: object)
# (1345, variable                                                         CC8
# descripcion        ¿Conoce Usted el trabajo desarrollado por la J...
# dimension                                 Buen Gobierno y Ciudadanía
# modulo                                          Concejo De La Ciudad
# respuestas         {'92': 'No Sabe / No Responde', '1': 'Sí lo co...
# tipo_respuestas                                           categorica
# ano_min                                                         2009
# ano_max                                                         2014
# Name: 1345, dtype: object)
# (1346, variable                                                         CC9
# descripcion        ¿Conoce usted o había escuchado [HABLAR] antes...
# dimension                                 Buen Gobierno y Ciudadanía
# modulo                                          Concejo De La Ciudad
# respuestas         {'92': 'No Sabe / No Responde', '1': 'Sí', '2'...
# tipo_respuestas                                           categorica
# ano_min                                                         2013
# ano_max                                                         2014
# Name: 1346, dtype: object)
# (1347, variable                                                        CC9C
# descripcion        ¿Conoce usted o había escuchado [HABLAR] antes...
# dimension                                 Buen Gobierno y Ciudadanía
# modulo                                          Concejo De La Ciudad
# respuestas         {'90': 'Ninguno', '1': 'Ciudad Cómo Vamos', '2...
# tipo_respuestas                                           categorica
# ano_min                                                         2005
# ano_max                                                         2007
# Name: 1347, dtype: object)
# (1348, variable                                                        CC9A
# descripcion        ¿Conoce usted o había escuchado [HABLAR] antes...
# dimension                                 Buen Gobierno y Ciudadanía
# modulo                                          Concejo De La Ciudad
# respuestas         {'90': 'Ninguno', '1': 'Ciudad Cómo Vamos', '2...
# tipo_respuestas                                           categorica
# ano_min                                                         2005
# ano_max                                                         2007
# Name: 1348, dtype: object)
# (1349, variable                                                        CC10
# descripcion        ¿Cómo califica, en términos generales, la gest...
# dimension                                 Buen Gobierno y Ciudadanía
# modulo                                          Concejo De La Ciudad
# respuestas         {'9': 'Cámara de comercio', '95': 'Todos', '2'...
# tipo_respuestas                                           categorica
# ano_min                                                         2005
# ano_max                                                         2007
# Name: 1349, dtype: object)
# (1350, variable                                                        CC13
# descripcion        ¿Sabe Usted que hay representantes en el Congr...
# dimension                                 Buen Gobierno y Ciudadanía
# modulo                                          Concejo De La Ciudad
# respuestas         {'92': 'No Sabe / No Responde', '1': 'Si', '2'...
# tipo_respuestas                                           categorica
# ano_min                                                         2008
# ano_max                                                         2010
# Name: 1350, dtype: object)
# (1351, variable                                                       CC13A
# descripcion        ¿Los representantes en el Congreso de la Repúb...
# dimension                                 Buen Gobierno y Ciudadanía
# modulo                                          Concejo De La Ciudad
# respuestas         {'92': 'No Sabe / No Responde', '1': 'Sí están...
# tipo_respuestas                                           categorica
# ano_min                                                         2008
# ano_max                                                         2010
# Name: 1351, dtype: object)
# (1352, variable                                                       CC13B
# descripcion        ¿Qué tan insatisfecho(a) o satisfecho(a) está ...
# dimension                                 Buen Gobierno y Ciudadanía
# modulo                                          Concejo De La Ciudad
# respuestas         {'4': '4', '5': 'Muy satisfecho', '1': 'Muy in...
# tipo_respuestas                                           categorica
# ano_min                                                         2008
# ano_max                                                         2008
# Name: 1352, dtype: object)
# (1353, variable                                                        CC14
# descripcion        Pensando en las elecciones que se celebran en ...
# dimension                                 Buen Gobierno y Ciudadanía
# modulo                                          Concejo De La Ciudad
# respuestas         {'4': 'No voto nunca', '2': 'En la mayoría', '...
# tipo_respuestas                                           categorica
# ano_min                                                         2004
# ano_max                                                         2006
# Name: 1353, dtype: object)
# (1354, variable                                                       CC15A
# descripcion        Ya para terminar, y solamente con propósitos e...
# dimension                                 Buen Gobierno y Ciudadanía
# modulo                                          Concejo De La Ciudad
# respuestas         {'4': 'Presidente de la republica', '7': 'Conc...
# tipo_respuestas                                           categorica
# ano_min                                                         2005
# ano_max                                                         2006
# Name: 1354, dtype: object)
# (1355, variable                                                        CC16
# descripcion        ¿Cuál considera usted que debe ser la función ...
# dimension                                 Buen Gobierno y Ciudadanía
# modulo                                          Concejo De La Ciudad
# respuestas         {'4': '\tSeñalar los sectores, comunidades o t...
# tipo_respuestas                                           categorica
# ano_min                                                         2004
# ano_max                                                         2006
# Name: 1355, dtype: object)
# (1356, variable                                                        CC23
# descripcion        ¿La imagen que Usted tiene del Concejo de [CIU...
# dimension                                 Buen Gobierno y Ciudadanía
# modulo                                          Concejo De La Ciudad
# respuestas         {'4': 'El programa que busca reducir el tiempo...
# tipo_respuestas                                           categorica
# ano_min                                                         2000
# ano_max                                                         2000
# Name: 1356, dtype: object)
# (1357, variable                      TOTALP6D_1
# descripcion                          NaN
# dimension                          Extra
# modulo             Módulo De Desigualdad
# respuestas                           NaN
# tipo_respuestas                      NaN
# ano_min                             2005
# ano_max                             2005
# Name: 1357, dtype: object)
# (1358, variable                      TOTALP6D_2
# descripcion                          NaN
# dimension                          Extra
# modulo             Módulo De Desigualdad
# respuestas                           NaN
# tipo_respuestas                      NaN
# ano_min                             2005
# ano_max                             2005
# Name: 1358, dtype: object)
# (1359, variable                      TOTALP6D_3
# descripcion                          NaN
# dimension                          Extra
# modulo             Módulo De Desigualdad
# respuestas                           NaN
# tipo_respuestas                      NaN
# ano_min                             2005
# ano_max                             2005
# Name: 1359, dtype: object)
# (1360, variable                      TOTALP6D_4
# descripcion                          NaN
# dimension                          Extra
# modulo             Módulo De Desigualdad
# respuestas                           NaN
# tipo_respuestas                      NaN
# ano_min                             2005
# ano_max                             2005
# Name: 1360, dtype: object)
# (1361, variable                      TOTALP6D_5
# descripcion                          NaN
# dimension                          Extra
# modulo             Módulo De Desigualdad
# respuestas                           NaN
# tipo_respuestas                      NaN
# ano_min                             2005
# ano_max                             2005
# Name: 1361, dtype: object)
# (1362, variable                      TOTALP6D_6
# descripcion                          NaN
# dimension                          Extra
# modulo             Módulo De Desigualdad
# respuestas                           NaN
# tipo_respuestas                      NaN
# ano_min                             2005
# ano_max                             2005
# Name: 1362, dtype: object)
# (1363, variable                      TOTALP6D_7
# descripcion                          NaN
# dimension                          Extra
# modulo             Módulo De Desigualdad
# respuestas                           NaN
# tipo_respuestas                      NaN
# ano_min                             2005
# ano_max                             2005
# Name: 1363, dtype: object)
# (1364, variable                      TOTALP6D_8
# descripcion                          NaN
# dimension                          Extra
# modulo             Módulo De Desigualdad
# respuestas                           NaN
# tipo_respuestas                      NaN
# ano_min                             2005
# ano_max                             2005
# Name: 1364, dtype: object)
# (1365, variable                    TOTALP6D_HOM
# descripcion                          NaN
# dimension                          Extra
# modulo             Módulo De Desigualdad
# respuestas                           NaN
# tipo_respuestas                      NaN
# ano_min                             2005
# ano_max                             2005
# Name: 1365, dtype: object)
# (1366, variable                    TOTALP6D_MUJ
# descripcion                          NaN
# dimension                          Extra
# modulo             Módulo De Desigualdad
# respuestas                           NaN
# tipo_respuestas                      NaN
# ano_min                             2005
# ano_max                             2005
# Name: 1366, dtype: object)

# %%
for i, indicadores in diccionario_objetivos.iterrows():
    print(indicadores["id"])
    print(indicadores["Indicador"])
    print(indicadores["anillo"])
    type("objetivo")
# Out:
# 0-PO-1
# Indice de Envejecimiento Hombres
# Escenarios Transversales
# 0-PO-12
# Extensión territorial área hectáreas
# Escenarios Transversales
# 0-PO-13
# Extensión territorial área km2
# Escenarios Transversales
# 0-PO-14
# Indice de envejecimiento
# Escenarios Transversales
# 0-PO-2
# Indice de Envejecimiento Mujeres
# Escenarios Transversales
# 0-PO-23
# Población Hombres
# Escenarios Transversales
# 0-PO-25
# Población Mujeres
# Escenarios Transversales
# 0-PO-27
# Población Total
# Escenarios Transversales
# 0-PO-28
# Porcentaje de Población Afrodescendientes
# Escenarios Transversales
# 0-PO-29
# Porcentaje de población en el área Urbana
# Escenarios Transversales
# 0-PO-3
# Densidad poblacional por Km
# Escenarios Transversales
# 0-PO-30
# Porcentaje de Población Indígena
# Escenarios Transversales
# 0-PO-34
# Relación de Dependencia
# Escenarios Transversales
# 0-PO-36
# Tasa de crecimiento de la población
# Escenarios Transversales
# 0-PO-37
# Tasa de Dependencia Hombres
# Escenarios Transversales
# 0-PO-38
# Tasa de Dependencia Mujeres
# Escenarios Transversales
# 0-PO-4
# El lugar donde habita es propio con permiso del propietario
# Escenarios Transversales
# 0-PO-5
# El lugar donde habita es propio y se esta pagando
# Escenarios Transversales
# 0-PO-6
# El lugar en donde habita es en arriendo
# Escenarios Transversales
# 0-PO-7
# El lugar en donde habita es propio totalmente pagado
# Escenarios Transversales
# 0-PO-8
# Esperanza de vida al nacer
# Escenarios Transversales
# 0-PO-9
# Esperanza de vida al nacer Mujeres
# Escenarios Transversales
# 0-PD-11
# Índice de condiciones de vida ICV
# Escenarios Transversales
# 0-PD-16
# Índice de Desarrollo Humano Urbano
# Escenarios Transversales
# 0-PD-17
# Índice de Pobreza Multidimensional
# Escenarios Transversales
# 0-PD-18
# Índice de Pobreza Multidimensional Multipropósito
# Escenarios Transversales
# 0-PD-21
# Población bajo la línea de indigencia
# Escenarios Transversales
# 0-PD-22
# Población bajo la línea de indigencia 13 AM
# Escenarios Transversales
# 0-PD-23
# Población bajo la línea de indigencia GEIH
# Escenarios Transversales
# 0-PD-24
# Población bajo la línea de pobreza
# Escenarios Transversales
# 0-PD-25
# Población bajo la línea de pobreza 13 AM
# Escenarios Transversales
# 0-PD-26
# Población bajo la línea de pobreza GEIH
# Escenarios Transversales
# 0-PD-27
# Porcentaje de familias promovidas en el programa Unidos
# Escenarios Transversales
# 0-PD-3
# Coeficiente de Gini Bogotá Multipróposito
# Escenarios Transversales
# 0-PD-32
# Tasa de cobertura del programa Unidos
# Escenarios Transversales
# 0-PD-33
# Tasa de trabajo infantil
# Escenarios Transversales
# 0-PD-34
# Tasa de trabajo infantil ampliado
# Escenarios Transversales
# 0-PD-37
# Variación porcentual en el Ingreso promedio del hogar
# Escenarios Transversales
# 0-PD-4
# coeficiente de Gini de los ingresos
# Escenarios Transversales
# 0-PD-5
# El lugar donde habita es en tenencia o posesión
# Escenarios Transversales
# 0-PD-6
# Incidencia pobreza monetaria
# Escenarios Transversales
# 0-PD-7
# Incidencia pobreza monetaria extrema
# Escenarios Transversales
# 1-SA-100
# Porcentaje de desnutrición crónica en menores de 5 años
# Activos de las personas
# 1-SA-105
# Porcentaje de nacimientos en adolescentes de 10 a 14 años
# Activos de las personas
# 1-SA-108
# Porcentaje de personas vinculadas pero no afiliadas
# Activos de las personas
# 1-SA-111
# Porcentaje de población que requirió el servicio de salud y accedió al mismo
# Activos de las personas
# 1-SA-115
# Prevalencia de bajo peso al nacer
# Activos de las personas
# 1-SA-145
# Razón de mortalidad materna x 100.000 NV
# Activos de las personas
# 1-SA-168
# Tasa de  (AVPP) por afecciones del periodo neonatal
# Activos de las personas
# 1-SA-169
# Tasa de  (AVPP) por causas externas.
# Activos de las personas
# 1-SA-17
# Cinco primeras causas de morbilidad atendida en consulta externa red adscrita
# Activos de las personas
# 1-SA-170
# Tasa de  (AVPP) por enfermedades del sistema circulatorio
# Activos de las personas
# 1-SA-171
# Tasa de  (AVPP) por enfermedades Transmisibles
# Activos de las personas
# 1-SA-172
# Tasa de  (AVPP) por neoplasias
# Activos de las personas
# 1-SA-173
# Tasa de desnutrición global para menores de 5 años (prevalencia)
# Activos de las personas
# 1-SA-18
# Cinco primeras causas de morbilidad atendida en consulta externa red NO adscrita
# Activos de las personas
# 1-SA-181
# Tasa de mortalidad en menores de 1 año
# Activos de las personas
# 1-SA-182
# Tasa de mortalidad en menores de 5 años
# Activos de las personas
# 1-SA-183
# Tasa de mortalidad general
# Activos de las personas
# 1-SA-184
# Tasa de mortalidad infantil (menores de un año)
# Activos de las personas
# 1-SA-185
# Tasa de mortalidad materna
# Activos de las personas
# 1-SA-187
# Tasa de mortalidad perinatal por 1.000 nacidos vivos
# Activos de las personas
# 1-SA-188
# Tasa de mortalidad por cáncer de cuello uterino x 100000
# Activos de las personas
# 1-SA-189
# Tasa de mortalidad por desnutrición en menores de 5 años (por 100 mil menores de 5 años)
# Activos de las personas
# 1-SA-19
# Cinco principales causas de mortalidad
# Activos de las personas
# 1-SA-199
# Tasa de mortalidad por neumonía por 100.000 menores de cinco años
# Activos de las personas
# 1-SA-20
# Cobertura al régimen contributivo
# Activos de las personas
# 1-SA-21
# Cobertura al régimen especial
# Activos de las personas
# 1-SA-22
# Cobertura de población afiliada al régimen subsidiado en total de la población
# Activos de las personas
# 1-SA-24
# Cobertura de vacunación con anti influenzae tipo B en menores de un año
# Activos de las personas
# 1-SA-25
# Cobertura de vacunación con antipolio en menores de un año
# Activos de las personas
# 1-SA-26
# Cobertura de vacunación con BCG en niños menores de un año
# Activos de las personas
# 1-SA-27
# Cobertura de vacunación contra fiebre amarilla en niños de un año de edad
# Activos de las personas
# 1-SA-28
# Cobertura de vacunación contra hepatitis B en menores de un año
# Activos de las personas
# 1-SA-29
# Cobertura de vacunación DPT
# Activos de las personas
# 1-SA-35
# Cobertura de vacunación triple viral (T.V)
# Activos de las personas
# 1-SA-36
# Cobertura en aseguramiento
# Activos de las personas
# 1-SA-38
# Cobertura en vacunación  DTP tercera dosis (menores de un año)
# Activos de las personas
# 1-SA-39
# Cobertura en vacunación TV (un año)
# Activos de las personas
# 1-SA-43
# Cobertura en vacunación, en menores de un año y un año  Hepatitis B
# Activos de las personas
# 1-SA-47
# Consumo de sustancias psicoactivas
# Activos de las personas
# 1-SA-5
# Camas hospitalarias por cada 1000 habitantes
# Activos de las personas
# 1-SA-63
# Incidencia del VIH * 100,000 hab
# Activos de las personas
# 1-SA-65
# La Tasa de Morbilidad por Enfermedad Diarreica Aguda (EDA) en Menores de 5 años (tasa por mil menores de 5años)
# Activos de las personas
# 1-SA-66
# Mediana de lactancia materna
# Activos de las personas
# 1-SA-67
# Mortalidad por cáncer de mama (número de casos)
# Activos de las personas
# 1-SA-77
# N de ambulancias habilitadas en la ciudad
# Activos de las personas
# 1-SA-82
# Nacimientos en adolescentes de 10 a 14 años
# Activos de las personas
# 1-SA-83
# Nacimientos en adolescentes de 15 a 19 años
# Activos de las personas
# 1-SA-90
# Número de personas afiliadas al régimen subsidiado (Subsidio pleno)
# Activos de las personas
# 1-ED-11
# Años promedio de educación población de 15 a 24 años
# Activos de las personas
# 1-ED-12
# Cobertura neta en educación inicial (prejardin y jardín)
# Activos de las personas
# 1-ED-124
# resultados prueba saber 11
# Activos de las personas
# 1-ED-131
# Tasa  de Deserción para el Sector Privado Preescolar
# Activos de las personas
# 1-ED-132
# Tasa  de Deserción para el Sector Privado Primaria
# Activos de las personas
# 1-ED-133
# Tasa  de Deserción para el Sector Privado Secundaria
# Activos de las personas
# 1-ED-134
# Tasa bruta de cobertura en media vocacional
# Activos de las personas
# 1-ED-135
# Tasa bruta de cobertura Preescolar (5 años)
# Activos de las personas
# 1-ED-136
# Tasa de analfabetismo de 15 a 24 años
# Activos de las personas
# 1-ED-140
# Tasa de aprobación oficial media
# Activos de las personas
# 1-ED-141
# Tasa de aprobación oficial preescolar
# Activos de las personas
# 1-ED-142
# Tasa de aprobación oficial primaria
# Activos de las personas
# 1-ED-143
# Tasa de aprobación oficial secundaria
# Activos de las personas
# 1-ED-144
# Tasa de aprobación oficial total
# Activos de las personas
# 1-ED-145
# Tasa de Aprobación para el Sector Privado nivel media
# Activos de las personas
# 1-ED-146
# Tasa de Aprobación para el Sector Privado nivel Preescolar
# Activos de las personas
# 1-ED-147
# Tasa de Aprobación para el Sector Privado nivel Primaria
# Activos de las personas
# 1-ED-148
# Tasa de Aprobación para el Sector Privado nivel Secundaria
# Activos de las personas
# 1-ED-149
# Tasa de Aprobación Total Sector Privado
# Activos de las personas
# 1-ED-151
# Tasa de cobertura bruta en educación universitaria
# Activos de las personas
# 1-ED-154
# Tasa de cobertura Bruta en Primaria
# Activos de las personas
# 1-ED-155
# Tasa de cobertura Bruta en Secundaria
# Activos de las personas
# 1-ED-158
# Tasa de cobertura neta en básica secundaria
# Activos de las personas
# 1-ED-159
# Tasa de cobertura neta en Media
# Activos de las personas
# 1-ED-160
# Tasa de cobertura neta en preescolar
# Activos de las personas
# 1-ED-162
# Tasa de cobertura neta en Primaria
# Activos de las personas
# 1-ED-163
# Tasa de cobertura neta en Secundaria
# Activos de las personas
# 1-ED-166
# Tasa de deserción educación media
# Activos de las personas
# 1-ED-167
# Tasa de deserción educación preescolar pública
# Activos de las personas
# 1-ED-168
# Tasa de deserción educación preescolar, básica primaria, básica secundaria y media vocacional privada
# Activos de las personas
# 1-ED-169
# Tasa de deserción educación preescolar, básica primaria, básica secundaria y media vocacional pública
# Activos de las personas
# 1-ED-170
# Tasa de deserción educación primaria pública
# Activos de las personas
# 1-ED-171
# Tasa de deserción educación secundaria
# Activos de las personas
# 1-ED-173
# Tasa de deserción escolar - sector público
# Activos de las personas
# 1-ED-179
# Tasa de repetencia en media para sector privado
# Activos de las personas
# 1-ED-182
# Tasa de repitencia en básica primaria, básica
# Activos de las personas
# 1-ED-183
# Tasa de repitencia en preescolar para sector privado
# Activos de las personas
# 1-ED-184
# Tasa de repitencia en primaria para sector privado
# Activos de las personas
# 1-ED-185
# Tasa de repitencia en secundaria para sector privado
# Activos de las personas
# 1-ED-186
# Tasa de repitencia media pública
# Activos de las personas
# 1-ED-187
# Tasa de repitencia preescolar pública
# Activos de las personas
# 1-ED-188
# Tasa de repitencia primaria pública
# Activos de las personas
# 1-ED-189
# Tasa de repitencia secundaria pública
# Activos de las personas
# 1-ED-191
# Tasa de reprobación del sector oficial media
# Activos de las personas
# 1-ED-192
# Tasa de reprobación del sector oficial preescolar
# Activos de las personas
# 1-ED-193
# Tasa de reprobación del sector oficial primaria
# Activos de las personas
# 1-ED-194
# Tasa de reprobación del sector oficial secundaria
# Activos de las personas
# 1-ED-195
# Tasa de reprobación del sector oficial total
# Activos de las personas
# 1-ED-196
# Tasa global de cobertura bruta en educación
# Activos de las personas
# 1-ED-198
# Tasa global de cobertura neta en educación
# Activos de las personas
# 1-ED-200
# Tasa global de participación
# Activos de las personas
# 1-ED-201
# Tasa global de participación Multipropósito
# Activos de las personas
# 1-ED-25
# Matricula oficial primera infancia grado jardín
# Activos de las personas
# 1-ED-26
# Matricula oficial primera infancia grado prejardín
# Activos de las personas
# 1-ED-27
# Matricula oficial primera infancia grado transición
# Activos de las personas
# 1-ED-28
# Matricula oficial primera infancia total
# Activos de las personas
# 1-ED-29
# Matricula privada primera infancia grado jardín
# Activos de las personas
# 1-ED-30
# Matricula privada primera infancia grado prejardín
# Activos de las personas
# 1-ED-31
# Matricula Privada primera infancia grado transición
# Activos de las personas
# 1-ED-32
# Matricula Privada primera infancia total
# Activos de las personas
# 1-ED-42
# Número de estudiantes matriculados en carreras
# Activos de las personas
# 1-ED-45
# Población en edad escolar de 5 a 16 años
# Activos de las personas
# 1-ED-46
# Porcentaje de colegios NO oficiales en categoría medio, bajo, inferior y muy inferior en la prueba SABER 11.
# Activos de las personas
# 1-ED-47
# Porcentaje de colegios oficiales en categoría medio, bajo, inferior y muy inferior en la prueba SABER 11.
# Activos de las personas
# 1-ED-48
# Porcentaje de estudiantes de 11° con dominio del inglés con nivel B1 o B+
# Activos de las personas
# 1-ED-52
# Porcentaje de estudiantes de 5º con un nivel avanzado o satisfactorio en las pruebas estandarizadas nacionales de lenguaje
# Activos de las personas
# 1-ED-53
# Porcentaje de estudiantes de 5º con un nivel avanzado o satisfactorio en las pruebas estandarizadas nacionales de matemáticas
# Activos de las personas
# 1-ED-54
# Porcentaje de estudiantes de 9º con un nivel avanzado o satisfactorio en las pruebas estandarizadas nacionales de lenguaje
# Activos de las personas
# 1-ED-55
# Porcentaje de estudiantes de 9º con un nivel avanzado o satisfactorio en las pruebas estandarizadas nacionales de matemáticas
# Activos de las personas
# 1-ED-56
# Porcentaje de los colegios en concesión clasificados en "C " y "D" por rendimiento en las pruebas de Estado SABER 11
# Activos de las personas
# 1-ED-57
# Porcentaje de los colegios en Conseción clasificados en "A+ " y "A" por rendimiento en las pruebas de Estado SABER 11
# Activos de las personas
# 1-ED-58
# Porcentaje de los colegios en Conseción clasificados en "B" por rendimiento en las pruebas de Estado SABER 11
# Activos de las personas
# 1-ED-59
# Porcentaje de los colegios en Convenio clasificados en "A+ " y "A" por rendimiento en las pruebas de Estado SABER 11
# Activos de las personas
# 1-ED-60
# Porcentaje de los colegios en Convenio clasificados en "B" por rendimiento en las pruebas de Estado SABER 11
# Activos de las personas
# 1-ED-61
# Porcentaje de los colegios en Convenio clasificados en "C " y "D" por rendimiento en las pruebas de Estado SABER 11
# Activos de las personas
# 1-ED-62
# Porcentaje de los colegios NO oficiales clasificados en "C " y "D" por rendimiento en las pruebas de Estado SABER 11
# Activos de las personas
# 1-ED-63
# Porcentaje de los colegios NO oficiales clasificados en categoría "B" por rendimiento en las pruebas de Estado SABER 11
# Activos de las personas
# 1-ED-64
# Porcentaje de los colegios NO oficiales clasificados en las categorías "A+" y "A" por rendimiento en las pruebas de Estado SABER 11
# Activos de las personas
# 1-ED-65
# Porcentaje de los colegios NO oficiales clasificados en las categorías alto, superior y muy superior por rendimiento en las pruebas de Estado SABER 11
# Activos de las personas
# 1-ED-66
# Porcentaje de los colegios oficiales clasificados en "B " por rendimiento en las pruebas de Estado SABER 11
# Activos de las personas
# 1-ED-67
# Porcentaje de los colegios oficiales clasificados en "C " y "D" por rendimiento en las pruebas de Estado SABER 11
# Activos de las personas
# 1-ED-68
# Porcentaje de los colegios oficiales clasificados en las categorías "A+ "y "A" por rendimiento en las pruebas de Estado SABER 11
# Activos de las personas
# 1-ED-69
# Porcentaje de los colegios oficiales clasificados en las categorías alto, superior y muy superior por rendimiento en las pruebas de Estado SABER 11
# Activos de las personas
# 1-ED-70
# Porcentaje de los colegios oficiales EN CONCESIÓN clasificados en las categorías alto, superior y muy superior por rendimiento en las pruebas de Estado SABER 11
# Activos de las personas
# 1-ED-71
# Porcentaje de los colegios oficiales EN CONVENIO clasificados en las categorías alto, superior y muy superior por rendimiento en las pruebas de Estado SABER 11
# Activos de las personas
# 1-ED-84
# Puntaje promedio de los colegios distritales en  las pruebas de Estado (inglés)
# Activos de las personas
# 1-ED-85
# Puntaje promedio de los colegios distritales en  las pruebas de Estado (lenguaje)
# Activos de las personas
# 1-ED-86
# Puntaje promedio de los colegios distritales en  las pruebas de Estado (matemáticas)
# Activos de las personas
# 1-ED-87
# Puntaje promedio de los resultados de las pruebas SABER en ciencias naturales del grado 5to en los colegios distritales
# Activos de las personas
# 1-ED-88
# Puntaje promedio de los resultados de las pruebas SABER en ciencias naturales del grado 9 en los colegios distritales
# Activos de las personas
# 1-ED-91
# Puntaje promedio de los resultados de las pruebas SABER en lenguaje del grado 5to en los colegios distritales
# Activos de las personas
# 1-ED-92
# Puntaje promedio de los resultados de las pruebas SABER en lenguaje del grado 9 en los colegios distritales
# Activos de las personas
# 1-ED-93
# Puntaje promedio de los resultados de las pruebas SABER en matemáticas del grado 5to en los colegios distritales
# Activos de las personas
# 1-ED-94
# Puntaje promedio de los resultados de las pruebas SABER en matemáticas del grado 9 en los colegios distritales
# Activos de las personas
# 1-ED-95
# Puntaje promedio de los resultados de las pruebas SABER en PENSAMIENTO CIUDADANO del grado 5to  en los colegios distritales
# Activos de las personas
# 1-ED-96
# Puntaje promedio de los resultados de las pruebas SABER en PENSAMIENTO CIUDADANO del grado 9  en los colegios distritales
# Activos de las personas
# 1-ED-98
# Relación Alumndo docente
# Activos de las personas
# 1-ML-41
# Tasa de desempleo
# Activos de las personas
# 1-ML-46
# Tasa de desempleo juvenil (15  25 años)
# Activos de las personas
# 1-ML-49
# Tasa de informalidad
# Activos de las personas
# 1-ML-51
# Tasa de ocupación
# Activos de las personas
# 1-ML-53
# Tasa de subempleo objetivo
# Activos de las personas
# 1-ML-55
# Tasa global de participacion
# Activos de las personas
# 1-ML-59
# Tasa de Desempleo Multipropósito
# Activos de las personas
# 1-ML-60
# Tasa de desempleo Jefes de hogar
# Activos de las personas
# 1-ML-61
# Tasa de desempleo Jefes de hogar Multipropósito
# Activos de las personas
# 1-SC-134
# Hurto residencias
# Activos de las personas
# 1-SC-137
# Hurtos de bancos
# Activos de las personas
# 1-SC-161
# Indice de intensidad (expulsión) del desplazamiento forzado
# Activos de las personas
# 1-SC-223
# Número de accidentes de tránsito
# Activos de las personas
# 1-SC-237
# Número de homicidios
# Activos de las personas
# 1-SC-293
# Número de lesiones personales
# Activos de las personas
# 1-SC-296
# Número de Secuestros
# Activos de las personas
# 1-SC-314
# Porcentaje de ciudadanos que fue extorsionado o lo han intentado extorsionar
# Activos de las personas
# 1-SC-315
# Porcentaje de ciudadanos que fueron víctimas de algún delito y denunciaron el hecho
# Activos de las personas
# 1-SC-317
# Porcentaje de ciudadanos que se sienten seguros o muy seguros en la ciudad
# Activos de las personas
# 1-SC-319
# Porcentaje de la población que fue víctima de un delito en los últimos 12 meses
# Activos de las personas
# 1-SC-320
# Porcentaje de victimas de hurto a personas en la vía pública
# Activos de las personas
# 1-SC-338
# Suicidios
# Activos de las personas
# 1-SC-339
# Tasa de adolescentes capturados por cada mil adolescentes (14 a 17 años)
# Activos de las personas
# 1-SC-351
# Tasa de homicidios de personas entre 15 y 24 años de edad
# Activos de las personas
# 1-SC-353
# Tasa de Homicidios por cada 100 mil habitantes
# Activos de las personas
# 1-SC-355
# Tasa de hurto a automóviles
# Activos de las personas
# 1-SC-356
# Tasa de Hurto a personas
# Activos de las personas
# 1-SC-357
# Tasa de hurto de motocicletas
# Activos de las personas
# 1-SC-358
# Tasa de lesiones personales
# Activos de las personas
# 1-SC-368
# Tasa Hurto a residencias
# Activos de las personas
# 1-SC-402
# Número de adolescentes que ingresan al Sistema de Responsabilidad Penal para Adolescentes
# Activos de las personas
# 1-SC-403
# Tasa de muertes violentas por 100.000 habitantes
# Activos de las personas
# 1-SC-404
# Tasa de suicidios por 100.000 habitantes
# Activos de las personas
# 1-SC-405
# Victimización  directa
# Activos de las personas
# 1-SC-406
# Denuncia
# Activos de las personas
# 1-SC-407
# Percepción de inseguridad
# Activos de las personas
# 1-SC-408
# Tasa de habitantes de calle por 10.000 habitantes
# Activos de las personas
# 1-SC-409
# Tasa de homicidios por 100.000 habitantes
# Activos de las personas
# 1-SC-410
# Tasa de hurto de vehículos
# Activos de las personas
# 1-SC-411
# Número de hurtos a personas
# Activos de las personas
# 1-SC-412
# Tasa de lesiones Personales MUJERES
# Activos de las personas
# 1-SC-413
# Tasa de lesiones Personales HOMBRES
# Activos de las personas
# 1-SC-414
# Número de hurtos a vehículos
# Activos de las personas
# 1-SC-415
# Tasa de hurto a bancos
# Activos de las personas
# 1-SC-416
# Número de hurto a establecimientos de comercio
# Activos de las personas
# 1-SC-417
# Tasa de hurto a establecimientos de comercio
# Activos de las personas
# 2-MO-131
# Número de intersecciones semaforizadas
# Hábitat Urbano
# 2-MO-285
# Tasa de morbilidad en accidentes de tránsito por cada 100.000 habitantes
# Hábitat Urbano
# 2-MO-286
# Tasa de mortalidad en accidentes de tránsito por cada 100.000 habitantes
# Hábitat Urbano
# 2-MO-287
# Tasa de morbilidad en accidentes de transito x 10.000 vehículos
# Hábitat Urbano
# 2-MO-288
# Tasa de mortalidad en accidentes de transito x 10.000 vehiculos
# Hábitat Urbano
# 2-MO-289
# Víctimas fatales en accidentes de transito
# Hábitat Urbano
# 2-MO-290
# Mujeres victimas fatales de accidentes de tránsito
# Hábitat Urbano
# 2-MO-291
# Hombres victimas fatales de accidentes de tránsito
# Hábitat Urbano
# 2-MO-292
# Víctimas fatales por condición (peatones)
# Hábitat Urbano
# 2-MO-293
# Víctimas fatales por condición (motociclistas)
# Hábitat Urbano
# 2-MO-294
# Víctimas fatales por condición (pasajeros)
# Hábitat Urbano
# 2-MO-295
# Víctimas fatales por condición (conductores)
# Hábitat Urbano
# 2-MO-296
# Víctimas fatales por condición (ciclistas)
# Hábitat Urbano
# 2-MO-297
# Número total de accidentes totales en el SITP
# Hábitat Urbano
# 2-MO-298
# Número total de accidentes totales en el sistema Transmilenio.
# Hábitat Urbano
# 2-MO-299
# Comparendos por infracción no vehicular
# Hábitat Urbano
# 2-MO-300
# Comparendos por infracción peatonal
# Hábitat Urbano
# 2-MO-301
# Comparendos por infracción vehicular
# Hábitat Urbano
# 2-MO-302
# Comparendos por infracción tecnico mecanica
# Hábitat Urbano
# 2-MO-303
# Comparendos por infracción operativos emisiones
# Hábitat Urbano
# 2-MO-304
# Tiempo promedio de desplazamiento de las personas en la ciudad (minutos)
# Hábitat Urbano
# 2-MO-305
# Tiempo total de viaje TPC
# Hábitat Urbano
# 2-MO-306
# Tiempo total de viaje Transmilenio
# Hábitat Urbano
# 2-MO-307
# Tiempo total de viaje Alimentadores
# Hábitat Urbano
# 2-MO-308
# Tiempo total de viaje Taxi
# Hábitat Urbano
# 2-MO-309
# Tiempo total de viaje Moto
# Hábitat Urbano
# 2-MO-310
# Tiempo total de viaje Particular
# Hábitat Urbano
# 2-MO-311
# Tiempo total de viaje Bicicleta
# Hábitat Urbano
# 2-MO-312
# Tiempo total de viaje A pie
# Hábitat Urbano
# 2-MO-313
# Estado de la malla vial bueno
# Hábitat Urbano
# 2-MO-314
# Estado de la malla vial malo
# Hábitat Urbano
# 2-MO-315
# Estado de la malla vial regular
# Hábitat Urbano
# 2-MO-316
# Estado de la malla vial ARTERIAL bueno
# Hábitat Urbano
# 2-MO-317
# Estado de la malla vial ARTERIAL regular
# Hábitat Urbano
# 2-MO-318
# Estado de la malla vial ARTERIAL malo
# Hábitat Urbano
# 2-MO-319
# Estado de la malla vial INTERMEDIA bueno
# Hábitat Urbano
# 2-MO-320
# Estado de la malla vial INTERMEDIA regular
# Hábitat Urbano
# 2-MO-321
# Estado de la malla vial INTERMEDIA malo
# Hábitat Urbano
# 2-MO-322
# Estado de la malla vial LOCAL bueno
# Hábitat Urbano
# 2-MO-323
# Estado de la malla vial LOCAL regular
# Hábitat Urbano
# 2-MO-324
# Estado de la malla vial LOCAL malo
# Hábitat Urbano
# 2-MO-325
# Recuperación de la malla vial (km anuales recuperados)
# Hábitat Urbano
# 2-MO-326
# Porcentaje de personas que se moviliza principalmente a pie
# Hábitat Urbano
# 2-MO-327
# Porcentaje de personas que se moviliza principalmente en Transmilenio
# Hábitat Urbano
# 2-MO-328
# Porcentaje de personas que se moviliza principalmente en Buses rojos o azules del SITP
# Hábitat Urbano
# 2-MO-329
# Porcentaje de personas que se moviliza principalmente en bus, buseta o colectivo
# Hábitat Urbano
# 2-MO-330
# Porcentaje de personas que se moviliza principalmente en carro particular
# Hábitat Urbano
# 2-MO-331
# Porcentaje de personas que se moviliza principalmente en  taxi
# Hábitat Urbano
# 2-MO-332
# Porcentaje de personas que se moviliza principalmente en  bici-taxi
# Hábitat Urbano
# 2-MO-333
# Porcentaje de personas que se moviliza principalmente en  moto
# Hábitat Urbano
# 2-MO-334
# Porcentaje de personas que se moviliza principalmente en  bicicleta
# Hábitat Urbano
# 2-MO-335
# Pasajeros diarios movilizados por transporte público masivo (Transmilenio)
# Hábitat Urbano
# 2-MO-336
# Promedio de pasajeros en hora pico en Transmilenio
# Hábitat Urbano
# 2-MO-337
# Número total de pasajeros interurbanos transportados integrados a Transmilenio
# Hábitat Urbano
# 2-MO-338
# Promedio anual de velocidad en transporte público (km/hora).
# Hábitat Urbano
# 2-MO-339
# Promedio anual de velocidad de transporte individual (taxi) (km/hora).
# Hábitat Urbano
# 2-MO-340
# Promedio anual de velocidad particular (km/hora).
# Hábitat Urbano
# 2-MO-341
# Velocidad promedio de recorrido en el SITP
# Hábitat Urbano
# 2-MO-342
# Velocidad promedio de recorrido en Transmilenio
# Hábitat Urbano
# 2-MO-343
# Muertes en el sistema Transmilenio
# Hábitat Urbano
# 2-MO-344
# Heridos en el sistema Transmilenio
# Hábitat Urbano
# 2-MO-345
# Cobertura de ciclo rutas
# Hábitat Urbano
# 2-MO-346
# Cobertura Bici-carril
# Hábitat Urbano
# 2-MO-347
# Total infraestrutura para bicicletas (Ciclorutas, Bici-carril, ciclobarrio)
# Hábitat Urbano
# 2-MO-348
# Cobertura carril bici
# Hábitat Urbano
# 2-MO-349
# Parque automotor de transporte particular (automovil, campero y camioneta)
# Hábitat Urbano
# 2-MO-350
# Parque automotor de transporte particular (motocicletas)
# Hábitat Urbano
# 2-MO-351
# Parque automotor de transporte público
# Hábitat Urbano
# 2-MO-352
# Charratización buses, busetas y microbusetas
# Hábitat Urbano
# ANIO
# AÑO
# nan
# CIUDAD
# CIUDAD
# nan
# LOCALIDAD
# LOCALIDAD
# nan

# %%
import json

output_dict = {}
responses_by_variable = {}
print(diccionario_subjetivos.columns.values)

for i, encuesta in diccionario_subjetivos.iterrows():
    print(encuesta["variable"])
    print(encuesta["descripcion"])
    print(encuesta["dimension"])
    print(encuesta["respuestas"])
    print(encuesta["tipo_respuestas"])
    try:
        midstring_switch = str(encuesta["respuestas"]).replace("': '","MIDSTRINGSIGNAL")
        endstring_switch = midstring_switch.replace("', '", "ENDOFSTRINGSIGNAL")
        quote_removal = endstring_switch.replace("'","")
        double_quote_removal = quote_removal.replace('"',"")
        midstring_backinplace = double_quote_removal.replace("MIDSTRINGSIGNAL","': '")
        endstring_backinplace = midstring_backinplace.replace("ENDOFSTRINGSIGNAL","', '")
        doublequote_addition = "{'"+str(endstring_backinplace[1:-1])+"'}"
        switch_quote_type= doublequote_addition.replace("'",'"')
        responses_by_variable[encuesta["variable"]] = json.loads(switch_quote_type)
    except:
        responses_by_variable[encuesta["variable"]] = {0: "nan"}
# Out:
# ['variable' 'descripcion' 'dimension' 'modulo' 'respuestas'
#  'tipo_respuestas' 'ano_min' 'ano_max']
# CR1H
# Cuando usted va a - Ferias generalmente paga o asiste gratis.
# Buen Gobierno y Ciudadanía
# {'9': 'Visitar museos/ galerías/ bibliotecas[/ CASAS CULTURALES]', '117': 'Conciertos de música colombiana y de cámara realizados en la sala oriol rangel', '101': 'Oír música', '2': 'Cine', '94': 'Cualquiera', '22': 'Navegar por internet', '51': 'Fiestas Culturales', '97': 'Ningún otro', '104': 'Club deportivo', '109': 'Festival de salsa al parque', '107': 'Festival colombia al parque - música y danza tradicional', '79': 'Parque cultural del caribe', '4': 'Ferias y exposiciones', '125': 'Festival de verano', '66': 'Septimazo', '16': 'Religiosas/misas', '124': 'Ciclovía dominical', '85': 'Zoológicos', '8': 'Carnaval', '60': 'Semana Santa en Yumbo', '54': 'Encuentro Nacional de teatro', '44': 'Visitar Centros Comerciales', '77': 'Viajes turísticos', '75': 'Concurso nacional de belleza', '84': 'Exposiciones/Pintura', '106': 'Minga - encuentro de culturas y saberes indígenas', '119': 'Ciclo conciertos didácticos para niños', '70': 'Viajes', '23': 'Feria de las flores', '59': 'Encuentro Nacional de Música Colombiana', '93': 'No responde', '82': 'Participar de turismo ecológico', '95': 'Todos', '19': 'Ver películas de vídeo', '105': 'Jugar Billar', '13': 'Festivales 'Al Parque' como Rock al Parque, Jazz al Parque, etc.', '7': 'Tertulias', '6': 'Festivales [POPULARES]', '67': 'Ir a los restaurantes', '71': 'Iglesia', '68': 'Hacer ejercicio/actividades deportivas', '116': 'Conciertos con solistas, orquestas, bandas, coros en el clásico domingo el último domingo de cada mes', '118': 'Conciertos de géneros fusión llamados tortazos', '65': 'Baila/Sale a bailar', '55': 'Semana de la municipalidad', '76': 'Fiestas de la independencia', '52': 'Desfiles', '110': 'Carnaval de la diversidad – desfile de comparsas', '18': 'Visita al zoológico de Barranquilla', '100': 'Ver televisión', '49': 'Festividades populares', '21': 'Ver deportes', '78': 'Jugar dominó', '40': 'Ir a parques', '72': 'Eventos recreativos', '91': 'No Recuerda', '83': 'Investigaciones por internet', '69': 'Ver tv/escuchar música', '103': 'Actividades de campo (Pesca, Rio)', '15': 'Parques de recreación', '112': 'Festival de hip-hop al parque', '126': 'Lunadas metropolitanas', '46': 'Ir a piscinas', '123': 'Colón electrónico', '17': 'Futbol', '10': 'Leer libros//Programas de lectura y lectoescritura', '127': 'Festival de navidad', '102': 'Festivales', '80': 'Ir al río / Visita al Río Guatapurí', '61': 'Semana del idioma', '5': 'Conferencias', '115': 'Conciertos de invitados nacionales e internacionales en el ciclo media torta latinoamericana', '12': 'Visitar monumentos/ sitios históricos', '113': 'Festival de ranchera y tríos al parque', '121': 'Premio nacional de interpretación, ciudad de Bogotá', '86': 'Fiestas de la cosecha', '64': 'Participar en ciclovía', '11': 'Leer periódicos/ revistas/Libros', '45': 'Caminar', '43': 'Ajedrez', '108': 'Festival de ópera y zarzuela al parque', '114': 'Conciertos de invitados nacionales en el ciclo media torta colombiana el primer domingo de cada mes', '81': 'Visitas turísticas a corregimientos y otros municipios', '20': 'Alcaldía adulto mayor / Servicio social a ancianos', '41': 'Ir a la playa', '90': 'Ninguna', '111': 'Festival de niños y niñas al parque - carnaval de niños y niñas', '3': 'Conciertos', '89': 'Otra. ¿Cuál? ', '53': 'Manualidades', '57': 'Fiestas Patronales', '48': 'Actividades de las fiestas de Noviembre', '120': 'Premio nacional de composición, ciudad de Bogotá', '122': 'Música antigua para nuestro tiempo', '25': 'Ir a tomar trago', '24': 'Actividades manuales', '87': 'Audiciones musicales', '42': 'Eventos Organizados por la alcaldía', '96': 'No aplica', '1': 'Teatro', '47': 'Cabalgatas', '73': 'Juegos de mesa / Internet / Leer libros', '14': 'Danza', '58': 'Encuentro Nacional de Danzas', '63': 'Practicar algún deporte/Actividad física', '74': 'Paseos', '50': 'Actividades eclesiásticas / Religiosas', '62': 'Actividades deportivas como espectador, sin incluir por televisión', '92': 'No Sabe / No Responde', '56': 'Feria de ...
# categorica
# NUMERO
# NUMERO
# nan
# nan
# nan
# NSE_1
# NSE
# nan
# {'4': 'Estrato 4', '7': 'Rural', '5': 'Estrato 5', '2': 'Estrato 2', '6': 'Estrato 6', '1': 'Estrato 1', '3': 'Estrato 3'}
# categorica
# CIUDAD
# CIUDAD
# nan
# {'54001': 'Cucuta', '66001': 'Pereira', '76892': 'Yumbo', '13001': 'Cartagena', '8001': 'Barranquilla', '76001': 'Cali', '11001': 'Bogotá', '17001': 'Manizales', '73001': 'Ibagué', '5001': 'Medellín', '68001': 'Bucaramanga Metropolitana', '20001': 'Valledupar'}
# categorica
# TIPO_ENTREV
# TIPO_ENTREV
# nan
# {'4': 'Transporte Informal', '1': 'Transporte Publico', '2': 'Transporte Privado', '3': 'Transporte Humano'}
# categorica
# LOCALIDAD_COMUNA
# LOCALIDAD_COMUNA
# Extra
# {'157': 'Villa Hermosa', '9': 'Fontibón', '158': 'Buenos Aires', '519': 'Veracruz', '2': 'Chapinero', '514': 'Cuchilla del Salado', '557': 'Occidente', '558': 'Sur Occidente', '305': 'Comuna 6', '551': 'Centro Oriente', '450': 'Comuna 1', '113': 'Unidad de Gobierno 14', '507': 'Comuna Palogrande', '503': 'Comuna Estación', '315': 'Comuna 16', '516': 'Alto Bonito', '8': 'Kennedy', '60': 'Comuna 11', '151': 'Santa Cruz', '13': 'Teusaquillo', '452': 'Comuna 3', '351': 'Rio Otún', '518': 'Alto tablazo', '70': 'Comuna 21', '160': 'Laureles-Estadio', '259': 'Comuna 10', '508': 'Comuna Universitaria', '258': 'Comuna 9', '164': 'Guayabal', '111': 'Unidad de Gobierno 12', '71': 'Comuna 22', '68': 'Comuna 19', '116': 'De la virgen y turística', '352': 'Centro', '65': 'Comuna 16', '513': 'La Aurora', '353': 'Villavicencio', '400': 'Comuna 1', '201': 'Riomar', '250': 'Comuna 1', '156': 'Robledo', '64': 'Comuna 15', '307': 'Comuna 8', '203': 'Suroccidente', '401': 'Comuna 2', '361': 'Ferrocarril', '505': 'Comuna Eco turístico Cerro de Oro', '368': 'El Poblado', '150': 'Popular', '300': 'Comuna 1', '455': 'Comuna 6', '521': 'El Palo', '302': 'Comuna 3', '162': 'San Javier', '355': 'Universidad', '256': 'Comuna 7', '556': 'Nor Occidente', '202': 'Metropolitana', '504': 'Comuna Ciudadela del Norte', '366': 'El Rocío', '117': 'Industrial de la bahía', '261': 'Comuna 12', '311': 'Comuna 12', '251': 'Comuna 2', '553': 'Oriente', '108': 'Unidad de Gobierno 9', '362': 'San Joaquín', '512': 'La Garrucha', '501': 'Comuna San José', '515': 'Alto Corinto', '358': 'Cuba', '310': 'Comuna 11', '57': 'Comuna 8', '260': 'Comuna 11', '511': 'Colombia (Kilometro 41)', '107': 'Unidad de Gobierno 8', '555': 'Norte ', '14': 'Los Mártires', '559': 'Cementerio', '153': 'Aranjuez', '309': 'Comuna 10', '306': 'Comuna 7', '301': 'Comuna 2', '112': 'Unidad de Gobierno 13', '1': 'Usaquén', '56': 'Comuna 7', '53': 'Comuna 4', '502': 'Comuna Cumanday', '101': 'Unidad de Gobierno 2', '509': 'Comuna La Fuente', '51': 'Comuna 2', '506': 'Comuna Tesorito', '109': 'Unidad de Gobierno 10', '403': 'Comuna 4', '4': 'San Cristóbal', '66': 'Comuna 17', '304': 'Comuna 5', '350': 'Villa Santana', '453': 'Comuna 4', '550': 'Centro', '357': 'Jardín', '54': 'Comuna 5', '523': 'Quiebra de Vélez', '360': 'Olímpica', '308': 'Comuna 9', '252': 'Comuna 3', '314': 'Comuna 15', '105': 'Unidad de Gobierno 6', '552': 'Sur Oriente', '114': 'Unidad de Gobierno 15', '364': 'El Oso', '517': 'Bajo tablazo', '67': 'Comuna 18', '104': 'Unidad de Gobierno 5', '16': 'Puente Aranda', '55': 'Comuna 6', '312': 'Comuna 13', '520': 'Morrogacho', '52': 'Comuna 3', '303': 'Comuna 4', '18': 'Rafael Uribe', '100': 'Unidad de Gobierno 1', '161': 'La América', '522': 'La Palma', '110': 'Unidad de Gobierno 11', '313': 'Comuna 14', '500': 'Comuna Atardeceres', '69': 'Comuna 20', '103': 'Unidad de Gobierno 4', '363': 'Perla del Otún', '165': 'Belén', '15': 'Antonio Nariño', '106': 'Unidad de Gobierno 7', '454': 'Comuna 5', '159': 'La Candelaria', '155': 'Doce de octubre', '17': 'Candelaria', '10': 'Engativá', '102': 'Unidad de Gobierno 3', '152': 'Manrique', '61': 'Comuna 12', '254': 'Comuna 5', '115': 'Histórica y del caribe norte', '12': 'Barrios Unidos', '316': 'Comuna 17', '255': 'Comuna 6', '154': 'Castilla', '59': 'Comuna 10', '402': 'Comuna 3', '365': 'San Nicolás', '20': 'Rural', '19': 'Ciudad Bolívar', '354': 'Oriente', '3': 'Santafé', '5': 'Usme', '451': 'Comuna 2', '163': 'El Poblado', '554': 'Nor Oriente', '58': 'Comuna 9', '356': 'Boston', '257': 'Comuna 8', '262': 'Comuna 13', '200': 'Norte Centro-Histórico', '367': 'Del Café', '11': 'Suba', '6': 'Tunjuelito', '253': 'Comuna 4', '510': 'Comuna La Macarena', '7': 'Bosa', '63': 'Comuna 14', '50': 'Comuna 1', '359': 'Consota', '62': 'Comuna 13', '204': 'Suroriente'}
# categorica
# BARRIO
# BARRIO
# nan
# nan
# nan
# ZONAS
# ZONAS
# Extra
# {'9': 'Nororiental', '12': 'Histórica y del Caribe Norte', '23': 'Universidades', '2': 'Sur-occidental', '22': 'Frontera', '19': 'Zona Rural', '3': 'Sur-oriental', '7': 'Sur', '17': 'Zona 3', '10': 'Oriente', '24': 'Occidente Norte', '16': 'Zona 2', '68547': 'Girón', '20': 'Centroriental', '4': 'Centro', '5': 'Chapinero', '18': 'Zona 4', '11': 'Distrito de agua blanca', '6': 'Norte', '21': 'Centroccidental', '68307': 'Piedecuesta', '14': 'Industrial de la Bahía', '68276': 'Floridablanca', '8': 'Noroccidental', '13': 'De la Virgen y Turística', '1': 'Occidental', '15': 'Zona 1'}
# categorica
# SEXO
# SEXO
# nan
# {'1': 'Masculino', '2': 'Femenino'}
# categorica
# EDAD
# EDAD
# Activos de las personas
# {'4': 'De 46 a 55 años', '5': 'Más de 55 años', '1': 'De 18 a 25 años', '2': 'De 26 a 35 años', '3': 'De 36 a 45 años'}
# categorica
# PON
# PON
# Extra
# {'4': 'Nada importante', '92': 'No Sabe / No Responde', '1': 'Absolutamente importante', '2': 'Algo importante', '3': 'Poco importante'}
# categorica
# AÑO
# AÑO
# nan
# {'2000': '2000', '2007': '2007', '2012': '2012', '1999': '1999', '2014': '2014', '2001': '2001', '2005': '2005', '2010': '2010', '2013': '2013', '2004': '2004', '2006': '2006', '2011': '2011', '2008': '2008', '2002': '2002', '1998': '1998', '2003': '2003', '2009': '2009'}
# categorica
# TIPO_TRANSPORTE
# TIPO_TRANSPORTE
# nan
# {'4': 'Transporte Informal', '1': 'Transporte Publico', '2': 'Transporte Privado', '3': 'Transporte Humano'}
# categorica
# F1
# Tipo de entrevistad(a)
# nan
# {'1': '¿Podría por favor hablar con el jefe del hogar hombre?', '2': '¿Podría entonces hablar con la jefe del hogar mujer?', '3': '¿Podría entonces hablar con un mayor de 18 años de edad, residente habitual de este hogar, que se encuentre ahora en casa?'}
# categorica
# F2
# Actualmente estamos realizando un estudio para lo cual me gustaría hacerle algunas preguntas. ¿Podría responderme esta encuesta?
# nan
# {'1': 'Sí', '2': 'No'}
# categorica
# F3_1
# Para comenzar me gustaría saber si usted o algún miembro de su familia trabaja actualmente o ha trabajado en los últimos seis meses en …..AGENCIAS DE INVESTIGACION QUE HACEN ENCUESTAS
# nan
# {'1': 'Si', '2': 'No'}
# categorica
# F3A_1
# Para comenzar me gustaría saber si usted o algún miembro de su familia trabaja actualmente o ha trabajado en los últimos seis meses en …..AGENCIAS DE INVESTIGACION QUE HACEN ENCUESTAS
# nan
# {'1': 'Si', '2': 'No'}
# categorica
# F3A_2
# Para comenzar me gustaría saber si usted o algún miembro de su familia trabaja actualmente o ha trabajado en los últimos seis meses en …..AGENCIAS DE PUBLICIDAD
# nan
# {'1': 'Si', '2': 'No'}
# categorica
# F3A_3
# Para comenzar me gustaría saber si usted o algún miembro de su familia trabaja actualmente o ha trabajado en los últimos seis meses en …..ALGUNA ENTIDAD OFICIAL O DEL ESTADO
# nan
# {'1': 'Si', '2': 'No'}
# categorica
# F4
# ¿En qué empresa trabaja Usted?
# nan
# {'4': 'Por ser mujer (ENC: VALIDE POR SEXO)', '5': 'Por no tener suficiente educación', '2': 'Por ser inmigrante', '9': 'Por ser joven', '11': 'Por la religión', '6': 'Por no tener conexiones', '12': 'Por el lugar donde vivo', '90': 'Ninguna', '3': 'Por ser pobre', '7': 'Por ser viejo', '8': 'Por ser discapacitado', '10': 'Por ser homosexual (LGBTI)', '1': 'Por el color de piel'}
# categorica
# F5
# ¿Y cuál es su ocupación?
# nan
# nan
# nan
# F6
# ¿Usted vive de forma permanente en [CIUDAD], o se encuentra en la ciudad por turismo o negocios?
# nan
# {'1': 'Vive en [CIUDAD]', '2': 'Está en la ciudad por turismo o negocios'}
# categorica
# F6A_AOS
# ¿Hace cuánto tiempo vive en [CIUDAD]?
# nan
# nan
# nan
# F6A_MESES
# ¿Hace cuánto tiempo vive en [CIUDAD]?
# nan
# nan
# nan
# F6A_DIAS
# ¿Hace cuánto tiempo vive en [CIUDAD]?
# nan
# nan
# nan
# F7
# ¿Podría por favor decirme cuántos hogares hay en esta vivienda? Grupo de personas que vive permanentemente en esta vivienda y comparten los alimentos; los empleados del servicio doméstico y sus familiares no forman parte del hogar.
# nan
# {'4': 'En usufructo', '5': 'Ocupante de hecho', '1': 'Casa propia totalmente pagada', '2': 'Casa propia, la está pagando', '3': 'En arriendo o subarriendo'}
# categorica
# F7A
# ¿Usted vive en?
# nan
# {'4': 'Apartamento Conjunto Cerrado', '1': 'Casa', '2': 'Apartamento', '3': 'Casa conjunto cerrado'}
# categorica
# F7B
# Podría decirme si esta vivienda es:
# nan
# {'4': 'En usufructo', '5': 'Ocupante de hecho', '1': 'Casa propia totalmente pagada', '2': 'Casa propia, la está pagando', '3': 'En arriendo o subarriendo'}
# categorica
# F9
# De acuerdo a su cultura o rasgos físicos, ¿Usted se reconoce como _____?
# nan
# {'4': 'Afrodescendiente', '5': 'Raizal de San Andrés y Providencia', '2': 'Mestizo', '93': 'No responde', '94': 'Cualquiera', '6': 'Palenquero de San Basilio', '90': 'Ninguno', '92': 'No Sabe / No Responde', '97': 'Ningún Otro', '3': 'ROM Gitano', '91': 'No Recuerda', '7': 'Blanco', '89': 'Otra. ¿Cuál?', '8': 'Mulato', '96': 'No Aplica', '1': 'Indígena', '95': 'Todos'}
# categorica
# F12
# Cuál de las siguientes opciones describe mejor su Posición dentro del hogar
# nan
# {'4': '\tHija/Hijo de la familia', '5': 'Abuelo/Abuela de la familia', '2': 'Esposa/esposo', '93': 'No responde', '6': 'Es otro familiar o pariente', '92': 'No Sabe / No Responde', '1': 'Ama (o) de casa o Jefe de hogar', '89': 'Otro', '3': 'Madre/Padre'}
# categorica
# AG1
# Ahora quisiera saber si en su opinión, las cosas en [CIUDAD] en general, ¿van por buen camino o por mal camino?
# Optimismo y bienestar subjetivo
# {'92': 'No Sabe / No Responde', '1': 'Buen camino', '2': 'Mal camino', '3': 'Siguen igual'}
# categorica
# AG2
# Usted personalmente, ¿qué tan orgulloso(a) se siente de [CIUDAD] ahora, en una escala de 1 a 5, donde 1 es nada orgulloso y 5 es muy orgulloso? Puede utilizar cualquier número de la escala.
# Optimismo y bienestar subjetivo
# {'4': '4', '5': 'Muy orgulloso', '2': '2', '92': 'No Sabe / No Responde', '1': 'Nada orgulloso', '3': '3'}
# categorica
# AG3
# Durante el próximo año, ¿Usted cree que las cosas en Bogotá van a mejorar o van a empeorar
# Optimismo y bienestar subjetivo
# {'1': 'Van a mejorar', '2': 'Van a emporar'}
# categorica
# CV0
# Por favor imagine una escalera Suponga que el peldaño más bajo representa la peor vida posible para usted y el peldaño más alto representa la mejor vida posible para usted ¿En qué peldaño de la escala se siente usted en estos momentos?
# Optimismo y bienestar subjetivo
# {'4': '4', '7': '7', '5': '5', '8': '8', '2': '2', '9': '9', '6': '6', '0': 'La peor vida posible para usted', '10': 'La mejor vida posible para usted', '1': '1', '3': '3'}
# categorica
# CV3
# De los aspectos que encontrará en esta tarjeta, ¿Cuáles considera que son los TRES más importantes para su calidad de vida? ¿Cuál sería el primero, el más importante, cuál sería el segundo, y cuál sería el tercero? - TERCERO
# Optimismo y bienestar subjetivo
# {'9': 'Seguridad', '12': 'Recreación', '23': 'Buen gobierno', '2': 'Salud', '22': 'Humanidad', '90': 'Ninguno', '19': 'Participación en asuntos de interés público o colectivo', '3': 'Empleo', '7': 'Servicios públicos', '17': 'Los amigos', '10': 'Medio ambiente', '24': 'Equidad', '16': 'La familia', '20': 'Servicios comunitarios', '4': 'Ingreso', '5': 'Posesiones materiales', '92': 'No Sabe / No Responde', '18': 'Los vecinos', '11': 'Cultura', '6': 'Vivienda', '21': 'Tolerancia', '14': 'Alimentación', '89': 'Otros. ¿Cuáles?', '8': 'Espacio público', '13': 'Deporte', '1': 'Educación', '15': 'Movilidad y transporte'}
# categorica
# CV5A
# Pensando en las obras y en las inversiones que se hacen en la ciudad, ¿qué tan satisfecho(a) se siente Usted con la forma como la alcaldía invierte los recursos y dineros de [CIUDAD], usando estas opciones?
# Optimismo y bienestar subjetivo
# {'9': 'Mejor calidad de vida', '73': 'Peor de lo que está ahora / Con más problemas', '2': 'Muy segura / Menos delincuencia / Menos corrupción / Fuerza pública', '28': 'Sin guerrilla / Menos secuestros', '22': 'Más bonita', '57': 'Con problemática social / Los ricos siempre van a tener más que los pobres', '31': 'Una gran metrópoli / Muy turística', '90': 'Ninguna', '30': 'Mejor transporte', '10': 'Menos contaminación / Cuidando el medio ambiente', '1': 'Con más oportunidad de empleo / Mayores oportunidades', '72': 'El transporte más costosos', '35': 'Inversión en el sector salud', '80': 'Con mayor población / Superpoblada', '89': 'Otros', '34': 'Mayor construcción de viviendas', '4': 'Más organizada / Ordenada / Limpia', '61': 'Alto costo de vida', '5': 'Mejor economía', '38': 'Mayor preocupación por la niñez / juventud / tercera edad', '91': 'No Recuerda', '66': 'Alza en la Canasta familiar / Todo más caro', '58': 'Muy congestionada', '82': 'Sin buses / Sin busetas / Sin taxis / Sin TransMilenio / Sin metro', '37': 'Mejor en servicios públicos', '29': 'Avanzada tecnológicamente', '8': 'Menos congestión', '60': 'Mucha contaminación / Mal el medio ambiente', '45': 'En Paz / Tranquila', '54': 'Un caos / Desorden', '44': 'Menos impuestos', '71': 'Problemas con la niñez / juventud', '69': 'Las vías en mal estado / huecos / No movilidad vial', '75': 'Mal en comercio / Privatización de empresas', '81': 'Más gente de otras partes', '83': 'Depende de los gobernantes / De los cambios que se presenten', '27': 'Más desarrollo / Progreso', '70': 'Igual que ahora / Con los mismos problemas', '23': 'Mejor infraestructura / Más obras', '20': 'Más grande', '93': 'No responde', '39': 'Bajan los precios de la Canasta familiar', '26': 'Mayor comercio / Industria / Mejor en cuanto a empresa', '3': 'Próspera / Menos pobreza', '36': 'Transmilenio en completo funcionamiento', '7': 'Buen desarrollo social', '33': 'Mejor en educación (Más colegios / Universidades / Educación gratuita)', '53': 'Más pobreza  / Desplazados', '67': 'Más problemas en el sector salud / Menos hospitales', '51': 'Con más desempleo', '68': 'Con más hambre / Menos alimentos', '25': 'Con metro / Mejor que ahora gracias al metro', '95': 'Todos', '55': 'Muy mala economía', '24': 'Más vías / Mayor infraestructura vial / Mayor movilidad', '52': 'Más insegura / Mayor delincuencia', '92': 'No Sabe / No Responde', '94': 'Cualquiera', '96': 'No aplica', '6': 'Buena administración / Mejor gobierno', '21': 'Más moderna', '40': 'Ciudad más cultural / Cultura ciudadana', '65': 'Los servicios públicos más caros', '63': 'Problemas en educación / Menos colegios / Menos docentes', '74': 'No cree estar para verla / Algo pasara que no la verá', '64': 'Con más impuestos / Mas altos', '59': 'No mejora la calidad de vida', '62': 'Con más carros / Problemas en cuanto a transporte', '32': 'Más espacios recreativos y culturales', '76': 'El hombre será reemplazado por máquinas', '50': 'Mucho mejor en todo sentido', '56': 'Mala administración / Dirigentes políticos corruptos'}
# categorica
# CV6A
# Independientemente si usted nació o no en [CIUDAD], se siente de [CIUDAD] o de otra parte del país?
# Optimismo y bienestar subjetivo
# {'92': 'No Sabe / No Responde', '1': 'De CIUDAD', '2': 'De otra parte del país'}
# categorica
# CV6B
# Por favor descríbame a Bogotá en una sola palabra
# Optimismo y bienestar subjetivo
# {'158': 'Politiquería', '2': 'Pujante', '281': 'Proceso', '216': 'Estrés', '31': 'Metrópoli', '339': 'Posibilidades', '340': 'Acabada', '207': 'Desgobernada', '89': 'Todos', '79': 'Tolerante', '337': 'Inseguridad', '315': 'Invasión', '96': 'Polifacética', '128': 'Sobrevivir', '131': 'Malo', '124': 'Generosa', '236': 'Guerreros', '29': 'Cambio', '213': 'Sociable', '151': 'Huecos', '228': 'Ladrones', '270': 'Fenomenal', '332': 'Maldad', '27': 'Delincuencia', '70': 'Desastroso', '160': 'Esperanza', '248': 'Calidad', '191': 'Amor', '95': 'Víctima', '19': 'Bonita', '182': 'Monopolio', '164': 'Interesante', '186': 'Impredecible', '116': 'Humana', '283': 'Innovador', '65': 'Adolescente', '134': 'Enorme', '345': 'Desagradable', '231': 'Imposible', '250': 'Codiciado', '185': 'Contaminada', '78': 'Inconclusa', '91': 'Feliz', '64': 'Desarrollo', '307': 'Promesas', '176': 'Orgullo', '203': 'Hospitalaria', '37': 'Armoniosa', '184': 'Inigualable', '300': 'Desafío', '123': 'Alegre', '992': 'No sabe', '305': 'Atractiva', '302': 'Desnivel', '80': 'Vandalismo', '35': 'Hermosa', '256': 'Placer', '249': 'Preciosa', '223': 'Simple', '86': 'Mediocre', '261': 'Invivible', '311': 'Tecnológica', '268': 'Amigable', '43': 'Floja', '209': 'Conflicto', '34': 'Vivible', '238': 'Terrible', '41': 'Pasión', '81': 'Opciones', '36': 'Inestable', '263': 'Desmejorada', '53': 'Calidosa', '310': 'Exquisita', '120': 'Ruidosa', '252': 'Corrupta', '237': 'Subdesarrollo', '125': 'Bacana', '107': 'Ágil', '172': 'Devaluar', '14': 'Progreso', '318': 'Discriminante', '153': 'Genial', '309': 'Urbana', '336': 'Mega ciudad', '301': 'Aprecio', '227': 'Agonía', '1': 'Acogedora', '56': 'Ineficiente', '175': 'Capitalista', '168': 'Diversión', '101': 'Cultura', '193': 'Interés', '298': 'Deshonestidad', '57': 'Chévere', '97': 'Habitable', '129': 'Recursivo', '126': 'Indiferente', '210': 'Competitiva', '46': 'Congestión', '273': 'Perdidas', '66': 'Desequilibrada', '304': 'Destrucción', '246': 'Insoportable', '140': 'Costosa', '54': 'Hogar', '275': 'Mundial', '183': 'Refugio', '47': 'Mejoría', '23': 'Horrible', '39': 'Agradable', '130': 'Urbanismo', '212': 'Futuro', '105': 'Des planificada', '67': 'Variable', '104': 'Crisis', '220': 'Incomprendida', '118': 'Intranquilidad', '16': 'Cosmopolita', '303': 'Catástrofe', '161': 'Olvidada', '279': 'Farra', '215': 'Agradecido', '321': 'Albergue', '299': 'Libertinaje', '177': 'Suspicaz', '313': 'Desamparada', '83': 'Des culturalizada', '98': 'Estresante', '264': 'Riqueza', '239': 'Principal', '15': 'Mal', '187': 'Única', '99': 'Romántica', '211': 'Anarquía', '188': 'Enredada', '327': 'Viva', '127': 'Completa', '143': 'Activa', '141': 'Bella', '324': 'Extremista', '198': 'Injusta', '181': 'Turística', '254': 'Inspiración', '255': 'Evolución', '229': 'Nevera', '147': 'Inundaciones', '197': 'Solidaria', '25': 'Desastre', '265': 'Intransitable', '241': 'Aceptable', '259': 'Macro', '306': 'Inaguantable', '245': 'Dinero', '285': 'Puerta', '288': 'Servicios', '276': 'Fabulosa', '33': 'Fría', '163': 'Sorpresas', '320': 'Democrática', '58': 'Comodidad', '257': 'Esfuerzo', '42': 'Peligrosa', '110': 'Complicada', '50': 'Fresca', '159': 'Controladora', '63': 'Intolerancia', '242': 'Versátil', '325': 'Antigua', '291': 'Imponente', '274': 'Delito', '157': 'Atraso', '9': 'Bien', '113': 'Armónica', '94': 'Seguridad', '75': 'Diversidad', '71': 'Corrupción', '68': 'Futurista', '266': 'Atrasada', '342': 'Monopólica', '280': 'Loco', '335': 'Vivir', '289': 'Descontrol', '38': 'Agitada', '343': 'Especial', '85': 'Sabroso', '170': 'Respeto', '8': 'Desorden', '13': 'Linda', '77': 'Ecológica', '234': 'Súper', '84': 'Sucia', '119': 'Pesada', '93': 'Progresista', '82': 'Construcción', '224': 'Colaboradora', '278': 'Acelerada', '189': 'Parche', '111': 'Caótica', '148': 'Rota', '331': 'Armonía', '201': 'Frío', '139': 'Elefante', '49': 'Alta', '21': 'Visionaria', '40': 'Normal', '222': 'Basurero', '72': 'Inconformidad', '156': 'Fatal', '317': 'Avanzada', '323': 'Eficiente ...
# categorica
# CV6C
# ¿Ud. nació en CIUDAD, o en otra ciudad?
# Optimismo y bienestar subjetivo
# {'1': '\tNació en CIUDAD', '2': '\tNació en otra ciudad'}
# categorica
# CV6D_BOG
# ¿En qué ciudad nació usted?
# Optimismo y bienestar subjetivo
# {'9': 'Girardot', '117': 'Cañas Gordas', '101': 'Bayunca', '2': 'Barranquilla', '28': 'Otras ciudades del Tolima', '22': 'Pereira', '51': 'Otras ciudades de Choco', '31': 'Otras ciudades de Santander', '97': 'Ningún otro', '129': 'Támesis', '30': 'Otras ciudades de Caldas', '109': 'Puente Nacional', '133': 'Yolombo', '107': 'Otras ciudades del Magdalena', '35': 'Otras ciudades de Meta', '79': 'Junín', '34': 'Otras ciudades de Huila', '4': 'Medellín', '96': 'No aplica', '38': 'Otras ciudades de Casanare, Caquetá, Putumayo, Arauca', '128': 'Sopetran', '66': 'Duitama', '16': 'Vélez', '132': 'Yarumal', '124': 'Rionegro', '26': 'Otras ciudades de Cundinamarca', '94': 'Cualquiera', '29': 'Otras ciudades de Antioquia', '8': 'Fusagasugá', '60': 'Buenaventura', '13': 'Pacho', '44': 'San Juan de Nepomuceno', '137': 'Pasacaballo', '77': 'Gacheta', '75': 'Facatativá', '106': 'Otras ciudades de Córdoba', '27': 'Otras ciudades del Valle', '70': 'Soata', '23': 'Pasto', '59': 'Buga', '93': 'No responde', '82': 'Ubala', '130': 'Urrao', '95': 'Todos', '19': 'Ciudades del extranjero', '105': 'Turbo', '54': 'Tumaco', '7': 'Cúcuta', '67': 'Susacon', '71': 'Somondoco', '68': 'Moniquira', '116': 'Betulia', '118': 'Concordia', '65': 'Villa de Leyva', '55': 'Ipiales', '76': 'Guáchala', '52': 'San Onofre', '110': 'Zipaquirá', '18': 'Villeta', '100': 'Otras ciudades de la Guajira', '138': 'Bocachica', '139': 'Barrancabermeja', '49': 'Lorica', '21': 'Sincelejo', '78': 'Guaduas', '40': 'Otras ciudades de Cesar, Sucre, Córdoba', '72': 'Anolaima', '91': 'No Recuerda', '83': 'Ubaté', '69': 'Sabota', '103': 'Santa Marta', '135': 'Boquilla', '32': 'Otras ciudades de Norte de Santander', '15': 'Tunja', '112': 'Aguadas', '104': 'Turbaco', '39': 'Otras ciudades de Cauca, Nariño', '126': 'San Rafael', '46': 'María la baja', '140': 'Mompox', '37': 'Otras ciudades de Quindío', '134': 'Barú', '119': 'Dabeiva', '123': 'Nariño', '17': 'Villavicencio', '10': 'Ibagué', '1': 'Cali', '127': 'Sonson', '125': 'Salgar', '102': 'San Andrés', '141': 'Tolú', '80': 'La Palma', '61': 'Tuluá', '5': 'Armenia', '115': 'Argelia', '12': 'Neiva', '113': 'Amaga', '121': 'Frontino', '64': 'Zarzal', '45': 'Arjona', '43': 'Bogotá', '108': 'Otras ciudades de Sucre', '136': 'Pontezuela', '114': 'Andes', '81': 'Tocaima', '20': 'Líbano', '41': 'Carmen de Bolívar', '90': 'Ninguno', '111': 'Abejorral', '3': 'Bucaramanga', '36': 'Otras ciudades de Bolívar', '89': 'Otros ¿Cuál?', '53': 'Popayán', '57': 'Otras ciudades de Risaralda', '48': 'Magangue', '120': 'Fredonia', '122': 'Gómez Plata', '25': 'Otras ciudades de Boyacá', '24': 'Montería', '92': 'No Sabe / No Responde', '42': 'Villanueva', '11': 'Manizales', '6': 'Chiquinquirá', '47': 'San Jacinto', '73': 'Cachipay', '14': 'Sogamoso', '58': 'Palmira', '63': 'Sevilla', '74': 'Chía', '33': 'Otras ciudades de la Costa Atlántica', '131': 'Valparaíso', '62': 'Cartago', '50': 'Cerete', '56': 'Barbacoas'}
# categorica
# CV6E
# ¿En qué departamento nació usted?
# Optimismo y bienestar subjetivo
# {'104': 'Sabana (Córdoba, Sucre, Cesar)', '9': 'No existe el código', '12': 'Nariño', '23': 'Cesar', '2': 'Cundinamarca', '93': 'No responde', '28': 'Cauca', '22': 'Atlántico', '90': 'Ninguno', '19': 'Risaralda', '97': 'Ningún otro', '3': 'Valle', '103': 'Costa Atlántica(Atlántico, Magdalena)', '7': 'Santander', '17': 'Sur del país (Casanare, Putumayo, Caquetá, Amazonas)', '10': 'Extranjero', '24': 'Córdoba', '102': 'Santanderes', '101': 'San Andrés / Providencia', '105': 'Cauca y Nariño', '16': 'Bolívar', '95': 'Todos', '94': 'Cualquiera', '20': 'Choco', '4': 'Tolima', '5': 'Antioquia', '92': 'No Sabe / No Responde', '18': 'Quindío', '100': 'Norte de Santander', '11': 'Sucre', '6': 'Viejo Caldas / Caldas', '21': 'Otros Países', '14': 'Huila', '25': 'Guajira', '96': 'No aplica', '91': 'No Recuerda', '89': 'Otros', '8': 'Magdalena', '13': 'Antiguos territorios nacionales', '1': 'Boyacá', '15': 'Meta'}
# categorica
# CO3
# ¿En general cómo califica la calidad de la información que recibe?
# Optimismo y bienestar subjetivo
# {'9': 'El costo de acceso a cultura/ recreación/ deporte', '2': 'El costo de los servicios públicos', '28': 'Deudas en general', '22': 'Dejó de recibir un ingreso adicional', '51': 'Por la edad ya no puede trabajar', '31': 'Depende de familiares / De los hijos', '97': 'Ningún otro', '30': 'Separación con la pareja', '35': 'Por discapacidad no puede trabajar', '79': 'Cierre de la frontera', '34': 'Esta dura la situación económica', '4': 'El costo del vestuario', '96': 'No Aplica', '38': 'El gobierno no ofrece apoyo económico', '66': 'Mal manejo del estado / Sistema político', '16': 'Dejaron de recibir remesas de familiares en el exterior', '94': 'Cualquiera', '29': 'Deterioro de los sectores económicos locales', '8': 'El costo del transporte', '60': 'Calamidad del líder de la casa', '13': 'Falleció uno de los principales sostenes económicos de la familia', '44': 'Desigualdad social', '77': 'Los impuestos', '75': 'El trabajo no va como se espera', '27': 'Se sienten estancados / Que no progresan', '70': 'Otros problemas familiares', '23': 'Por la mala situación económica del país', '59': 'Incapacidad por enfermedad', '93': 'No responde', '39': 'El costo de vida en general ha subido', '95': 'Todos', '19': 'Falta de oportunidades laborales', '54': 'Las ventas han bajado', '7': 'El costo de la salud', '67': 'Hay mayores ingresos y/o estabilidad económica', '71': 'Los impuestos altos / Muchos', '68': 'El alza de la gasolina / Combustible', '65': 'Inseguridad / Violencia / Guerrilla', '55': 'Todo está costoso/ Aumentaron los gastos', '76': 'Falta de ingresos', '52': 'Salarios muy bajos/No es justa la remuneración', '18': 'Por mal estado de salud no puede laborar un miembro de la familia', '49': 'Enfermedad del líder de la casa', '21': 'El costo de los impuestos', '78': 'Recesión Económica', '40': 'Inseguridad', '72': 'Falta de empleo / Falta de empleo para uno de los familiares', '91': 'No Recuerda', '64': 'Algún negocio/trabajo no va como se espera', '69': 'La tasas de interés', '32': 'Falta de oportunidades', '15': 'Separación/ divorcio de los padres', '46': 'Por aumento en los impuestos', '37': 'Los ingresos o salarios no alcanzan', '17': 'El costo de vida', '10': 'Uno o más miembros de la familia han perdido su empleo/ inestabilidad laboral', '1': 'El cierre de los negocios y empresas', '80': 'No hay empleo/Gobierno no deja trabajar', '61': 'Esta enfermo o tiene algún familiar enfermo', '5': 'El costo de la vivienda', '12': 'La familia creció, ahora los ingresos no alcanzan', '45': 'El invierno/ Las inundaciones', '43': 'Por inconvenientes de salud no puede trabajar/ de un familiar/ del él o ella', '26': 'No cuentan con una estabilidad económica / Con un empleo estable', '20': 'Es desplazado/ Los obligaron a dejar su vivienda/ ciudad', '41': 'Recesión económica/ No hay crecimiento económico', '90': 'Ninguna', '3': 'El costo de la alimentación', '36': 'Hay desempleo/ Empleos inestables', '89': 'Otro. ¿Cuál?', '53': 'La mala gestión publica/El modelo económico es desfavorable', '57': 'Se incrementaron los gastos', '48': 'Contrabando', '25': 'Por el desempleo', '24': 'Se independizó/ separó de la familia', '42': 'Mala administración/ Malos gobernantes/ Corrupción', '11': 'Uno o más miembros de la familia no recibieron aumento de sueldo/ no fue suficiente el aumento', '6': 'El costo de la educación', '47': 'El pico y placa', '73': 'La situación del país', '14': 'Algún negocio quebró/ no va como se esperaba', '58': 'Engaños de los mandatarios del gobierno/ Corrupción', '63': 'La persona que aporta económicamente está delicado de salud', '74': 'Nada ha afectado la situación económica', '33': 'No alcanza el dinero / Se ve la escases del dinero', '50': 'Crisis Mundial/Crisis económica/Difícil situación', '62': 'El sueldo / La pensión no alcanza para nada', '92': 'No Sabe / No Responde', '56': 'La casa se le cayó'}
# categorica
# CO4A_SI
# ¿Por qué SI se considera pobre?
# Optimismo y bienestar subjetivo
# {'9': 'No tiene un buen salario', '46': 'No tiene para la alimentación / Aguanta hambre', '2': 'Por la falta de dinero/ el dinero no alcanza para cubrir las necesidades', '28': 'Tiene muchas deudas /Debe impuestos/Servicios', '22': 'Mala administración de sus gobernantes', '57': 'Hay mas pobres', '31': 'No tiene carro', '97': 'Ninguna otra', '90': 'Ninguna', '30': 'Es una persona discapacitada', '17': 'Falta de oportunidades', '10': 'Falta de educación/ oportunidades educativas', '35': 'Por la discriminación', '94': 'Cualquiera', '34': 'Muchos impuestos por pagar', '4': 'No tengo vivienda propia', '5': 'Tengo justo lo necesario para vivir', '96': 'No aplica', '38': 'Porque no cuenta con SISBEN', '25': 'El dinero no alcanza para cubrir las necesidades', '12': 'No tiene oportunidades', '37': 'Porque es madre cabeza de hogar', '29': 'No tiene seguridad social', '8': 'Se pasan muchas necesidades', '45': 'Solo tengo la casa / Solo tengo la vivienda', '43': 'Por la baja calidad de vida', '13': 'No tiene familia/ es sólo', '44': 'No tengo nada', '27': 'Los servicios están muy caros', '47': 'Otras definiciones sobre la pobreza', '23': 'Es muy alto el costo de vida', '20': 'Tiene problemas de salud/ El servicio de salud es deficiente', '93': 'No responde', '39': 'No tiene pensión / No alcanza la pensión', '26': 'No ayudan a la gente que lo necesita/Discriminación', '19': 'El gobierno no invierte bien los recursos/ Hay corrupción', '3': 'Faltan muchas cosas para vivir mejor', '54': 'No tiene los recursos para el estudio/No tiene estudios', '7': 'Por la situación económica', '33': 'Vive en un barrio de estrato bajo', '53': 'No puede trabajar / Tiene que dedicarse al hogar', '51': 'No tiene sino la pensión / No tiene sino el salario', '48': 'Otros aspectos que inciden a la pobreza (Por la edad no le dan trabajo)', '16': 'El costo de la vida está aumentando', '95': 'Todos', '55': 'No tiene un  buen  salario /No tiene suficientes ingresos', '24': 'No tiene acceso a la seguridad social', '52': 'Solo tiene a los hijos, la familia que le ayudan', '92': 'No Sabe / No Responde', '18': 'Falta de salud', '42': 'Porque tiene que trabajar', '11': 'Es desplazado', '6': 'No tiene todas las comodidades/ no se puede dar lujos', '49': 'El dinero solo le alcanza para pagar los servicios', '21': 'Falta educación/ No tiene estudios profesionales', '14': 'No tiene salud/ Está enfermo', '40': 'Por la estratificación / Por el sector en que vive', '56': 'No tiene familia /No tiene a nadie / No tiene quien le ayude', '65': 'Si uno fuera rico ayudaría a la gente', '91': 'No Recuerda', '89': 'Otro. ¿Cuál?', '50': 'Por que tiene muchos gastos / No puede ahorrar', '32': 'No ha tenido apoyo por parte del estado', '1': 'No tiene empleo', '15': 'No ha estudiado / No ha continuado sus estudios', '41': 'No tiene salud / Poco acceso a la salud'}
# categorica
# CO4A_NO
# ¿Por qué NO se considera pobre?
# Optimismo y bienestar subjetivo
# {'9': 'Tengo familia/ hogar/ buen hogar', '46': 'Tengo valores / inteligencia / actitud optimista', '2': 'Tengo donde vivir/ tengo techo/ tengo vivienda', '28': 'Tengo estudio/ tengo educación/ Ofrece educación a sus hijos', '22': 'Tiene riqueza espiritual', '31': 'Es emprendedor/ Tiene ganas de salir adelante', '97': 'Ninguna otra', '90': 'Ninguna', '30': 'Tiene una pensión', '17': 'Tengo vestuario', '10': 'Nadie es pobre/ pobre es aquel que no tiene nada', '35': 'Cree en Dios', '94': 'Cualquiera', '34': 'Aunque hay cosas que están desmejorando', '4': 'Tengo trabajo/ puedo trabajar', '5': 'Tengo salud/ tengo seguro médico', '96': 'No aplica', '38': 'Tiene buena actitud/rico espiritualmente/Confía en Dios', '25': 'Tiene vida / Falta mucho por vivir', '12': 'Tengo un ingreso estable', '37': 'Hay personas que son más pobres que uno', '29': 'Tiene a Dios/ Tiene riqueza espiritual', '8': 'Tengo estudio/ tengo educación', '45': 'Tengo aspiraciones / tengo sueños / espíritu de salir adelante', '43': 'Tengo los servicios básicos / Puedo pagar los servicios o impuestos', '13': 'Puedo gastar en recreación', '44': 'Tengo bienes / Tengo carro / Rentas / Su propio negocio', '27': 'Tiene vida/ capacidades para trabajar', '47': 'Tiene la actitud de no pobreza', '23': 'Tiene a Dios en su vida / En su corazón', '20': 'Porque pobre es el que no tiene espíritu', '93': 'No responde', '39': 'La pobreza no es solo no tener dinero', '26': 'Los hijos son profesionales', '3': 'No falta la comida', '36': 'Pobres los que no creen en Dios/ No tienen espíritu', '7': 'Estoy estable económicamente/ tengo capacidad económica', '33': 'Tiene capacidades intelectuales', '51': 'Por que tengo A Dios / cuento con la ayuda de Dios', '48': 'Espiritualmente no soy pobre /Tengo espíritu /Tengo valores', '16': 'La pobreza es mental', '95': 'Todos', '24': 'Hay personas más necesitadas', '92': 'No Sabe / No Responde', '18': 'Hay personas que tienen menos recursos que yo / Que nosotros', '42': 'Por su estrato no es pobre / Vive en un estrato de clase media', '11': 'Tengo valores/ a Dios/ espíritu/ fortaleza', '6': 'Porque vivo bien/ tengo comodidades', '49': 'Tengo : Inteligencia / Capacidades / Sueños / Optimismo / Conocimientos', '21': 'La pobreza es espiritual', '14': 'No es pobre de Espíritu/Pobre es el que no tiene espíritu', '40': 'Vive  de la pensión', '91': 'No Recuerda', '89': 'Otro. ¿Cuál?', '50': 'Porque recibe ayuda de otras personas (Padres, hijos, esposo)', '32': 'Los integrantes de su hogar aportan dinero', '1': 'Tengo lo necesario', '15': 'Tiene ganas/ fuerzas para luchar/ salir a adelante', '41': 'Tiene las capacidades para hacer lo que quiera'}
# categorica
# CO4_SI_BOG_05
# ¿Por qué SI se considera pobre?
# Optimismo y bienestar subjetivo
# {'1': 'Si', '2': 'No'}
# categorica
# CO4B
# ¿Podría decirme si usted se considera pobre?
# Optimismo y bienestar subjetivo
# {'4': 'Otra pérdida económica importante', '7': 'Se atrasaron en pago de vivienda 4 meses o más continuos.', '5': '\tSe atrasaron en el pago de guarderías o colegio 4 meses o más continuos', '8': '\tSe atrasaron en pago servicios públicos 4 meses o más continuos', '2': 'El cónyuge perdió su empleo', '9': 'Se atrasaron en el pago de impuestos (predial, valorización y renta)', '6': 'No pudieron pagar la universidad.', '90': 'Ninguno de las anteriores', '1': 'El jefe de hogar perdió su empleo', '3': 'Otro miembro del hogar perdió su empleo'}
# categorica
# CO4C
# ¿Podría decirme si usted se considera pobre?
# Optimismo y bienestar subjetivo
# {'9': 'Disminuyeron el gasto en vestuario', '95': 'Todos', '2': 'Montaron un negocio familiar', '93': 'No responde', '94': 'Cualquiera', '90': 'Ninguno', '3': '\tSe fueron a vivir con familiares', '7': '\tRetiraron hijos del colegio o los cambiaron a uno más económico', '17': 'Se retiro de estudiar / Estudiar en otra parte es más barato', '10': 'Se cambiaron a una vivienda más económica', '1': '\tUno o más miembros del hogar que no trabajaban empezaron a trabajar', '16': 'Llega a acuerdos', '4': '\tGastaron los ahorros', '5': 'Se endeudaron', '18': 'Esperar / No lo ha solucionado', '96': 'No aplica', '6': 'Vendieron algunos bienes', '14': 'Ayuda familiar de otros', '91': 'No Recuerda', '8': '\tDisminuyeron el gasto en alimentos', '13': 'Crear otras posibilidades de ingreso / Rebusque / Trabajo informal', '92': 'No Sabe / No Responde', '15': 'Busca trabajo'}
# categorica
# CO12
# En el último año, ¿este hogar ha tenido alguna dificultad económica que haya dado lugar a retrasos en alguno de los pagos del hogar?
# Optimismo y bienestar subjetivo
# {'92': 'No Sabe / No Responde', '1': 'Sí', '2': 'No'}
# categorica
# CO13
# ¿Qué es lo primero que ha sacrificado el hogar al no tener con que pagar?
# Optimismo y bienestar subjetivo
# {'9': 'Gastos en recreación/ diversión/ vacaciones', '27': 'Reducción de gastos otros (Recreación, Gastos personales, Crédito, Impuesto predial)', '12': 'Empeña las cosas', '23': 'Vestuario', '2': 'Gastos en educación', '93': 'No responde', '28': 'Lujos personales', '31': 'Compra de vestuario/Necesidades personales', '22': 'Diversión y entretenimiento/Club', '26': 'Se ha endeudado con prestamos', '19': 'Carro', '90': 'Nada/Ninguna', '3': 'Aportes a seguridad social', '30': 'Gas natural', '7': 'Pago de servicios públicos', '17': 'Electrodomésticos/Empeño', '10': 'Impuestos', '24': 'Internet', '16': 'Administración del conjunto', '95': 'Todos', '89': 'Otro. ¿Cuál?', '20': 'Gastos personales', '4': 'Gastos en salud', '5': 'Gastos en transporte', '92': 'No Sabe / No Responde', '18': 'Cosas de la casa', '11': 'No comprar ropa/ joyas/ lujos', '6': 'Gastos en alimentación', '21': 'Pago de impuestos/Predial/valorización/catastro', '14': 'Recreación', '33': 'Empeñar prendas', '25': 'Canasta familiar', '96': 'No aplica', '91': 'No Recuerda', '29': 'Brindar una ayuda a un familiar', '8': 'Créditos/ deudas', '13': 'Televisión por cable', '32': 'Cuotas de créditos / Prestamos /', '1': 'Arriendo/ Cuota hipotecaria', '15': 'Obligaciones bancarias/Bancos/Tarjetas', '94': 'Cualquiera'}
# categorica
# CO14
# ¿Cuál servicio público?/¿Cuál servicio público ha tenido mayores dificultades para pagar?
# Optimismo y bienestar subjetivo
# {'4': 'Teléfono fijo', '5': 'Celular', '2': 'Energía eléctrica', '9': 'Mega obras', '6': 'Televisión por cable', '90': 'Ninguno', '92': 'No Sabe / No Responde', '3': 'Gas natural', '7': 'Internet', '89': 'Otro. ¿Cuál?', '8': 'Impuestos', '88': 'No especifico servicio', '10': 'Teléfono sin especificar', '1': 'Acueducto, alcantarillado y aseo', '95': 'Todos los servicios'}
# categorica
# CO14B
# ¿Cuál servicio público?/¿Cuál servicio público ha tenido mayores dificultades para pagar?
# Optimismo y bienestar subjetivo
# {'4': 'Gas', '90': 'Ninguno', '1': 'Energía eléctrica', '2': 'Acueducto, Alcantarillado y Aseo', '3': 'Teléfono'}
# categorica
# AL1
# En las últimas CUATRO semanas, ¿Usted o algún miembro de su hogar tuvo que comer menos de TRES comidas diarias porque no había suficientes alimentos?
# Optimismo y bienestar subjetivo
# {'1': 'Sí', '2': 'No', '3': 'No Sabe'}
# categorica
# AL2
# ¿Con qué frecuencia sucedió esto?
# Optimismo y bienestar subjetivo
# {'4': 'Por lo menos una vez al mes', '1': 'Pocas veces, una o dos veces en las últimas cuatro semanas', '2': 'A veces, entre tres y diez veces las últimas cuatro semanas', '3': 'Con frecuencia, más de diez veces en las últimas cuatro semanas'}
# categorica
# A2
# ¿Utilizaron los servicios de salud de cualquier entidad?
# nan
# {'4': 'Las tres comidas', '92': 'No Sabe / No Responde', '1': 'Desayuno', '2': 'Almuerzo', '3': 'Comida'}
# categorica
# A2A
# ¿Fue por consulta externa o fue una urgencia?
# nan
# {'1': 'Por consulta externa', '2': 'Una urgencia'}
# categorica
# A2B_1
# Cuál o cuáles miembros del hogar no consumieron alguna de las tres comidas - Hombre (s) - Menores de 5 años
# nan
# {'4': 'De 18 a 25 años', '7': 'De 46 a 55 años', '5': 'De 26 a 35 años', '8': 'Más de 55 años', '2': 'De 5 a 12 años', '6': 'De 36 a 45 años', '1': 'Menores de 5 años', '3': 'De 13 a 17 años'}
# categorica
# A2B_2
# Cuál o cuáles miembros del hogar no consumieron alguna de las tres comidas - Hombre (s) - De 5 a 12 años
# nan
# {'4': 'De 18 a 25 años', '7': 'De 46 a 55 años', '5': 'De 26 a 35 años', '8': 'Más de 55 años', '2': 'De 5 a 12 años', '6': 'De 36 a 45 años', '1': 'Menores de 5 años', '3': 'De 13 a 17 años'}
# categorica
# A2B_3
# Cuál o cuáles miembros del hogar no consumieron alguna de las tres comidas - Hombre (s) - De 13 a 17 años
# nan
# {'4': 'De 18 a 25 años', '7': 'De 46 a 55 años', '5': 'De 26 a 35 años', '8': 'Más de 55 años', '2': 'De 5 a 12 años', '6': 'De 36 a 45 años', '1': 'Menores de 5 años', '3': 'De 13 a 17 años'}
# categorica
# A2B_4
# Cuál o cuáles miembros del hogar no consumieron alguna de las tres comidas - Hombre (s) - De 18 a 35 años
# nan
# {'4': '4', '5': 'Mucho', '2': '2', '92': 'No Sabe / No Responde', '1': 'Nada', '3': '3'}
# categorica
# A2B_5
# Cuál o cuáles miembros del hogar no consumieron alguna de las tres comidas - Hombre (s) - De 26 a 35 años
# nan
# {'4': '4', '5': 'Mucho', '2': '2', '92': 'No Sabe / No Responde', '1': 'Nada', '3': '3'}
# categorica
# A2B_6
# Cuál o cuáles miembros del hogar no consumieron alguna de las tres comidas - Hombre (s) - De 36 a 45 años
# nan
# {'4': '4', '5': 'Mucho', '2': '2', '92': 'No Sabe / No Responde', '1': 'Nada', '3': '3'}
# categorica
# A2B_7
# Cuál o cuáles miembros del hogar no consumieron alguna de las tres comidas - Hombre (s) - De 46 a 55 años -
# nan
# {'4': '4', '5': 'Mucho', '2': '2', '92': 'No Sabe / No Responde', '1': 'Nada', '3': '3'}
# categorica
# A2B_8
# Cuál o cuáles miembros del hogar no consumieron alguna de las tres comidas - Hombre (s) - Más de 55 años -
# nan
# {'4': '4', '5': 'Mucho', '2': '2', '92': 'No Sabe / No Responde', '1': 'Nada', '3': '3'}
# categorica
# A2C_1
# Cuál o cuáles miembros del hogar no consumieron alguna de las tres comidas - Mujer (es) - Menores de 5 años -
# nan
# {'92': 'No Sabe / No Responde', '1': 'Si', '2': 'No'}
# categorica
# A2C_2
# Cuál o cuáles miembros del hogar no consumieron alguna de las tres comidas - Mujer (es) - De 5 a 12 años -
# nan
# {'92': 'No Sabe / No Responde', '1': 'Si', '2': 'No'}
# categorica
# A2C_3
# Cuál o cuáles miembros del hogar no consumieron alguna de las tres comidas - Mujer (es) - De 13 a 17 años -
# nan
# {'92': 'No Sabe / No Responde', '1': 'Si', '2': 'No'}
# categorica
# A2C_4
# Cuál o cuáles miembros del hogar no consumieron alguna de las tres comidas - Mujer (es) - De 18 a 35 años -
# nan
# {'92': 'No Sabe / No Responde', '1': 'Si', '2': 'No'}
# categorica
# A2C_5
# Cuál o cuáles miembros del hogar no consumieron alguna de las tres comidas - Mujer (es) - De 26 a 35 años -
# nan
# {'4': '4', '5': 'Mucho', '2': '2', '92': 'No Sabe / No Responde', '1': 'Nada', '3': '3'}
# categorica
# A2C_6
# Cuál o cuáles miembros del hogar no consumieron alguna de las tres comidas - Mujer (es) - De 36 a 45 años -
# nan
# {'4': '4', '5': 'Mucho', '2': '2', '92': 'No Sabe / No Responde', '1': 'Nada', '3': '3'}
# categorica
# A2C_7
# Cuál o cuáles miembros del hogar no consumieron alguna de las tres comidas - Mujer (es) - De 46 a 55 años -
# nan
# {'4': '4', '5': 'Mucho', '2': '2', '92': 'No Sabe / No Responde', '1': 'Nada', '3': '3'}
# categorica
# A2C_8
# Cuál o cuáles miembros del hogar no consumieron alguna de las tres comidas - Mujer (es) - Más de 55 años -
# nan
# {'4': '4', '5': 'Mucho', '2': '2', '92': 'No Sabe / No Responde', '1': 'Nada', '3': '3'}
# categorica
# AL7_1
# A continuación, le mencionaré afirmaciones de la gente  sobre su situación alimentaría. Me gustaría que me dijera si ocurrieron en su hogar en estos 12 meses :	En mi hogar nos preocupa que se termine la comida y no tengamos dinero para comprar más
# Optimismo y bienestar subjetivo
# {'1': 'Siempre', '2': 'Algunas veces', '3': 'Nunca'}
# categorica
# AL7_2
# A continuación, le mencionaré afirmaciones de la gente  sobre su situación alimentaría. Me gustaría que me dijera si ocurrieron en su hogar en estos 12 meses: 	En mi hogar la comida se nos acabó antes de disponer de dinero para comprar más
# Optimismo y bienestar subjetivo
# {'1': 'Siempre', '2': 'Algunas veces', '3': 'Nunca'}
# categorica
# AL7_3
# A continuación, le mencionaré algunas afirmaciones de la gente  sobre su situación alimentaría. Me gustaría que me dijera si ocurrieron en su hogar:	En mi hogar no podemos afrontar los gastos para consumir comidas completas y equilibradas
# Optimismo y bienestar subjetivo
# {'1': 'Siempre', '2': 'Algunas veces', '3': 'Nunca'}
# categorica
# AL7_4
# Mencionaré algunas afirmaciones de la gente sobre su situación alimentaría en los últimos 12 meses-	En mi hogar no podemos darle a nuestros hijos una alimentación completa y equilibrada debido a que no podemos subir los gastos
# Optimismo y bienestar subjetivo
# {'1': 'Siempre', '2': 'Algunas veces', '3': 'Nunca'}
# categorica
# AL7_5
# Voy a mencionar afirmaciones de la gente sobre su situación alimentaría en los últimos 12 meses-Qué tan a menudo sus hijos no se alimentaron lo suficiente debido a que en el hogar no pudieron comprar los alimentos necesarios en los últimos 12 meses.
# Optimismo y bienestar subjetivo
# {'1': 'Siempre', '2': 'Algunas veces', '3': 'Nunca'}
# categorica
# AL7_6
# ...
# categorica
# CC6_9
# Voy a leerle frases sobre el Concejo de CIUDAD ¿qué tan de acuerdo o en desacuerdo está-.Hay que apoyar a un concejal si uno quiere que él lo apoye a uno.
# Buen Gobierno y Ciudadanía
# {'4': '4', '5': 'Completamente De Acuerdo', '2': '2', '92': 'No Sabe / No Responde', '1': 'Completamente en desacuerdo', '3': '3'}
# categorica
# CC6_10
# Voy a leerle frases sobre el Concejo de CIUDAD ¿qué tan de acuerdo o en desacuerdo está- El voto se puede usar para castigar a los malos concejales.
# Buen Gobierno y Ciudadanía
# {'4': '4', '5': 'Completamente De Acuerdo', '2': '2', '92': 'No Sabe / No Responde', '1': 'Completamente en desacuerdo', '3': '3'}
# categorica
# CC6_11
# Voy a leerle frases sobre el Concejo de CIUDAD ¿qué tan de acuerdo o en desacuerdo está- Los ciudadanos no pueden hacer nada frente a los malos concejales.
# Buen Gobierno y Ciudadanía
# {'4': '4', '5': 'Completamente De Acuerdo', '2': '2', '92': 'No Sabe / No Responde', '1': 'Completamente en desacuerdo', '3': '3'}
# categorica
# CC6_12
# Voy a leerle frases sobre el Concejo de CIUDAD ¿qué tan de acuerdo o en desacuerdo está-  El concejo es una institución importante, el problema son las personas escogidas como concejales.
# Buen Gobierno y Ciudadanía
# {'4': '4', '5': 'Completamente De Acuerdo', '2': '2', '92': 'No Sabe / No Responde', '1': 'Completamente en desacuerdo', '3': '3'}
# categorica
# CC6_13
# Voy a leerle frases sobre el Concejo de CIUDAD ¿qué tan de acuerdo o en desacuerdo está-  El Alcalde de Ciudad no debe acceder a ninguna petición de los concejales aunque eso signifique la no aprobación de proyectos claves para la ciudad.
# Buen Gobierno y Ciudadanía
# {'4': '4', '5': 'Completamente De Acuerdo', '2': '2', '92': 'No Sabe / No Responde', '1': 'Completamente en desacuerdo', '3': '3'}
# categorica
# CC6_14
# Voy a leerle frases sobre el Concejo de CIUDAD ¿qué tan de acuerdo o en desacuerdo está- La actitud de los concejales obstaculiza la gestión del Alcalde Mayor de la ciudad.
# Buen Gobierno y Ciudadanía
# {'4': '4', '5': 'Completamente De Acuerdo', '2': '2', '92': 'No Sabe / No Responde', '1': 'Completamente en desacuerdo', '3': '3'}
# categorica
# CC6_15
# Voy a leerle frases sobre el Concejo de CIUDAD ¿qué tan de acuerdo o en desacuerdo está- A ratos, las cosas de la política y el gobierno parecen tan complicadas que personas como yo no pueden entenderlas realmente.
# Buen Gobierno y Ciudadanía
# {'4': '4', '5': 'Completamente De Acuerdo', '2': '2', '92': 'No Sabe / No Responde', '1': 'Completamente en desacuerdo', '3': '3'}
# categorica
# CC6_16
# Voy a leerle frases sobre el Concejo de CIUDAD ¿qué tan de acuerdo o en desacuerdo está-El alcalde de CIUDAD debe discutir con los concejales los nombramientos en algunos cargos públicos.
# Buen Gobierno y Ciudadanía
# {'4': '4', '5': 'Completamente De Acuerdo', '2': '2', '92': 'No Sabe / No Responde', '1': 'Completamente en desacuerdo', '3': '3'}
# categorica
# CC6_17
# Voy a leerle frases sobre el Concejo de CIUDAD ¿qué tan de acuerdo o en desacuerdo está-El Concejo representa bien la composición e intereses de la ciudadanía .
# Buen Gobierno y Ciudadanía
# {'4': '4', '5': 'Completamente De Acuerdo', '2': '2', '92': 'No Sabe / No Responde', '1': 'Completamente en desacuerdo', '3': '3'}
# categorica
# CC6_26
# Voy a leerle frases sobre el Concejo de CIUDAD ¿qué tan de acuerdo o en desacuerdo está- Los actuales concejales no aportan nada para el desarrollo de la ciudad.
# Buen Gobierno y Ciudadanía
# {'4': '4', '5': 'Completamente De Acuerdo', '2': '2', '92': 'No Sabe / No Responde', '1': 'Completamente en desacuerdo', '3': '3'}
# categorica
# CC6_27
# Voy a leerle frases sobre el Concejo de CIUDAD ¿qué tan de acuerdo o en desacuerdo está- Algunos concejales de Bogotá obstaculizan el desarrollo de la ciudad.
# Buen Gobierno y Ciudadanía
# {'4': '4', '5': 'Completamente De Acuerdo', '2': '2', '92': 'No Sabe / No Responde', '1': 'Completamente en desacuerdo', '3': '3'}
# categorica
# CC6A
# De las opciones contenidas en esta tarjeta, ¿cómo votó Usted en las pasadas elecciones al Concejo de su CIUDAD?
# Buen Gobierno y Ciudadanía
# {'91': 'No Recuerda', '1': 'Votó por un candidato o partido', '2': 'Votó en blanco', '3': 'No votó'}
# categorica
# CC6B
# De las opciones contenidas en esta tarjeta, ¿qué fue lo que más lo(a) motivó para votar por un candidato o partido en las pasadas elecciones al consejo su CIUDAD?
# Buen Gobierno y Ciudadanía
# {'4': 'Por su partido o movimiento político', '5': 'Para poder obtener beneficios personales', '2': 'El carisma o personalidad del candidato', '93': 'No responde', '9': 'Amistad con el candidato', '11': 'El día libre por votar', '6': 'Porque era un candidato nuevo', '90': 'Ninguno', '92': 'No Sabe / No Responde', '3': 'La opinión de amigos y familiares', '91': 'No Recuerda', '7': 'Ejercer el derecho al voto', '89': 'Otro. ¿Cuál?', '8': 'Por apoyar al candidato', '96': 'No aplica', '10': 'Voto en blanco', '1': 'Las propuestas e ideas', '95': 'Todos', '94': 'cualquiera'}
# categorica
# CC6C
# De las opciones contenidas en esta tarjeta, ¿cuál fue la principal razón por la cual no votó en las pasadas elecciones al Concejo de su CIUDAD?
# Buen Gobierno y Ciudadanía
# {'9': 'Era menor de edad', '95': 'Todos', '2': 'No confía en los políticos', '93': 'No responde', '94': 'cualquiera', '90': 'Ninguno', '3': 'Considera al Concejo como una institución inútil', '7': 'No pudo votar', '17': 'Estaba trabajando', '10': 'No estaba en la ciudad', '96': 'No aplica', '16': 'No participa en política', '4': 'No sabe qué hace el Concejo', '5': 'No cree que su voto cambie las cosas', '92': 'No Sabe / No Responde', '18': 'Estaba enfermo/En situación riesgosa', '11': 'No alcanzó / Falta de tiempo', '6': 'Nadie lo convenció', '12': 'Pereza', '14': 'No le gusta votar / No le interesa', '91': 'No Recuerda', '89': 'Otro. ¿Cuál?', '8': 'No tenia la cédula / no tenia la cédula inscrita', '13': 'Nunca vota', '1': 'No conocía propuestas ni candidatos', '15': 'No alcanzo a inscribir la cedula'}
# categorica
# CC6D
# Cuando se elija el alcalde de la ciudad, también se elegirán concejales. ¿ que tan probable es que usted personalmente vote para esas elecciones??
# Buen Gobierno y Ciudadanía
# {'4': 'Probablemente NO votará', '5': 'Definitivamente NO votará', '1': 'Definitivamente votará', '2': 'Probablemente votará', '3': 'No sabe'}
# categorica
# CC6F
# ¿Cree que el Concejo de LA CIUDAD, está haciendo cosas por mejorar la calidad de vida de las personas como usted?
# Buen Gobierno y Ciudadanía
# {'92': 'No Sabe / No Responde', '1': 'Si', '2': 'No'}
# categorica
# CC7D_1
# ¿Qué tan importante es para usted que el Concejo discuta cada uno de ellos? En una escala de 1 a 5 :  La reforma tributaria: aumentar los impuestos en general
# Buen Gobierno y Ciudadanía
# {'4': '4', '5': 'Muy importante', '2': '2', '92': 'No Sabe / No Responde', '1': 'Nada importante', '3': '3'}
# categorica
# CC7D_2
# De los temas que le voy a leer ¿Qué tan importante es para usted que el Concejo discuta cada uno de ellos?-La reforma al código de la policía: reglas de convivencia, procedimientos de policía y cultura ciudadana.
# Buen Gobierno y Ciudadanía
# {'4': '4', '5': 'Muy importante', '2': '2', '92': 'No Sabe / No Responde', '1': 'Nada importante', '3': '3'}
# categorica
# CC7D_3
# De los temas que le voy a leer ¿Qué tan importante es para usted que el Concejo discuta cada uno de ellos?-La prohibición de usar animales en los circos y el mejoramiento del trato a los animales.
# Buen Gobierno y Ciudadanía
# {'4': '4', '5': 'Muy importante', '2': '2', '92': 'No Sabe / No Responde', '1': 'Nada importante', '3': '3'}
# categorica
# CC7D_4
# De los temas que le voy a leer ¿qué tan importante es para usted que el Concejo los discuta ? de 1 a 5 donde 5 es muy importante y 1 nada importante :  El cuestionamiento a la gestión de funcionarios o entidades del distrito.
# Buen Gobierno y Ciudadanía
# {'4': '4', '5': 'Muy importante', '2': '2', '92': 'No Sabe / No Responde', '1': 'Nada importante', '3': '3'}
# categorica
# CC7D_5
# De los temas que le voy a leer ¿qué tan importante es para usted que el Concejo discuta cada uno de ellos? En una escala de 1 a 5:  El Plan de Desarrollo de la ciudad
# Buen Gobierno y Ciudadanía
# {'4': '4', '5': 'Muy importante', '2': '2', '92': 'No Sabe / No Responde', '1': 'Nada importante', '3': '3'}
# categorica
# CC7E_1
# De estos temas que le acabo de mencionar ¿cuáles está discutiendo el Concejo de (CIUDAD)  en la actualidad?  La reforma tributaria: aumentar los impuestos en general.
# Buen Gobierno y Ciudadanía
# {'92': 'No Sabe / No Responde', '1': 'Si', '2': 'No'}
# categorica
# CC7E_2
# De estos temas que le acabo de mencionar ¿cuáles está discutiendo el Concejo de (CIUDAD)  en la actualidad?  La reforma al código de la policía: reglas de convivencia, procedimientos de policía y cultura ciudadana.
# Buen Gobierno y Ciudadanía
# {'92': 'No Sabe / No Responde', '1': 'Si', '2': 'No'}
# categorica
# CC7E_3
# De estos temas que le acabo de mencionar ¿cuáles está discutiendo el Concejo de (CIUDAD)  en la actualidad?  La prohibición de usar animales en los circos y el mejoramiento del trato a los animales.
# Buen Gobierno y Ciudadanía
# {'92': 'No Sabe / No Responde', '1': 'Si', '2': 'No'}
# categorica
# CC7E_4
# De estos temas que le acabo de mencionar ¿cuáles está discutiendo el Concejo de (CIUDAD)  en la actualidad?  El cuestionamiento a la gestión de funcionarios o entidades del distrito.
# Buen Gobierno y Ciudadanía
# {'92': 'No Sabe / No Responde', '1': 'Si', '2': 'No'}
# categorica
# CC7E_5
# De estos temas que le acabo de mencionar ¿cuáles está discutiendo el Concejo de (CIUDAD)  en la actualidad?  El Plan de Desarrollo de la ciudad
# Buen Gobierno y Ciudadanía
# {'92': 'No Sabe / No Responde', '1': 'Si', '2': 'No'}
# categorica
# CC7
# ¿Sabe Usted que hay una Junta Administradora Local “JAL” compuesta por ediles que son elegidos popularmente en las localidades?
# Buen Gobierno y Ciudadanía
# {'92': 'No Sabe / No Responde', '1': 'Sí sabe', '2': 'No sabe'}
# categorica
# CC8
# ¿Conoce Usted el trabajo desarrollado por la Junta Administradora Local “JAL” y los ediles de la localidad en la que reside?
# Buen Gobierno y Ciudadanía
# {'92': 'No Sabe / No Responde', '1': 'Sí lo conoce', '2': 'No lo conoce'}
# categorica
# CC9
# ¿Conoce usted o había escuchado [HABLAR] antes sobre el Programa [CIUDAD] Cómo Vamos?
# Buen Gobierno y Ciudadanía
# {'92': 'No Sabe / No Responde', '1': 'Sí', '2': 'No'}
# categorica
# CC9C
# ¿Conoce usted o había escuchado [HABLAR] antes sobre el Programa [CIUDAD] Cómo Vamos?
# Buen Gobierno y Ciudadanía
# {'90': 'Ninguno', '1': 'Ciudad Cómo Vamos', '2': 'Concejo Cómo Vamos'}
# categorica
# CC9A
# ¿Conoce usted o había escuchado [HABLAR] antes sobre el Programa [CIUDAD] Cómo Vamos?
# Buen Gobierno y Ciudadanía
# {'90': 'Ninguno', '1': 'Ciudad Cómo Vamos', '2': 'Concejo Cómo Vamos'}
# categorica
# CC10
# ¿Cómo califica, en términos generales, la gestión de la Junta Administradora Local JAL y de los ediles de su localidad, en una escala de 1 a 5, siendo 1 muy mala gestión y 5 muy buena gestión? Puede utilizar cualquier número de la escala.
# Buen Gobierno y Ciudadanía
# {'9': 'Cámara de comercio', '95': 'Todos', '2': 'Entrevistas o notas radiales', '93': 'No responde', '94': 'Cualquiera', '90': 'Ninguno', '97': 'Ningún otro', '3': 'Noticieros de televisión', '7': 'Alguien le comentó / Un amigo le comentó', '17': 'En la  universidad /en el SENA', '10': 'Conferencias', '96': 'No aplica', '16': 'Avisos en la  calle', '4': 'Boletines o informes del Programa', '5': 'A través de Internet', '92': 'No Sabe / No Responde', '18': 'Publicidad (vallas, Comerciales, Avisos)', '11': 'Facebook o Twitter', '6': 'Presentación en conferencia', '12': 'Página web de [CIUDAD ]Cómo Vamos', '14': 'Supercades', '91': 'No Recuerda', '89': 'Otro. ¿Cuál?', '8': 'Programas de Opinión/ Programas de televisión', '13': 'Canales de televisión', '1': 'Informes de prensa', '15': 'Familiares / Ciudadanos'}
# categorica
# CC13
# ¿Sabe Usted que hay representantes en el Congreso de la República que son elegidos por Bogotá?
# Buen Gobierno y Ciudadanía
# {'92': 'No Sabe / No Responde', '1': 'Si', '2': 'No'}
# categorica
# CC13A
# ¿Los representantes en el Congreso de la República elegidos por Bogotá están haciendo cosas por esta ciudad?
# Buen Gobierno y Ciudadanía
# {'92': 'No Sabe / No Responde', '1': 'Sí están haciendo cosas por la ciudad', '2': 'No están haciendo cosas por la ciudad'}
# categorica
# CC13B
# ¿Qué tan insatisfecho(a) o satisfecho(a) está usted con las cosas que están haciendo los representantes en el Congreso de la República elegidos por Bogotá?
# Buen Gobierno y Ciudadanía
# {'4': '4', '5': 'Muy satisfecho', '1': 'Muy insatisfecho', '2': '2', '3': '3'}
# categorica
# CC14
# Pensando en las elecciones que se celebran en el país en diferentes periodos, podría decirme si en general, suele usted votar
# Buen Gobierno y Ciudadanía
# {'4': 'No voto nunca', '2': 'En la mayoría', '93': 'No responde', '1': 'En todas las elecciones', '92': 'No Sabe / No Responde', '3': 'Solo en algunas.'}
# categorica
# CC15A
# Ya para terminar, y solamente con propósitos estadísticos cuénteme, ¿Ud. votó en las pasadas elecciones para
# Buen Gobierno y Ciudadanía
# {'4': 'Presidente de la republica', '7': 'Concejo', '5': 'Congreso', '93': 'No responde', '91': 'No Recuerda', '6': 'Alcalde', '90': 'Ninguna de las Anteriores', '92': 'No Sabe / No Responde'}
# categorica
# CC16
# ¿Cuál considera usted que debe ser la función de su candidato electo una vez que ejerza como concejal?
# Buen Gobierno y Ciudadanía
# {'4': '\tSeñalar los sectores, comunidades o temas a los que se les debe destinar presupuesto del distrito.', '5': '\tExpedir normas para el distrito y controlar la gestión del Alcalde.', '2': 'Defender a los ciudadanos de las decisiones adoptadas por el alcalde u otros funcionarios Distritales', '93': 'No Responde', '9': 'Ayudar / Apoyar a las personas más necesitadas, los pobres / Los niños', '11': 'No esta de acuerdo con la función o el desempeño de los concejales', '6': 'Servir como intermediario entre los ciudadanos y los funcionarios del distrito/Tramitar solicitudes y hacer gestión por las comunidades.', '90': 'Ninguno', '92': 'No Sabe / No Responde', '97': 'Ningún Otro', '3': '\tAsegurar la defensa del interés común y expedir normas en beneficio de todos los ciudadanos', '91': 'No Recuerda', '7': 'Señalar los temas, comunidades o barrios a los que se les deben asignar los recursos del presupuesto', '89': 'Otra. ¿Cuál?________________________________________________________', '8': 'Cumplir con lo prometido en su programa', '96': 'No Aplica', '10': 'Trabajar por el pueblo / los ciudadanos', '1': '\tApoyar a las personas que votaron por él.', '95': 'Todos', '94': 'Cualquiera'}
# categorica
# CC23
# ¿La imagen que Usted tiene del Concejo de [CIUDAD] es favorable o desfavorable?
# Buen Gobierno y Ciudadanía
# {'4': 'El programa que busca reducir el tiempo de los desplazamientos en Bogotá, manejando el tráfico y mejorando la infraestructura vial principalmente.', '7': 'El programa que busca que las entidades públicas del Distrito sean cada vez más modernas y eficientes.', '5': 'El programa que busca lograr un crecimiento más ordenado de Bogotá y ofrecer más oportunidades de vivienda de interés social', '2': 'El programa que busca mejorar la calidad y acceso de toda la población a los servicios de salud y educación', '6': 'El programa que busca mejorar la seguridad en Bogotá logrando una mayor cercanía de la ciudadanía y la policía del Distrito', '90': 'Ninguno', '1': 'El programa para mejorar el nivel de vida en los barrios más pobres de Bogotá, mejorando sus vías, servicios de salud, de educación, de recreación y servicios públicos en general.', '3': 'El programa para que la ciudadanía pueda disfrutar más de los espacios públicos, de recreación y de deporte'}
# categorica
# TOTALP6D_1
# nan
# Extra
# nan
# nan
# TOTALP6D_2
# nan
# Extra
# nan
# nan
# TOTALP6D_3
# nan
# Extra
# nan
# nan
# TOTALP6D_4
# nan
# Extra
# nan
# nan
# TOTALP6D_5
# nan
# Extra
# nan
# nan
# TOTALP6D_6
# nan
# Extra
# nan
# nan
# TOTALP6D_7
# nan
# Extra
# nan
# nan
# TOTALP6D_8
# nan
# Extra
# nan
# nan
# TOTALP6D_HOM
# nan
# Extra
# nan
# nan
# TOTALP6D_MUJ
# nan
# Extra
# nan
# nan

# %%
Asumadre = []

# %%
Asumadre.append({"mybad":"lolol"})

# %%
Asumadre[-1]["mybad"]
# Out:
# 'lolol'

# %%
import pandas
import numpy as np
datos_objetivos = pandas.read_csv("data/indicadores_bogota.csv",delimiter=",", encoding="utf-8", dtype=np.string_ )

# %%
datos_subjetivos = pandas.read_csv("data/encuestas_bogota_lote.csv",delimiter=",", encoding="utf-8", dtype=np.string_ )

# %%
datos_objetivos.columns.values
# Out:
# array(['CIUDAD', 'ANIO', 'LOCALIDAD', '0-PO-27', '0-PO-23', '0-PO-25',
#        '0-PO-36', '0-PO-29', '0-PO-13', '0-PO-12', '0-PO-3', '0-PO-14',
#        '0-PO-1', '0-PO-2', '0-PO-34', '0-PO-37', '0-PO-38', '0-PO-30',
#        '0-PO-28', '0-PO-8', '0-PO-9', '0-PO-6', '0-PO-7', '0-PO-5',
#        '0-PO-4', '0-PD-6', '0-PD-7', '0-PD-37', '0-PD-4', '0-PD-3',
#        '0-PD-11', '0-PD-18', '0-PD-21', '0-PD-24', '0-PD-25', '0-PD-26',
#        '0-PD-22', '0-PD-23', '0-PD-17', '0-PD-16', '0-PD-32', '0-PD-27',
#        '0-PD-33', '0-PD-34', '0-PD-5', '1-SA-36', '1-SA-22', '1-SA-108',
#        '1-SA-90', '1-SA-5', '1-SA-77', '1-SA-111', '1-SA-1132', '1-SA-183',
#        '1-SA-82', '1-SA-105', '1-SA-83', '1-SA-66', '1-SA-185', '1-SA-145',
#        '1-SA-169', '1-SA-170', '1-SA-171', '1-SA-172', '1-SA-168',
#        '1-SA-17', '1-SA-18', '1-SA-19', '1-SA-115', '1-SA-562', '1-SA-63',
#        '1-SA-24', '1-SA-25', '1-SA-26', '1-SA-29', '1-SA-43', '1-SA-35',
#        '1-SA-27', '1-SA-38', '1-SA-39', '1-SA-181', '1-SA-187', '1-SA-184',
#        '1-SA-182', '1-SA-65', '1-SA-189', '1-SA-199', '1-SA-67',
#        '1-SA-188', '1-SA-100', '1-SA-173', '1-SA-28', '1-SA-20', '1-SA-21',
#        '1-SA-47', '1-ED-200', '1-ED-201', '1-ED-198', '1-ED-196',
#        '1-ED-158', '1-ED-28', '1-ED-30', '1-ED-25', '1-ED-29', '1-ED-26',
#        '1-ED-12', '1-ED-160', '1-ED-135', '1-ED-27', '1-ED-162',
#        '1-ED-163', '1-ED-159', '1-ED-134', '1-ED-45', '1-ED-173',
#        '1-ED-167', '1-ED-170', '1-ED-171', '1-ED-166', '1-ED-53',
#        '1-ED-52', '1-ED-55', '1-ED-54', '1-ED-48', '1-ED-154', '1-ED-155',
#        '1-ED-183', '1-ED-182', '1-ED-187', '1-ED-188', '1-ED-184',
#        '1-ED-189', '1-ED-185', '1-ED-186', '1-ED-179', '1-ED-141',
#        '1-ED-146', '1-ED-142', '1-ED-147', '1-ED-143', '1-ED-148',
#        '1-ED-140', '1-ED-145', '1-ED-144', '1-ED-149', '1-ED-192',
#        '1-ED-193', '1-ED-194', '1-ED-191', '1-ED-195', '1-ED-11',
#        '1-ED-124', '1-ED-131', '1-ED-132', '1-ED-133', '1-ED-168',
#        '1-ED-169', '1-ED-136', '1-ED-98', '1-ED-42', '1-ED-68', '1-ED-66',
#        '1-ED-67', '1-ED-64', '1-ED-63', '1-ED-62', '1-ED-57', '1-ED-58',
#        '1-ED-56', '1-ED-59', '1-ED-60', '1-ED-61', '1-ED-69', '1-ED-65',
#        '1-ED-70', '1-ED-71', '1-ED-47', '1-ED-46', '1-ED-84', '1-ED-85',
#        '1-ED-86', '1-ED-87', '1-ED-88', '1-ED-95', '1-ED-96', '1-ED-91',
#        '1-ED-92', '1-ED-93', '1-ED-94', '1-ED-151', '1-ED-31', '1-ED-32',
#        '1-ML-55', '1-ML-51', '1-ML-49', '1-ML-41', '1-ML-59', '1-ML-60',
#        '1-ML-61', '1-SC-402', '1-ML-53', '1-ML-46', '1-SC-319', '1-SC-315',
#        '1-SC-317', '1-SC-320', '1-SC-353', '1-SC-237', '1-SC-403',
#        '1-SC-404', '1-SC-409', '1-SC-293', '1-SC-358', '1-SC-412',
#        '1-SC-413', '1-SC-351', '1-SC-339', '1-SC-161', '1-SC-314',
#        '1-SC-410', '1-SC-355', '1-SC-357', '1-SC-356', '1-SC-411',
#        '2-MO-285', '2-MO-286', '2-MO-287', '2-MO-288', '2-MO-289',
#        '2-MO-290', '2-MO-291', '2-MO-292', '2-MO-293', '2-MO-294',
#        '2-MO-295', '2-MO-296', '2-MO-297', '2-MO-298', '2-MO-299',
#        '2-MO-300', '2-MO-301', '2-MO-302', '2-MO-303', '2-MO-304',
#        '2-MO-305', '2-MO-306', '2-MO-307', '2-MO-308', '2-MO-309',
#        '2-MO-310', '2-MO-311', '2-MO-312', '2-MO-313', '2-MO-314',
#        '2-MO-315', '2-MO-316', '2-MO-317', '2-MO-318', '2-MO-319',
#        '2-MO-320', '2-MO-321', '2-MO-322', '2-MO-323', '2-MO-324',
#        '2-MO-325', '2-MO-326', '2-MO-327', '2-MO-328', '2-MO-329',
#        '2-MO-330', '2-MO-331', '2-MO-332', '2-MO-333', '2-MO-334',
#        '2-MO-335', '2-MO-336', '2-MO-337', '2-MO-338', '2-MO-339',
#        '2-MO-340', '2-MO-341', '2-MO-342', '2-MO-343', '2-MO-344',
#        '2-MO-345', '2-MO-346', '2-MO-347', '2-MO-348', '2-MO-349',
#        '2-MO-350', '2-MO-351', '2-MO-352', '2-MO-131', '1-SC-223',
#        '1-SC-405', '1-SC-406', '1-SC-407', '1-SC-408', '1-SC-338',
#        '1-SC-134', '1-SC-137', '1-SC-368', '1-SC-414', '1-SC-415',
#        '1-SC-416', '1-SC-417', '1-SC-296'], dtype=object)

# %%
print(diccionario_objetivos.columns.values)
# Out:
# ['id' 'Indicador' 'anillo' 'tema' 'fuente' 'notas' 'unidad']

# %%
np.set_printoptions(threshold=np.nan)

# %%
whatadict = {}

# %%
whatadict["key2"] = [{"hat":"wobbuffet","hat2":"wobbuffet"},"lolol"]

# %%
whatadict["key2"]
# Out:
# [{'hat': 'wobbuffet', 'hat2': 'wobbuffet'}, 'lolol']

# %%
import os
import requests
import Levenshtein
import pandas as pd
import csv
import json
import numpy as np

DATADIRECTORY = "data"
OBJECTIVEDATA_STRING = "objetivo"
SUBJECTIVEDATA_STRING = "subjetivo"
OBJECTIVEDATA_VERBOSE = "indicadores"
SUBJECTIVEDATA_VERBOSE = "encuestas"
DICTIONARY_STRING = "diccionario"
DATA_STRING = "datos"


#Diccionario provisional de ciudades
cities = []
#cities_pretty_name = {"bogota":"Bogotá", "cartagena":"Cartagena", "bucaramanga-metropolitana":"Bucaramanga Metropolitana", "cali":"Cali", "ibague": "Ibagué", "manizales": "Manizales", "medellin":"Medellín", "pereira":"Pereira", "valledupar":"Valledupar", "yumbo": "Yumbo"}
cities_pretty_name = {"bogota":"Bogotá"}


def return_city_files(allcityfiles,city):
    cityfiles = []
    for filename in allcityfiles:
        if city in filename:
            cityfiles.append(filename)
    return(cityfiles)

def identify_data_type(cityfiles):
    datatype_byfilename = {}
    for filename in cityfiles:
        ratio_objective = Levenshtein.ratio(filename,OBJECTIVEDATA_VERBOSE)
        ratio_subjetive = Levenshtein.ratio(filename,SUBJECTIVEDATA_VERBOSE)
        if ratio_objective > ratio_subjetive:
            datatype = OBJECTIVEDATA_STRING
        else:
            datatype = SUBJECTIVEDATA_STRING
        if DICTIONARY_STRING in filename:
            filetype = DICTIONARY_STRING
        else:
            filetype = DATA_STRING
        datatype_byfilename[filename] = {"datatype":datatype,"filetype":filetype}
    return(datatype_byfilename)

def return_allcityfiles():
    allcityfiles = os.listdir(DATADIRECTORY)
    return allcityfiles

def get_data_type(files_data_type,type_string):
    dictionaries = {}
    for filename in files_data_type:
        if files_data_type[filename]["filetype"] == type_string:
            dictionaries[files_data_type[filename]["datatype"]] =filename
    return(dictionaries)

def string_cleaner_for_dictionary(source_string):
    midstring_switch = str(source_string).replace("': '","MIDSTRINGSIGNAL")
    endstring_switch = midstring_switch.replace("', '", "ENDOFSTRINGSIGNAL")
    quote_removal = endstring_switch.replace("'","")
    double_quote_removal = quote_removal.replace('"',"")
    midstring_backinplace = double_quote_removal.replace("MIDSTRINGSIGNAL","': '")
    endstring_backinplace = midstring_backinplace.replace("ENDOFSTRINGSIGNAL","', '")
    doublequote_addition = "{'"+str(endstring_backinplace[1:-1])+"'}"
    switch_quote_type= doublequote_addition.replace("'",'"')
    return switch_quote_type

def extract_city_variableinfo(files_data_type,output_json,city,responses):
    dictionaries = get_data_type(files_data_type,DICTIONARY_STRING)
    objective_dictionary = pd.read_csv(DATADIRECTORY + "/" + dictionaries[OBJECTIVEDATA_STRING],delimiter=",", encoding="utf-8", dtype=np.string_ )
    subjective_dictionary = pd.read_csv(DATADIRECTORY + "/" + dictionaries[SUBJECTIVEDATA_STRING],delimiter=",", encoding="utf-8", dtype=np.string_ )

    output_json.append({"name":cities_pretty_name[city], "categories": []})
    output_json[-1]["categories"] = []

    rings = list(objective_dictionary.anillo.unique())
    for extra_ring in list(subjective_dictionary.dimension.unique()):
        if extra_ring not in rings:
            rings.append(extra_ring)
    
    category_position_index = {}
    for ring in rings:
        output_json[-1]["categories"].append({"name" : ring,"indicators" : []})
        category_position_index[ring] = len(output_json[-1]["categories"])-1

    ## Filling objective data
    for i, objective_dictionary_row in objective_dictionary.iterrows():
        if objective_dictionary_row["id"]==objective_dictionary_row["Indicador"]: next
        indicator_category = objective_dictionary_row["anillo"]
        category_position = category_position_index[indicator_category]
        current_indicator_data = {"name" : objective_dictionary_row["id"], "type":"objetivo", "description": objective_dictionary_row["Indicador"]}
        output_json[-1]["categories"][category_position_index[indicator_category]]["indicators"].append(current_indicator_data)
        
    responses_by_variable = {}
    for i, subjective_dictionary_row in subjective_dictionary.iterrows():
        if subjective_dictionary_row["variable"]==subjective_dictionary_row["descripcion"]: next
        indicator_category = subjective_dictionary_row["dimension"]
        category_position = category_position_index[indicator_category]
        if subjective_dictionary_row["tipo_respuestas"] == "ordinal":
            data_type = "subjetivo ordinal"
        else:
            data_type = "subjetivo categorico"
        current_indicator_data = {"name" : subjective_dictionary_row["variable"], "type":data_type, "description": subjective_dictionary_row["descripcion"]}
        output_json[-1]["categories"][category_position_index[indicator_category]]["indicators"].append(current_indicator_data)

        
        
        clean_response_string = string_cleaner_for_dictionary(subjective_dictionary_row["respuestas"])
        
        try:
            responses_by_variable[subjective_dictionary_row["variable"]] = json.loads(clean_response_string)
        except:
            responses_by_variable[subjective_dictionary_row["variable"]] = { "0": "NaN"}

    
    return output_json, responses_by_variable

def generate_cities_json():
    allcityfiles = return_allcityfiles()
    output_variable_json = []
    responses = {}
    for city in cities_pretty_name:
        city_files = return_city_files(allcityfiles,city)
        files_data_type =identify_data_type(city_files)
        output_variable_json, responses = extract_city_variableinfo(files_data_type,output_variable_json,city,responses)

    return output_variable_json, responses

# %%
output_variable_json, responses= generate_cities_json()

# %%
import json
with open('data.txt', 'w') as outfile:
    json.dump(output_variable_json, outfile)

# %%
def dict_key_by_value(dict_to_search, value):
    for key in dict_to_search:
        if dict_to_search[key]==value:
            return key

# %%
allcityfiles = return_allcityfiles()
for city_dictionary in output_variable_json:
    city_pretty = city_dictionary["name"]
    city_plain_name = dict_key_by_value(cities_pretty_name,city_pretty)
    
    city_files = return_city_files(allcityfiles,city_plain_name)
    files_data_type =identify_data_type(city_files)
    data_files = get_data_type(files_data_type,DATA_STRING)
    
    objective_data = pd.read_csv(DATADIRECTORY + "/" + data_files[OBJECTIVEDATA_STRING],delimiter=",", encoding="utf-8", dtype=np.string_ )
    subjective_data = pd.read_csv(DATADIRECTORY + "/" + data_files[SUBJECTIVEDATA_STRING],delimiter=",", encoding="utf-8", dtype=np.string_ )

    
    for category_data in city_dictionary["categories"]:
        for indicator_data in category_data["indicators"]:
            variable_name = indicator_data["name"]
            variable_type = indicator_data["type"]
            try:
                if variable_type == "objetivo":
                    extracted_data = extract_data_columns("ANIO",variable_name,objective_data)
                    values = average_per_year("ANIO",variable_name,extracted_data,"objective")
                elif variable_type == "subjetivo ordinal":
                    extracted_data = extract_data_columns("AÑO",variable_name,subjective_data)
                    values = average_per_year("AÑO",variable_name,extracted_data,"subjective")
                else:
                    extracted_data = extract_data_columns("AÑO",variable_name,subjective_data)
                    values = responses_per_year("AÑO",variable_name,extracted_data,responses)
            except:
                values = [{"Caso especial de los datos": "0"}]
            return_dict = {"name":variable_name, "city":city_pretty, "type":variable_type, "value":values}
            print(return_dict)
            break
        break
    break
# Out:
# {'value': [{'year': 2005, 'value': 0.32691695251428571}, {'year': 2006, 'value': 0.34373425962857146}, {'year': 2007, 'value': 0.36239899395714276}, {'year': 2008, 'value': 0.38318828979999997}, {'year': 2009, 'value': 0.4062966378904761}, {'year': 2010, 'value': 0.43094005258095242}, {'year': 2011, 'value': 0.45351461872380949}, {'year': 2012, 'value': 0.47670678125714278}, {'year': 2013, 'value': 0.50201858080476192}, {'year': 2014, 'value': 0.53018558393809512}], 'type': 'objetivo', 'name': '0-PO-1', 'city': 'Bogotá'}

# %%
def extract_data_columns(year_string,variable_name,data_file):
    extracted_data = data_file[[year_string,variable_name]]
    extracted_data = extracted_data[pd.notnull(data_file[variable_name])]
    return extracted_data

# %%
subjective_data = pandas.read_csv(DATADIRECTORY + "/" + data_files[SUBJECTIVEDATA_STRING],delimiter=",", encoding="utf-8", dtype=np.string_ )
objective_data = pandas.read_csv(DATADIRECTORY + "/" + data_files[OBJECTIVEDATA_STRING],delimiter=",", encoding="utf-8", dtype=np.string_ )

# %%
def average_per_year(year_string, variable_name, filtered_data,data_type):
    data_return = []
    astype_data = filtered_data.convert_objects(convert_numeric=True)
    if data_type == "subjective":
        astype_data = astype_data[(astype_data[variable_name] >= 1.0) & (astype_data[variable_name]<=5.0)]
    ave_data = astype_data.groupby(year_string).mean()
    data_availability = ave_data[variable_name].keys()
    for key in data_availability:
        data_return.append({"year":int(key),"value":ave_data[variable_name][key]})
    return data_return

# %%
def responses_per_year(year_string, variable_name, filtered_data, responses_variable):
    data_return = []
    unique_years = np.unique(filtered_data[[year_string]])
    for year in unique_years:
        yearly_sum = {}
        yearly_data = filtered_data[filtered_data[year_string]==year]
        yearly_responses = {}
        for i, year_indicator in yearly_data.iterrows():
            string_choices = year_indicator[variable_name]
            string_array_choices = string_choices.split(";")
            for choice in string_array_choices:
                if choice in yearly_responses:
                    yearly_responses[choice] = yearly_responses[choice] + 1
                else:
                    yearly_responses[choice] = 1
                    
        for key in yearly_responses:
            try:
                yearly_sum[responses_variable[variable_name][key]] = yearly_responses[key]
            except:
                yearly_sum[key] = yearly_responses[key]
        data_return.append({"year":int(year),"value":yearly_sum})
    return data_return

# %%
extracted_data = extract_data_columns("AÑO","ED4A_12",subjective_data)
responses_per_year("AÑO","ED4A_12", extracted_data, responses)
# Out:
# [{'value': {'El colegio no tiene aprobación para algunos cursos': 1,
#    'Es una institución costosa/sus útiles son costosos/debería ser gratis': 1,
#    'Falta de ética en las instituciones': 1,
#    'Falta más compromiso de los docentes': 2,
#    'Ha disminuido el nivel académico/ el nivel académico es bajo': 7,
#    'Hay mucha delincuencia en los colegios: pandillas, drogas, licor': 9,
#    'La educación es de mala calidad/ mediocre': 10,
#    'Las instituciones no exigen mucho a sus estudiantes': 8,
#    'Le falta dotación al colegio / El colegio no está en buenas condiciones': 2,
#    'Los docentes enseñan poco/Los niños no aprenden nada': 3,
#    'Los estudiantes salen mal preparados': 3,
#    'No Responde': 2,
#    'No enseñan valores y principios': 6,
#    'No hay buen pensum académico': 4,
#    'Otro. ¿Cuál?': 2,
#    'Por la constante suspensión de clases/ paros': 2,
#    'Profesores poco preparados': 1},
#   'year': 2008},
#  {'value': {'Falta más compromiso de los docentes': 13,
#    'Ha disminuido el nivel académico/ el nivel académico es bajo': 20,
#    'Hay mucha delincuencia en los colegios: pandillas, drogas, licor': 9,
#    'La educación es de mala calidad/ mediocre': 23,
#    'Las instituciones no exigen mucho a sus estudiantes': 17,
#    'Los docentes enseñan poco/Los niños no aprenden nada': 11,
#    'Los estudiantes salen mal preparados': 16,
#    'No hay buen pensum académico': 19,
#    'No les están inculcando valores/ principios': 13,
#    'Otro. ¿Cuál?': 1},
#   'year': 2009},
#  {'value': {'Falta más compromiso de los docentes': 19,
#    'Ha disminuido el nivel académico/ el nivel académico es bajo': 37,
#    'Hay mucha delincuencia en los colegios: pandillas, drogas, licor': 8,
#    'La educación es de mala calidad/ mediocre': 29,
#    'Las instituciones no exigen mucho a sus estudiantes': 24,
#    'Los docentes enseñan poco': 17,
#    'Los estudiantes salen mal preparados': 17,
#    'Los niños no aprenden nada': 14,
#    'No Responde': 1,
#    'No hay buen pensum académico': 29,
#    'No les están inculcando valores/ principios': 19,
#    'Otro. ¿Cuál?': 7},
#   'year': 2010},
#  {'value': {'Falta más compromiso de los docentes': 24,
#    'Ha disminuido el nivel académico/ el nivel académico es bajo': 33,
#    'Hay mucha delincuencia en los colegios: pandillas, drogas, licor': 27,
#    'Intensidad horaria muy corta': 5,
#    'La educación es de mala calidad/ mediocre': 26,
#    'Las instituciones no exigen mucho a sus estudiantes': 15,
#    'Les falta exigir más a los docentes': 16,
#    'Les falta más experiencia a los docentes': 10,
#    'Los docentes enseñan poco': 7,
#    'Los estudiantes salen mal preparados': 11,
#    'Los niños no aprenden nada': 12,
#    'No enseñan otros idiomas': 3,
#    'No hay buen pensum académico': 7,
#    'No les están inculcando valores/ principios': 5,
#    'No se cumple con todo el aprendizaje/ está atrasado el aprendizaje': 5,
#    'Otro. ¿Cuál?': 1,
#    'Por la constante suspensión de clases/ paros': 5},
#   'year': 2011}]

# %%
a = "bo"

# %%
a.split(";")
# Out:
# ['bo']

# %%
values
# Out:
# [{'value': 3.8541806020066889, 'year': 2008},
#  {'value': 3.7504690431519698, 'year': 2009},
#  {'value': 3.7407407407407409, 'year': 2010},
#  {'value': 3.6515957446808511, 'year': 2011},
#  {'value': 3.6613226452905812, 'year': 2012},
#  {'value': 3.7269736842105261, 'year': 2013},
#  {'value': 3.7751834556370913, 'year': 2014}]

# %%
import os
import requests
import Levenshtein
import pandas as pd
import csv
import json
import numpy as np

DATADIRECTORY = "data"
OBJECTIVEDATA_STRING = "objetivo"
SUBJECTIVEDATA_STRING = "subjetivo"
OBJECTIVEDATA_VERBOSE = "indicadores"
SUBJECTIVEDATA_VERBOSE = "encuestas"
DICTIONARY_STRING = "diccionario"
DATA_STRING = "datos"


#Diccionario provisional de ciudades
cities = []
cities_pretty_name = {"bogota":"Bogotá", "cartagena":"Cartagena", "bucaramanga-metropolitana":"Bucaramanga Metropolitana", "cali":"Cali", "ibague": "Ibagué", "manizales": "Manizales", "medellin":"Medellín", "pereira":"Pereira", "valledupar":"Valledupar", "yumbo": "Yumbo"}
#cities_pretty_name = {"bogota":"Bogotá"}


def return_city_files(allcityfiles,city):
    cityfiles = []
    for filename in allcityfiles:
        if city in filename:
            cityfiles.append(filename)
    return(cityfiles)

def identify_data_type(cityfiles):
    datatype_byfilename = {}
    for filename in cityfiles:
        ratio_objective = Levenshtein.ratio(filename,OBJECTIVEDATA_VERBOSE)
        ratio_subjetive = Levenshtein.ratio(filename,SUBJECTIVEDATA_VERBOSE)
        if ratio_objective > ratio_subjetive:
            datatype = OBJECTIVEDATA_STRING
        else:
            datatype = SUBJECTIVEDATA_STRING
        if DICTIONARY_STRING in filename:
            filetype = DICTIONARY_STRING
        else:
            filetype = DATA_STRING
        datatype_byfilename[filename] = {"datatype":datatype,"filetype":filetype}
    return(datatype_byfilename)

def return_allcityfiles():
    allcityfiles = os.listdir(DATADIRECTORY)
    return allcityfiles

def get_data_type(files_data_type,type_string):
    dictionaries = {}
    for filename in files_data_type:
        if files_data_type[filename]["filetype"] == type_string:
            dictionaries[files_data_type[filename]["datatype"]] =filename
    return(dictionaries)

def dict_key_by_value(dict_to_search, value):
    for key in dict_to_search:
        if dict_to_search[key]==value:
            return key

def string_cleaner_for_dictionary(source_string):
    midstring_switch = str(source_string).replace("': '","MIDSTRINGSIGNAL")
    endstring_switch = midstring_switch.replace("', '", "ENDOFSTRINGSIGNAL")
    quote_removal = endstring_switch.replace("'","")
    double_quote_removal = quote_removal.replace('"',"")
    midstring_backinplace = double_quote_removal.replace("MIDSTRINGSIGNAL","': '")
    endstring_backinplace = midstring_backinplace.replace("ENDOFSTRINGSIGNAL","', '")
    doublequote_addition = "{'"+str(endstring_backinplace[1:-1])+"'}"
    switch_quote_type= doublequote_addition.replace("'",'"')
    return switch_quote_type

def extract_data_columns(year_string,variable_name,data_file):
    extracted_data = data_file[[year_string,variable_name]]
    extracted_data = extracted_data[pd.notnull(data_file[variable_name])]
    return extracted_data

def average_per_year(year_string, variable_name, filtered_data,data_type):
    data_return = []
    astype_data = filtered_data.convert_objects(convert_numeric=True)
    if data_type == "subjective":
        astype_data = astype_data[(astype_data[variable_name] >= 1.0) & (astype_data[variable_name]<=5.0)]
    ave_data = astype_data.groupby(year_string).mean()
    data_availability = ave_data[variable_name].keys()
    for key in data_availability:
        data_return.append({"year":int(key),"value":str(ave_data[variable_name][key])})
    return data_return

def responses_per_year(year_string, variable_name, filtered_data, responses_variable):
    data_return = []
    unique_years = np.unique(filtered_data[[year_string]])
    for year in unique_years:
        yearly_sum = {}
        yearly_data = filtered_data[filtered_data[year_string]==year]
        yearly_responses = {}
        for i, year_indicator in yearly_data.iterrows():
            string_choices = year_indicator[variable_name]
            string_array_choices = string_choices.split(";")
            for choice in string_array_choices:
                if choice in yearly_responses:
                    yearly_responses[choice] = yearly_responses[choice] + 1
                else:
                    yearly_responses[choice] = 1
                    
        for key in yearly_responses:
            try:
                yearly_sum[responses_variable[variable_name][key]] = str(yearly_responses[key])
            except:
                yearly_sum[key] = str(yearly_responses[key])
        data_return.append({"year":int(year),"value":str(yearly_sum)})
    return data_return

def extract_city_variableinfo(files_data_type,output_json,city,responses):
    dictionaries = get_data_type(files_data_type,DICTIONARY_STRING)
    objective_dictionary = pd.read_csv(DATADIRECTORY + "/" + dictionaries[OBJECTIVEDATA_STRING],delimiter=",", encoding="utf-8", dtype=np.string_ )
    subjective_dictionary = pd.read_csv(DATADIRECTORY + "/" + dictionaries[SUBJECTIVEDATA_STRING],delimiter=",", encoding="utf-8", dtype=np.string_ )

    output_json.append({"name":cities_pretty_name[city], "categories": []})
    output_json[-1]["categories"] = []

    rings = list(objective_dictionary.anillo.unique())
    for extra_ring in list(subjective_dictionary.dimension.unique()):
        if extra_ring not in rings:
            rings.append(extra_ring)
    
    category_position_index = {}
    for ring in rings:
        output_json[-1]["categories"].append({"name" : ring,"indicators" : []})
        category_position_index[ring] = len(output_json[-1]["categories"])-1

    ## Filling objective data
    for i, objective_dictionary_row in objective_dictionary.iterrows():
        if objective_dictionary_row["id"]==objective_dictionary_row["Indicador"]: next
        indicator_category = objective_dictionary_row["anillo"]
        category_position = category_position_index[indicator_category]
        current_indicator_data = {"name" : objective_dictionary_row["id"], "type":"objetivo", "description": objective_dictionary_row["Indicador"]}
        output_json[-1]["categories"][category_position_index[indicator_category]]["indicators"].append(current_indicator_data)
        
    responses_by_variable = {}
    for i, subjective_dictionary_row in subjective_dictionary.iterrows():
        if subjective_dictionary_row["variable"]==subjective_dictionary_row["descripcion"]: next
        indicator_category = subjective_dictionary_row["dimension"]
        category_position = category_position_index[indicator_category]
        if subjective_dictionary_row["tipo_respuestas"] == "ordinal":
            data_type = "subjetivo ordinal"
        else:
            data_type = "subjetivo categorico"
        current_indicator_data = {"name" : subjective_dictionary_row["variable"], "type":data_type, "description": subjective_dictionary_row["descripcion"]}
        output_json[-1]["categories"][category_position_index[indicator_category]]["indicators"].append(current_indicator_data)

        
        
        clean_response_string = string_cleaner_for_dictionary(subjective_dictionary_row["respuestas"])
        
        try:
            responses_by_variable[subjective_dictionary_row["variable"]] = json.loads(clean_response_string)
        except:
            responses_by_variable[subjective_dictionary_row["variable"]] = { "0": "NaN"}

    
    return output_json, responses_by_variable

def generate_city_data():
    allcityfiles = return_allcityfiles()
    output_variable_json = []
    responses = {}
    for city in cities_pretty_name:
        print("Cargando Variables de " + city)
        city_files = return_city_files(allcityfiles,city)
        files_data_type =identify_data_type(city_files)
        output_variable_json, responses = extract_city_variableinfo(files_data_type,output_variable_json,city,responses)
    
    allcityfiles = return_allcityfiles()
    for city_dictionary in output_variable_json:
        city_pretty = city_dictionary["name"]
        print("Cargando Variables de " + city_pretty)
        city_plain_name = dict_key_by_value(cities_pretty_name,city_pretty)
        
        city_files = return_city_files(allcityfiles,city_plain_name)
        files_data_type =identify_data_type(city_files)
        data_files = get_data_type(files_data_type,DATA_STRING)
        
        objective_data = pd.read_csv(DATADIRECTORY + "/" + data_files[OBJECTIVEDATA_STRING],delimiter=",", encoding="utf-8", dtype=np.string_ )
        subjective_data = pd.read_csv(DATADIRECTORY + "/" + data_files[SUBJECTIVEDATA_STRING],delimiter=",", encoding="utf-8", dtype=np.string_ )

        
        for category_data in city_dictionary["categories"]:
            for indicator_data in category_data["indicators"]:
                variable_name = indicator_data["name"]
                variable_type = indicator_data["type"]
                try:
                    if variable_type == "objetivo":
                        extracted_data = extract_data_columns("ANIO",variable_name,objective_data)
                        values = average_per_year("ANIO",variable_name,extracted_data,"objective")
                    elif variable_type == "subjetivo ordinal":
                        extracted_data = extract_data_columns("AÑO",variable_name,subjective_data)
                        values = average_per_year("AÑO",variable_name,extracted_data,"subjective")
                    else:
                        extracted_data = extract_data_columns("AÑO",variable_name,subjective_data)
                        values = responses_per_year("AÑO",variable_name,extracted_data,responses)
                except:
                    values = [{"Caso especial de los datos": "0"}]
                return_dict = {"name":variable_name, "city":city_pretty, "type":variable_type, "value":values}
                db.test_cities.insert_one(return_dict)
        
    return output_variable_json, responses

# %%
generate_city_data()
# Out:
# Cargando Variables de cali
# Cargando Variables de yumbo
# Cargando Variables de valledupar
# Cargando Variables de cartagena
# Cargando Variables de bucaramanga-metropolitana
# Cargando Variables de bogota
# Cargando Variables de manizales
# Cargando Variables de medellin
# Cargando Variables de ibague
# Cargando Variables de pereira
# Cargando Variables de Cali
# Cargando Variables de Yumbo
# Cargando Variables de Valledupar

# %%
from pymongo import MongoClient

client = MongoClient()
db = client.test_cities
